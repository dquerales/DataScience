# %% [markdown]
# # KC House Price Prediction

# %% [markdown]
# ## Importing required libraries

# %%
import sklearn
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## Load data

# %%
df = pd.read_csv('Datasets/kc_house_data.csv')

# %%
df.sample(10)
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 16294  3528900086  20140508T000000  1307000.0         5       3.25
# 2060    538000030  20140730T000000   272500.0         3       2.00
# 18865   123039364  20140521T000000   300000.0         2       1.00
# 3928   7135520300  20150407T000000  1300000.0         3       2.75
# 9480    259600410  20150413T000000   505000.0         3       2.25
# 2123   1085610030  20140801T000000   725500.0         4       2.50
# 20216  6061500130  20140714T000000  1029280.0         4       3.25
# 19939  8562780090  20150227T000000   325000.0         2       2.25
# 11123  2763710060  20140808T000000   459950.0         4       1.75
# 16484  5145100460  20140924T000000   469500.0         4       2.50
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 16294         2800      3200     1.5           0     0  ...     10
# 2060          1540      6250     1.0           0     0  ...      7
# 18865          970     13700     1.0           0     0  ...      6
# 3928          4120     16365     1.0           0     2  ...     12
# 9480          1460      7210     1.0           0     0  ...      7
# 2123          2790     74495     2.0           0     0  ...      9
# 20216         3600     18645     2.0           0     1  ...     10
# 19939         1230      1058     2.0           0     0  ...      7
# 11123         2430      9747     1.0           0     0  ...      8
# 16484         2090      7241     1.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 16294        1910            890      1932          2002    98109  47.6421
# 2060         1540              0      1998             0    98038  47.3539
# 18865         970              0      1949             0    98106  47.5150
# 3928         4120              0      1999             0    98059  47.5265
# 9480         1460              0      1963             0    98008  47.6316
# 2123         2790              0      1997             0    98053  47.6628
# 20216        3000            600      2013             0    98059  47.5294
# 19939        1160             70      2008             0    98027  47.5325
# 11123        1780            650      1974             0    98155  47.7687
# 16484        1140            950      2001             0    98034  47.7260
#
#           long  sqft_living15  sqft_lot15
# 16294 -122.350           2450        3500
# 2060  -122.025           2070        6250
# 18865 -122.362           1570       10880
# 3928  -122.148           4020       14110
# 9480  -122.119           1850        7519
# 2123  -122.056           2790       24643
# 20216 -122.154           3970       10957
# 19939 -122.073           1240         817
# 11123 -122.276           2340       10296
# 16484 -122.221           1510        7402
#
# [10 rows x 21 columns]

# %% [markdown]
# ## Check the dimensions

# %%
df.shape
# Out:
# (21613, 21)

# %% [markdown]
# ## Drop some columns

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
df = df.drop(['id', 'date','zipcode', 'lat', 'long'], axis=1)

# %%
df.head(5)
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
# 1     0          3      7        2170            400      1951          1991
# 2     0          3      6         770              0      1933             0
# 3     0          5      7        1050            910      1965             0
# 4     0          3      8        1680              0      1987             0
#
#    sqft_living15  sqft_lot15
# 0           1340        5650
# 1           1690        7639
# 2           2720        8062
# 3           1360        5000
# 4           1800        7503

# %% [markdown]
# ## Data Cleaning & Preparation

# %% [markdown]
# ### Categorize 'yr_renovated'

# %%
df.loc[df['yr_renovated'] > 1, 'yr_renovated'] = 1

# %%
df['yr_renovated'].head()
# Out:
# 0    0
# 1    1
# 2    0
# 3    0
# 4    0
# Name: yr_renovated, dtype: int64

# %% [markdown]
# ### Check for Nulls

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.shape
# Out:
# (21613, 16)

# %% [markdown]
# ### Check Data Types

# %%
df.dtypes
# Out:
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %% [markdown]
# ### Convert to Categories

# %%
col_names = ['waterfront', 'view', 'yr_renovated']

# %%
for col in col_names:
    df[col] = df[col].astype('category', copy= False)

# %%
df.dtypes
# Out:
# price             float64
# bedrooms            int64
# bathrooms         float64
# sqft_living         int64
# sqft_lot            int64
# floors            float64
# waterfront       category
# view             category
# condition           int64
# grade               int64
# sqft_above          int64
# sqft_basement       int64
# yr_built            int64
# yr_renovated     category
# sqft_living15       int64
# sqft_lot15          int64
# dtype: object

# %% [markdown]
# ## Save data cleaned

# %%
df.to_csv('Cleaned\kc_house_price_data_cleaned.csv', index ='false', header = True)

# %% [markdown]
# ## Visualize some data

# %% [markdown]
# ### Bedrooms vs Bathrooms

# %%
fig,ax = plt.subplots(figsize=(8,6))

plt.scatter(df['bedrooms'], df['bathrooms'])
plt.xlabel('# of bedrooms')
plt.ylabel('# of bathrooms')
plt.show()

# %% [markdown]
# ### SquareFootage vs Price

# %%
fig,ax = plt.subplots(figsize=(8,6))

plt.scatter(df['sqft_living'], df['price'])
plt.xlabel('square fotage of home')
plt.ylabel('price')
plt.show()

# %% [markdown]
# ### Grade vs Price

# %%
fig,ax = plt.subplots(figsize=(8,6))

plt.scatter(df['grade'], df['price'])
plt.xlabel('grade')
plt.ylabel('price')
plt.show()

# %% [markdown]
# ## Check correlation

# %%
df.corr()
# Out:
#                   price  bedrooms  bathrooms  sqft_living  sqft_lot    floors  \
# price          1.000000  0.308350   0.525138     0.702035  0.089661  0.256794
# bedrooms       0.308350  1.000000   0.515884     0.576671  0.031703  0.175429
# bathrooms      0.525138  0.515884   1.000000     0.754665  0.087740  0.500653
# sqft_living    0.702035  0.576671   0.754665     1.000000  0.172826  0.353949
# sqft_lot       0.089661  0.031703   0.087740     0.172826  1.000000 -0.005201
# floors         0.256794  0.175429   0.500653     0.353949 -0.005201  1.000000
# condition      0.036362  0.028472  -0.124982    -0.058753 -0.008958 -0.263768
# grade          0.667434  0.356967   0.664983     0.762704  0.113621  0.458183
# sqft_above     0.605567  0.477600   0.685342     0.876597  0.183512  0.523885
# sqft_basement  0.323816  0.303093   0.283770     0.435043  0.015286 -0.245705
# yr_built       0.054012  0.154178   0.506019     0.318049  0.053080  0.489319
# sqft_living15  0.585379  0.391638   0.568634     0.756420  0.144608  0.279885
# sqft_lot15     0.082447  0.029244   0.087175     0.183286  0.718557 -0.011269
#
#                condition     grade  sqft_above  sqft_basement  yr_built  \
# price           0.036362  0.667434    0.605567       0.323816  0.054012
# bedrooms        0.028472  0.356967    0.477600       0.303093  0.154178
# bathrooms      -0.124982  0.664983    0.685342       0.283770  0.506019
# sqft_living    -0.058753  0.762704    0.876597       0.435043  0.318049
# sqft_lot       -0.008958  0.113621    0.183512       0.015286  0.053080
# floors         -0.263768  0.458183    0.523885      -0.245705  0.489319
# condition       1.000000 -0.144674   -0.158214       0.174105 -0.361417
# grade          -0.144674  1.000000    0.755923       0.168392  0.446963
# sqft_above     -0.158214  0.755923    1.000000      -0.051943  0.423898
# sqft_basement   0.174105  0.168392   -0.051943       1.000000 -0.133124
# yr_built       -0.361417  0.446963    0.423898      -0.133124  1.000000
# sqft_living15  -0.092824  0.713202    0.731870       0.200355  0.326229
# sqft_lot15     -0.003406  0.119248    0.194050       0.017276  0.070958
#
#                sqft_living15  sqft_lot15
# price               0.585379    0.082447
# bedrooms            0.391638    0.029244
# bathrooms           0.568634    0.087175
# sqft_living         0.756420    0.183286
# sqft_lot            0.144608    0.718557
# floors              0.279885   -0.011269
# condition          -0.092824   -0.003406
# grade               0.713202    0.119248
# sqft_above          0.731870    0.194050
# sqft_basement       0.200355    0.017276
# yr_built            0.326229    0.070958
# sqft_living15       1.000000    0.183192
# sqft_lot15          0.183192    1.000000

# %%
fig,ax = plt.subplots(figsize=(8,6))

sns.heatmap(df.corr(), annot=True)
plt.show()

# %% [markdown]
# ## Machine Learning

# %% [markdown]
# ### Define Output and Inputs

# %%
y = df['price']
X = df.drop('price', axis = 1)

# %% [markdown]
# ### Split dataset

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,
                                                   test_size = 0.4,
                                                   random_state = 101)

# %%
X_train.shape, X_test.shape
# Out:
# ((12967, 15), (8646, 15))

# %%
y_train.shape, y_test.shape
# Out:
# ((12967,), (8646,))

# %% [markdown]
# ### Instantiate Linear Regression Model

# %%
reg = LinearRegression()
reg_model = reg.fit(X_train, y_train)

# %% [markdown]
# ### Score

# %%
reg_model.score(X_test, y_test)
# Out:
# 0.6614237738473145

# %% [markdown]
# ### Cross Validation

# %%
from sklearn.model_selection import cross_val_score

# %%
sklearn.metrics.SCORERS.keys()
# Out:
# dict_keys(['explained_variance', 'r2', 'max_error', 'neg_median_absolute_error', 'neg_mean_absolute_error', 'neg_mean_absolute_percentage_error', 'neg_mean_squared_error', 'neg_mean_squared_log_error', 'neg_root_mean_squared_error', 'neg_mean_poisson_deviance', 'neg_mean_gamma_deviance', 'accuracy', 'top_k_accuracy', 'roc_auc', 'roc_auc_ovr', 'roc_auc_ovo', 'roc_auc_ovr_weighted', 'roc_auc_ovo_weighted', 'balanced_accuracy', 'average_precision', 'neg_log_loss', 'neg_brier_score', 'adjusted_rand_score', 'rand_score', 'homogeneity_score', 'completeness_score', 'v_measure_score', 'mutual_info_score', 'adjusted_mutual_info_score', 'normalized_mutual_info_score', 'fowlkes_mallows_score', 'precision', 'precision_macro', 'precision_micro', 'precision_samples', 'precision_weighted', 'recall', 'recall_macro', 'recall_micro', 'recall_samples', 'recall_weighted', 'f1', 'f1_macro', 'f1_micro', 'f1_samples', 'f1_weighted', 'jaccard', 'jaccard_macro', 'jaccard_micro', 'jaccard_samples', 'jaccard_weighted'])

# %%
scores = cross_val_score(reg, X,y, cv=5, scoring='r2')

# %% [markdown]
# #### Make five trained models

# %%
scores
# Out:
# array([0.65601448, 0.65068776, 0.64352625, 0.65810485, 0.62574569])
