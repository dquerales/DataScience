# %% [markdown]
# # Repeated K-Fold CrossValidation

# %% [markdown]
# ## Importing required libraries

# %%
import sklearn

import pandas as pd
import numpy as np

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import RepeatedKFold, cross_val_score

# %% [markdown]
# ## Load data

# %%
df = pd.read_csv('Datasets/Cleaned/kc_house_price_data_cleaned.csv', index_col=0)

# %%
df.head(10)
# Out:
#        price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0   221900.0         3       1.00         1180      5650     1.0           0
# 1   538000.0         3       2.25         2570      7242     2.0           0
# 2   180000.0         2       1.00          770     10000     1.0           0
# 3   604000.0         4       3.00         1960      5000     1.0           0
# 4   510000.0         3       2.00         1680      8080     1.0           0
# 5  1225000.0         4       4.50         5420    101930     1.0           0
# 6   257500.0         3       2.25         1715      6819     2.0           0
# 7   291850.0         3       1.50         1060      9711     1.0           0
# 8   229500.0         3       1.00         1780      7470     1.0           0
# 9   323000.0         3       2.50         1890      6560     2.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
# 1     0          3      7        2170            400      1951             1
# 2     0          3      6         770              0      1933             0
# 3     0          5      7        1050            910      1965             0
# 4     0          3      8        1680              0      1987             0
# 5     0          3     11        3890           1530      2001             0
# 6     0          3      7        1715              0      1995             0
# 7     0          3      7        1060              0      1963             0
# 8     0          3      7        1050            730      1960             0
# 9     0          3      7        1890              0      2003             0
#
#    sqft_living15  sqft_lot15
# 0           1340        5650
# 1           1690        7639
# 2           2720        8062
# 3           1360        5000
# 4           1800        7503
# 5           4760      101930
# 6           2238        6819
# 7           1650        9711
# 8           1780        8113
# 9           2390        7570

# %% [markdown]
# ## Machine Learning

# %% [markdown]
# ### Define Output and Inputs

# %% [markdown]
# #### Convert the output to array format to work with the kfold model validation

# %%
y = (np.array(df['price'], dtype='float64').reshape(-1,1))

X = df.drop('price', axis = 1)
X = np.array(X)

# %%
X.shape, y.shape
# Out:
# ((21613, 15), (21613, 1))

# %% [markdown]
# ### Split dataset for Repeated Cross Validation

# %%
rkf = RepeatedKFold(n_splits=2, n_repeats=1, random_state=2)

# %% [markdown]
# #### We made n_splits splits with 50% test and 50% train partitions each one

# %%
indices_list = list(rkf.split(X))
indices_list
# Out:
# [(array([    3,     6,     7, ..., 21610, 21611, 21612]),
#   array([    0,     1,     2, ..., 21604, 21606, 21608])),
#  (array([    0,     1,     2, ..., 21604, 21606, 21608]),
#   array([    3,     6,     7, ..., 21610, 21611, 21612]))]

# %%
i = 1

for train, test in rkf.split(X):
    print('\nTrain' + str(i), train)
    print('Test' + str(i), test)

    i += 1
# Out:
# Train1 [    3     6     7 ... 21610 21611 21612]
# Test1 [    0     1     2 ... 21604 21606 21608]
#
# Train2 [    0     1     2 ... 21604 21606 21608]
# Test2 [    3     6     7 ... 21610 21611 21612]

# %%
len(X), len(train), len(test)
# Out:
# (21613, 10807, 10806)

# %%
indices_list[0]
# Out:
# (array([    3,     6,     7, ..., 21610, 21611, 21612]),
#  array([    0,     1,     2, ..., 21604, 21606, 21608]))

# %%
X_train1, y_train1 = X[indices_list[0][0]], y[indices_list[0][0]]
X_test1, y_test1 = X[indices_list[0][1]], y[indices_list[0][1]]

X_train2, y_train2 = X[indices_list[1][0]], y[indices_list[1][0]]
X_test2, y_test2 = X[indices_list[1][1]], y[indices_list[1][1]]

# %%
X_train1.shape, y_train1.shape
# Out:
# ((10806, 15), (10806, 1))

# %%
X_test1.shape, y_test1.shape
# Out:
# ((10807, 15), (10807, 1))

# %%
X_train2.shape, y_train2.shape
# Out:
# ((10807, 15), (10807, 1))

# %%
X_test2.shape, y_test2.shape
# Out:
# ((10806, 15), (10806, 1))

# %% [markdown]
# ### Linear Regression Model

# %% [markdown]
# #### Manually split

# %% [markdown]
# ##### First model

# %%
reg = LinearRegression().fit(X_train1, y_train1)

reg.score(X_test1, y_test1)
# Out:
# 0.6532649242956292

# %% [markdown]
# ##### Second model

# %%
reg = LinearRegression().fit(X_train2, y_train2)

reg.score(X_test2, y_test2)
# Out:
# 0.6484865109964704

# %% [markdown]
# #### Repeated Cross Validation Score

# %%
cross_val_score(reg, X,y, cv=rkf)
# Out:
# array([0.65326492, 0.64848651])
