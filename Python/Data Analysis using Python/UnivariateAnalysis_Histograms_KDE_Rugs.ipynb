# %% [markdown]
# # Univariate Analysis: Histograms, KDE & Rug

# %% [markdown]
# ## Importing required libraries

# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Loading the Data

# %%
df = pd.read_csv('Datasets/weight-height.csv')

# %%
df.head()
# Out:
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %% [markdown]
# ## Keep only Height for univariate analysis

# %%
df = df['Height']

# %%
df.head()
# Out:
# 0    73.847017
# 1    68.781904
# 2    74.110105
# 3    71.730978
# 4    69.881796
# Name: Height, dtype: float64

# %%
df.shape
# Out:
# (10000,)

# %% [markdown]
# ## Plot  a Histogram

# %% [markdown]
# is a diagram consisting of rectangles whose area is proportional to the frequency of a variable and whose width is equal to the class interval.

# %%
plt.figure(figsize=(10,8))

sns.histplot(df)

plt.show()

# %% [markdown]
# ### Plot Kernel Density Estimate

# %% [markdown]
# A kernel density estimate (KDE) plot is a method for visualizing the distribution of observations in a dataset, analagous to a histogram. KDE represents the data using a continuous probability density curve in one or more dimensions.

# %%
plt.figure(figsize=(10,8))

sns.histplot(df, kde=True)

plt.show()

# %% [markdown]
# #### Vertical axis

# %%
plt.figure(figsize=(10,8))

sns.histplot(y = df, kde=True)

plt.show()

# %% [markdown]
# ### Add Rug

# %% [markdown]
# Plot marginal distributions by drawing ticks along the x and y axes.
#
# This function is intended to complement other plots by showing the location of individual observations in an unobstrusive way.

# %%
plt.figure(figsize=(10,8))

sns.histplot(df, kde=True)
sns.rugplot(df)

plt.show()

# %% [markdown]
# #### Only the Rugs

# %%
plt.figure(figsize=(10,8))

sns.rugplot(df, height=0.5)

plt.show()

# %% [markdown]
# ### Add # of Bins

# %% [markdown]
# A histogram is a classic visualization tool that represents the distribution of one or more variables by counting the number of observations that fall within disrete bins

# %%
plt.figure(figsize=(10,8))

sns.histplot(df, bins=10)

plt.show()

# %% [markdown]
# ## Personalize Plots

# %% [markdown]
# ### Add shades

# %%
plt.figure(figsize=(10,8))

sns.set(color_codes=True)
sns.kdeplot(df, shade=True)

plt.show()

# %% [markdown]
# ### Change colors

# %%
plt.figure(figsize=(10,8))

sns.set(color_codes=True)
sns.kdeplot(df, shade=True, color='g')

plt.show()

# %% [markdown]
# ### Bandwidth

# %% [markdown]
# The bandwidth, or standard deviation of the smoothing kernel, is an important parameter. Misspecification of the bandwidth can produce a distorted representation of the data. Much like the choice of bin width in a histogram, an over-smoothed curve can erase true features of a distribution, while an under-smoothed curve can create false features out of random variability. The rule-of-thumb that sets the default bandwidth works best when the true distribution is smooth, unimodal, and roughly bell-shaped. It is always a good idea to check the default behavior by using bw_adjust to increase or decrease the amount of smoothing.

# %%
plt.figure(figsize=(10,8))

sns.kdeplot(df)
sns.kdeplot(df, bw_method=0.1, label='BW: 0.1')
sns.kdeplot(df, bw_method=1, label='BW: 1')

plt.show()
