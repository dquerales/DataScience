# %% [markdown]
# # Bivariate Analysis: Joint, Hexbin, KDE & Heatmap

# %% [markdown]
# ## Importing required libraries

# %%
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Loading the Data

# %%
df = pd.read_csv('Datasets/tips.csv')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.shape
# Out:
# (244, 7)

# %% [markdown]
# ## Scatter Plot

# %% [markdown]
# A scatter plot (aka scatter chart, scatter graph) uses dots to represent values for two different numeric variables. The position of each dot on the horizontal and vertical axis indicates values for an individual data point. Scatter plots are used to observe relationships between variables.
#
# The relationship between x and y can be shown for different subsets of the data using the hue, size, and style parameters.

# %%
plt.figure(figsize=(10,8))

sns.scatterplot(x = 'total_bill', y = 'tip', data = df)

plt.show()

# %% [markdown]
# higher the bill, higher the tip. almost a linear relationship

# %% [markdown]
# ### Add a hue

# %% [markdown]
# Grouping variable that will produce points with different colors. Can be either categorical or numeric, although color mapping will behave differently in latter case. Assigning a variable to hue will map its levels to the color of the points.

# %%
plt.figure(figsize=(10,8))

sns.scatterplot(x = 'total_bill', y = 'tip', hue ='smoker', data = df)

plt.show()

# %% [markdown]
# there is no evidence that smokers pays higher bills

# %% [markdown]
# ### Add style

# %% [markdown]
# Assigning the same variable to style will also vary the markers and create a more accessible plot

# %%
plt.figure(figsize=(10,8))

sns.scatterplot(x = 'total_bill', y = 'tip', hue ='time', style = 'time', data = df)

plt.show()

# %% [markdown]
# dinners seems to tips more

# %% [markdown]
# ### Add Size

# %% [markdown]
# A numeric variable can also be assigned to size to apply a semantic mapping to the areas of the points.

# %%
plt.figure(figsize=(10,8))

sns.scatterplot(x = 'total_bill', y = 'tip', hue ='day', size = 'size', data = df)

plt.show()

# %% [markdown]
# is harder to analyze

# %% [markdown]
# ### Customize

# %% [markdown]
# Control the range of marker areas with sizes, and set lengend="full" to force every unique value to appear in the legend:

# %%
plt.figure(figsize=(10,8))

sns.scatterplot(x = 'total_bill', y = 'tip', hue ='size', size = 'size', 
                sizes=(30, 300), hue_norm=(0,7), legend="full", data = df)

plt.show()

# %% [markdown]
# higher parties pays more tips

# %% [markdown]
# ## Hexplot

# %% [markdown]
# Generate a hexagonal binning plot. Similar to Histograms

# %%
df.plot.hexbin(x = 'total_bill', y = 'tip', gridsize=15, figsize=(10,8), sharex=False)

plt.show()

# %% [markdown]
# ## Joint Plots

# %% [markdown]
# A Jointplot comprises three plots. Out of the three, one plot displays a bivariate graph which shows how the dependent variable(Y) varies with the independent variable(X). Another plot is placed horizontally at the top of the bivariate graph and it shows the distribution of the independent variable(X).

# %%
sns.jointplot(x = 'total_bill', y = 'tip', data=df)

plt.show()

# %% [markdown]
# ### Change colors and style

# %%
with sns.axes_style('white'):
    sns.jointplot(x = 'total_bill', y = 'tip', data=df, kind='hex', color='r')

plt.show()

# %% [markdown]
# ## KDE: Kernel Density Estimate for various data

# %%
plt.figure(figsize=(10,8))

sns.kdeplot(x = 'total_bill', y = 'tip', data=df)

plt.show()

# %% [markdown]
# ## Heatmap

# %% [markdown]
# A heat map (or heatmap) is a data visualization technique that shows magnitude of a phenomenon as color in two dimensions. Plot rectangular data as a color-encoded matrix.

# %% [markdown]
# ### Correlation

# %% [markdown]
# Correlation is a statistical term describing the degree to which two variables move in coordination with one another. If the two variables move in the same direction, then those variables are said to have a positive correlation. If they move in opposite directions, then they have a negative correlation.
#
# Is expressed as a positive or negative number between -1 and 1. The value of the number indicates the strength of the relationship:
# * r = 0 means there is no correlation.
# * r = 1 means there is perfect positive correlation.
# * r = -1 means there is a perfect negative correlation.

# %%
df_corr = df.corr()
df_corr
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(df_corr, annot=True)
plt.show()
