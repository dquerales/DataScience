# %% [markdown]
# # TextClassification

# %% [markdown]
# ## Importing required libraries

# %%
import pandas as pd

# %% [markdown]
# ## Loading the Data
# source: https://www.kaggle.com/ashishpatel26/sentimental-analysis-nlp

# %%
df = pd.read_csv('Datasets/sentiment_data.csv', header=None, names=['Label', 'Text'], sep='\t')

# %% [markdown]
# ## Data Cleaning and Preparation

# %% [markdown]
# ### Check the dimensions

# %%
df.shape
# Out:
# (6918, 2)

# %% [markdown]
# ### Check columns names

# %%
df.columns
# Out:
# Index(['Label', 'Text'], dtype='object')

# %%
df.sample(10)
# Out:
#       Label                                               Text
# 1252      1                Mission Impossible 3 was excellent.
# 2498      1                               I love Harry Potter.
# 2819      1                               I love Harry Potter.
# 5012      0  mission impossible is the most worthless movie...
# 6584      0       So Brokeback Mountain was really depressing.
# 5600      0  Always knows what I want, not guy crazy, hates...
# 1206      1  i love kirsten / leah / kate escapades and mis...
# 3650      1  I either LOVE Brokeback Mountain or think it's...
# 5609      0       Is it just me, or does Harry Potter suck?...
# 1384      1            I liked the first " Mission Impossible.

# %% [markdown]
# ### Check for Nulls

# %%
df.isnull().values.any()
# Out:
# False

# %% [markdown]
# ## Machine Learning

# %%
import sklearn
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import LinearSVC
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import accuracy_score

# %% [markdown]
# ### Define Output and Inputs

# %%
y = df['Label']
X = df['Text']

# %% [markdown]
# ### Split dataset

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %% [markdown]
# ### Vectorizer

# %%
tfidf_vect = TfidfVectorizer(max_features=15)

# %% [markdown]
# ### 1) LogisticRegression

# %%
logistic_clf = LogisticRegression(solver='liblinear')

# %% [markdown]
# #### Pipeline

# %%
clf_pipeline = Pipeline(steps=[('tfidf_vect', tfidf_vect), ('classifier', logistic_clf)])

pipeline_model = clf_pipeline.fit(X_train, y_train)

# %% [markdown]
# #### Score

# %%
y_pred = pipeline_model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
accuracy
# Out:
# 0.8894508670520231

# %% [markdown]
# #### Save

# %%
import pickle

# %%
pickle.dump(pipeline_model, open('models/heroku_models/model.pkl',  'wb'))

# %% [markdown]
# ### 2) Decision Tree Classifier

# %%
decision_tree_clf = DecisionTreeClassifier(max_depth=10)

# %% [markdown]
# #### Pipeline

# %%
clf_pipeline = Pipeline(steps=[('tfidf_vect', tfidf_vect), ('classifier', decision_tree_clf)])

pipeline_model = clf_pipeline.fit(X_train, y_train)

# %% [markdown]
# #### Score

# %%
y_pred = pipeline_model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
accuracy
# Out:
# 0.8923410404624278

# %% [markdown]
# #### Save

# %%
pickle.dump(pipeline_model, open('models/heroku_models/model2.pkl',  'wb'))

# %% [markdown]
# ### 3) LinearSVC

# %%
linear_svc_clf = LinearSVC(C=1.0, max_iter=1000)

# %% [markdown]
# #### Pipeline

# %%
clf_pipeline = Pipeline(steps=[('tfidf_vect', tfidf_vect), ('classifier', linear_svc_clf)])

pipeline_model = clf_pipeline.fit(X_train, y_train)

# %% [markdown]
# #### Score

# %%
y_pred = pipeline_model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
accuracy
# Out:
# 0.8894508670520231

# %% [markdown]
# #### Save

# %%
pickle.dump(pipeline_model, open('models/heroku_models/model3.pkl',  'wb'))
