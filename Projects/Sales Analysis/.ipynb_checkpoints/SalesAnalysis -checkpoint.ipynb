# %% [markdown]
# # Sales Analysis

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd

import matplotlib.pyplot as plt

import os

# %% [markdown]
# ## Merge multiples .CSV files

# %%
path = './Datasets'

files = [file for file in os.listdir(path) if not file.startswith('.')] # Ignore hidden files

all_sales_data = pd.DataFrame()

for file in files:
    current_data = pd.read_csv(path+"/"+file)
    all_sales_data = pd.concat([all_sales_data, current_data])
    
all_sales_data.to_csv("all_sales_data.csv", index=False)

# %% [markdown]
# ## Load the merged file

# %%
df = pd.read_csv('all_sales_data.csv')

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Check dimensions

# %%
df.shape
# Out:
# (186850, 6)

# %%
df.sample(10)
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 53821    318046        USB-C Charging Cable                1      11.95
# 123119   196588             ThinkPad Laptop                1     999.99
# 85164    230454    Apple Airpods Headphones                1        150
# 122951   196428        USB-C Charging Cable                1      11.95
# 158179   262593                      iPhone                1        700
# 116730   172960    Lightning Charging Cable                2      14.95
# 70821    144345  Bose SoundSport Headphones                1      99.99
# 5702     182011    Apple Airpods Headphones                1        150
# 31575    296791    Lightning Charging Cable                1      14.95
# 73728    147115    Apple Airpods Headphones                1        150
#
#             Order Date                          Purchase Address
# 53821   12/17/19 15:47            294 11th St, Seattle, WA 98101
# 123119  05/26/19 09:14          875 Dogwood St, Boston, MA 02215
# 85164   07/18/19 15:09     491 South St, San Francisco, CA 94016
# 122951  05/24/19 16:06  318 Highland St, New York City, NY 10001
# 158179  10/14/19 07:51       284 8th St, New York City, NY 10001
# 116730  03/03/19 12:25      612 Cherry St, Los Angeles, CA 90001
# 70821   01/22/19 14:50             740 4th St, Atlanta, GA 30301
# 5702    04/12/19 19:48              92 8th St, Atlanta, GA 30301
# 31575   12/04/19 22:57           678 14th St, Portland, OR 97035
# 73728   01/05/19 15:17   254 Jackson St, New York City, NY 10001

# %% [markdown]
# ### Check for nulls

# %%
df.isnull().any()
# Out:
# Order ID            True
# Product             True
# Quantity Ordered    True
# Price Each          True
# Order Date          True
# Purchase Address    True
# dtype: bool

# %% [markdown]
# #### Drop all nulls values

# %%
df = df.dropna()

# %% [markdown]
# ### Check for duplicates

# %%
df.duplicated().any()
# Out:
# True

# %% [markdown]
# #### Drop duplicates

# %%
df = df.drop_duplicates()

# %% [markdown]
# ## Check data types

# %%
df.dtypes
# Out:
# Order ID            object
# Product             object
# Quantity Ordered    object
# Price Each          object
# Order Date          object
# Purchase Address    object
# dtype: object

# %% [markdown]
# #### Get rid of the OR in date

# %%
df = df[df['Order Date'].str[0:2]!='Or']

# %% [markdown]
# #### Change to Numeric

# %%
df['Quantity Ordered'] = pd.to_numeric(df['Quantity Ordered'])
df['Price Each'] = pd.to_numeric(df['Price Each'])

# %% [markdown]
# #### Change to Datetime

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])

# %%
df.dtypes
# Out:
# Order ID                    object
# Product                     object
# Quantity Ordered             int64
# Price Each                 float64
# Order Date          datetime64[ns]
# Purchase Address            object
# dtype: object

# %% [markdown]
# ## Question 1: What was the best month for sales? How much was earned that month?

# %% [markdown]
# ### Add a Column for Month

# %%
df['Month'] = pd.to_datetime(df['Order Date']).dt.month

# %%
df.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address  Month
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      4
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215      4
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001      4

# %% [markdown]
# ### Add a Column for Sales

# %%
df['Sales'] = df['Quantity Ordered'].astype('int') * df['Price Each'].astype('float')

# %%
df.sample(10)
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 100340   218217       AA Batteries (4-pack)                 2        3.84
# 25397    243387                      iPhone                 1      700.00
# 150730   291798            Wired Headphones                 1       11.99
# 46110    310682                      iPhone                 1      700.00
# 22906    241012    Lightning Charging Cable                 1       14.95
# 108154   164757        USB-C Charging Cable                 1       11.95
# 110237   166749  Bose SoundSport Headphones                 1       99.99
# 177782   250662    Apple Airpods Headphones                 1      150.00
# 25812    243781    Apple Airpods Headphones                 1      150.00
# 86150    231394    Lightning Charging Cable                 1       14.95
#
#                 Order Date                        Purchase Address  Month  \
# 100340 2019-06-13 20:54:00           989 Park St, Boston, MA 02215      6
# 25397  2019-08-07 22:20:00  854 Chestnut St, Los Angeles, CA 90001      8
# 150730 2019-11-18 16:30:00       545 Highland St, Austin, TX 73301     11
# 46110  2019-12-16 12:14:00        290 Meadow St, Atlanta, GA 30301     12
# 22906  2019-08-18 18:14:00          772 10th St, Seattle, WA 98101      8
# 108154 2019-03-02 19:32:00           437 West St, Dallas, TX 75001      3
# 110237 2019-03-08 18:33:00       330 Lakeview St, Boston, MA 02215      3
# 177782 2019-09-28 11:42:00    869 12th St, San Francisco, CA 94016      9
# 25812  2019-08-25 13:29:00       588 4th St, Los Angeles, CA 90001      8
# 86150  2019-07-26 23:33:00         967 Ridge St, Atlanta, GA 30301      7
#
#          Sales
# 100340    7.68
# 25397   700.00
# 150730   11.99
# 46110   700.00
# 22906    14.95
# 108154   11.95
# 110237   99.99
# 177782  150.00
# 25812   150.00
# 86150    14.95

# %%
max_sales_month = df.groupby(['Month']).sum()
max_sales_month
# Out:
#        Quantity Ordered  Price Each       Sales
# Month
# 1                 10893  1810924.81  1821413.16
# 2                 13431  2186940.38  2200078.08
# 3                 16979  2789084.64  2804973.35
# 4                 20536  3366218.76  3389217.98
# 5                 18653  3133134.61  3150616.23
# 6                 15234  2560503.50  2576280.15
# 7                 16054  2631225.12  2646461.32
# 8                 13429  2226963.90  2241083.37
# 9                 13091  2081897.65  2094465.69
# 10                22669  3713608.80  3734777.86
# 11                19769  3178872.53  3197875.05
# 12                28074  4583267.77  4608295.70

# %%
plt.figure(figsize=(10,8))
plt.bar(max_sales_month.index, max_sales_month['Sales'])

plt.title('Sales by Months')
plt.xlabel('Month')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
# ## Question 2: What city sold the most product?

# %% [markdown]
# ### Add city column

# %%
def get_city(address):
    return address.split(",")[1].strip(" ")

def get_state(address):
    return address.split(",")[2].split(" ")[1]

df['City'] = df['Purchase Address'].apply(lambda x: f"{get_city(x)}  ({get_state(x)})")
df.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address  Month   Sales  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      4   23.90
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215      4   99.99
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4  600.00
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4   11.99
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001      4   11.99
#
#                 City
# 0       Dallas  (TX)
# 2       Boston  (MA)
# 3  Los Angeles  (CA)
# 4  Los Angeles  (CA)
# 5  Los Angeles  (CA)

# %%
max_sales_city = df.groupby(['City']).sum()
max_sales_city
# Out:
#                      Quantity Ordered  Price Each   Month       Sales
# City
# Atlanta  (GA)                   16584  2778608.69  104649  2794199.07
# Austin  (TX)                    11137  1808340.03   69720  1818044.33
# Boston  (MA)                    22494  3634398.40  140898  3658627.65
# Dallas  (TX)                    16707  2750026.38  104447  2765373.96
# Los Angeles  (CA)               33247  5417171.70  208020  5448304.28
# New York City  (NY)             27903  4632920.54  175557  4661867.14
# Portland  (ME)                   2746   446752.36   17119   449321.38
# Portland  (OR)                  11291  1859836.44   70517  1870010.56
# San Francisco  (CA)             50169  8204001.38  314949  8254743.55
# Seattle  (WA)                   16534  2730586.55  104817  2745046.02

# %%
plt.figure(figsize=(10,8))

plt.bar(max_sales_city.index, max_sales_city['Sales'])

plt.title('Sales by Cities')
plt.xlabel('Citys')
plt.ylabel('Sales')
plt.xticks(rotation='vertical', size=8)
plt.show()

# %% [markdown]
# ## Question 3: Sales By Hour?

# %% [markdown]
# ### Add hour column

# %%
df['Hour'] = pd.to_datetime(df['Order Date']).dt.hour

# %%
df.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address  Month   Sales  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      4   23.90
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215      4   99.99
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4  600.00
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4   11.99
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001      4   11.99
#
#                 City  Hour
# 0       Dallas  (TX)     8
# 2       Boston  (MA)    22
# 3  Los Angeles  (CA)    14
# 4  Los Angeles  (CA)    14
# 5  Los Angeles  (CA)     9

# %%
max_sales_hour = df.groupby(['Hour']).sum()
max_sales_hour
# Out:
#       Quantity Ordered  Price Each  Month       Sales
# Hour
# 0                 4420   709124.09  27477   713548.66
# 1                 2616   458187.02  16643   460563.90
# 2                 1397   233821.65   8502   234839.45
# 3                  927   144711.47   5903   145742.94
# 4                  935   161943.24   6135   162546.07
# 5                 1492   229606.26   9298   230664.87
# 6                 2809   444850.12  17528   447963.01
# 7                 4547   739781.31  28787   744067.32
# 8                 6998  1185930.85  43605  1192309.20
# 9                 9808  1628251.95  60930  1638784.04
# 10               12292  1931369.92  76781  1942988.08
# 11               13986  2284864.78  87522  2296619.84
# 12               14188  2297415.19  89058  2314359.85
# 13               13671  2136724.04  85699  2152369.98
# 14               12343  2071035.74  77687  2082513.70
# 15               11375  1930248.59  71933  1940623.20
# 16               11636  1890379.42  72742  1902523.20
# 17               12214  2113969.38  77365  2126553.97
# 18               13785  2206722.64  86287  2218374.01
# 19               14451  2397620.91  91254  2411971.14
# 20               13758  2267253.28  86299  2280784.36
# 21               12228  2029553.45  76994  2040790.48
# 22                9884  1598162.92  61984  1606243.85
# 23                7052  1171114.25  44280  1177792.82

# %%
plt.figure(figsize=(10,8))

plt.plot(max_sales_hour.index, max_sales_hour['Sales'])

plt.title('Sales by hour')
plt.xlabel('Hour')
plt.ylabel('Sales')
plt.xticks(max_sales_hour.index)
plt.grid()
plt.show()

# %% [markdown]
# ## Question 4: What products sold the most?

# %%
df.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address  Month   Sales  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      4   23.90
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215      4   99.99
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4  600.00
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4   11.99
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001      4   11.99
#
#                 City  Hour
# 0       Dallas  (TX)     8
# 2       Boston  (MA)    22
# 3  Los Angeles  (CA)    14
# 4  Los Angeles  (CA)    14
# 5  Los Angeles  (CA)     9

# %%
most_sold = df.groupby(['Product']).sum()
most_sold
# Out:
#                             Quantity Ordered  Price Each   Month       Sales  \
# Product
# 20in Monitor                            4126   450739.02   29319   453818.74
# 27in 4K Gaming Monitor                  6239  2427687.75   44396  2433147.61
# 27in FHD Monitor                        7541  1124625.02   52484  1131074.59
# 34in Ultrawide Monitor                  6192  2346058.26   43258  2352898.08
# AA Batteries (4-pack)                  27615    78942.72  145423   106041.60
# AAA Batteries (4-pack)                 30986    61629.88  146149    92648.14
# Apple Airpods Headphones               15637  2328750.00  109304  2345550.00
# Bose SoundSport Headphones             13430  1329667.02   93918  1342865.70
# Flatscreen TV                           4813  1438200.00   34172  1443900.00
# Google Phone                            5529  3313200.00   38286  3317400.00
# LG Dryer                                 646   387600.00    4383   387600.00
# LG Washing Machine                       666   399600.00    4523   399600.00
# Lightning Charging Cable               23169   323069.50  152741   346376.55
# Macbook Pro Laptop                      4725  8025700.00   33526  8032500.00
# ThinkPad Laptop                         4128  4125958.74   28926  4127958.72
# USB-C Charging Cable                   23931   261215.05  154520   285975.45
# Vareebadd Phone                         2068   826000.00   14309   827200.00
# Wired Headphones                       20524   225999.51  133123   246082.76
# iPhone                                  6847  4788000.00   47933  4792900.00
#
#                               Hour
# Product
# 20in Monitor                 58729
# 27in 4K Gaming Monitor       90841
# 27in FHD Monitor            107422
# 34in Ultrawide Monitor       88957
# AA Batteries (4-pack)       298077
# AAA Batteries (4-pack)      296904
# Apple Airpods Headphones    222938
# Bose SoundSport Headphones  192077
# Flatscreen TV                68719
# Google Phone                 79438
# LG Dryer                      9326
# LG Washing Machine            9785
# Lightning Charging Cable    311815
# Macbook Pro Laptop           68225
# ThinkPad Laptop              59713
# USB-C Charging Cable        313980
# Vareebadd Phone              29472
# Wired Headphones            271245
# iPhone                       98617

# %%
plt.figure(figsize=(10,8))

plt.bar(most_sold.index, most_sold['Quantity Ordered'])

plt.xlabel('Product')
plt.ylabel('Quantity Ordered')
plt.xticks(rotation='vertical', size=8)
plt.show()

# %% [markdown]
# ## Question 5: What products are most often sold together?

# %%
df.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address  Month   Sales  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      4   23.90
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215      4   99.99
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4  600.00
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4   11.99
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001      4   11.99
#
#                 City  Hour
# 0       Dallas  (TX)     8
# 2       Boston  (MA)    22
# 3  Los Angeles  (CA)    14
# 4  Los Angeles  (CA)    14
# 5  Los Angeles  (CA)     9

# %%
# https://stackoverflow.com/questions/43348194/pandas-select-rows-if-id-appear-several-time
same_order_id = df[df['Order ID'].duplicated(keep=False)]
same_order_id
# Out:
#        Order ID                 Product  Quantity Ordered  Price Each  \
# 3        176560            Google Phone                 1      600.00
# 4        176560        Wired Headphones                 1       11.99
# 18       176574            Google Phone                 1      600.00
# 19       176574    USB-C Charging Cable                 1       11.95
# 32       176586  AAA Batteries (4-pack)                 2        2.99
# ...         ...                     ...               ...         ...
# 186792   259303   AA Batteries (4-pack)                 1        3.84
# 186803   259314        Wired Headphones                 1       11.99
# 186804   259314  AAA Batteries (4-pack)                 2        2.99
# 186841   259350            Google Phone                 1      600.00
# 186842   259350    USB-C Charging Cable                 1       11.95
#
#                 Order Date                        Purchase Address  Month  \
# 3      2019-04-12 14:38:00    669 Spruce St, Los Angeles, CA 90001      4
# 4      2019-04-12 14:38:00    669 Spruce St, Los Angeles, CA 90001      4
# 18     2019-04-03 19:42:00       20 Hill St, Los Angeles, CA 90001      4
# 19     2019-04-03 19:42:00       20 Hill St, Los Angeles, CA 90001      4
# 32     2019-04-10 17:00:00  365 Center St, San Francisco, CA 94016      4
# ...                    ...                                     ...    ...
# 186792 2019-09-20 20:18:00           106 7th St, Atlanta, GA 30301      9
# 186803 2019-09-16 00:25:00      241 Highland St, Atlanta, GA 30301      9
# 186804 2019-09-16 00:25:00      241 Highland St, Atlanta, GA 30301      9
# 186841 2019-09-30 13:49:00   519 Maple St, San Francisco, CA 94016      9
# 186842 2019-09-30 13:49:00   519 Maple St, San Francisco, CA 94016      9
#
#          Sales                 City  Hour
# 3       600.00    Los Angeles  (CA)    14
# 4        11.99    Los Angeles  (CA)    14
# 18      600.00    Los Angeles  (CA)    19
# 19       11.95    Los Angeles  (CA)    19
# 32        5.98  San Francisco  (CA)    17
# ...        ...                  ...   ...
# 186792    3.84        Atlanta  (GA)    20
# 186803   11.99        Atlanta  (GA)     0
# 186804    5.98        Atlanta  (GA)     0
# 186841  600.00  San Francisco  (CA)    13
# 186842   11.95  San Francisco  (CA)    13
#
# [14128 rows x 10 columns]

# %%
# Referenced: https://stackoverflow.com/questions/27298178/concatenate-strings-from-several-rows-using-pandas-groupby
df['Grouped'] = df.groupby('Order ID')['Product'].transform(lambda x: ','.join(x))
df2 = df[['Order ID', 'Grouped']].drop_duplicates()

# %%
# Referenced: https://stackoverflow.com/questions/52195887/counting-unique-pairs-of-numbers-into-a-python-dictionary
from itertools import combinations
from collections import Counter

count = Counter()

for row in df2['Grouped']:
    row_list = row.split(',')
    count.update(Counter(combinations(row_list, 2)))

for key,value in count.most_common(10):
    print(key, value)
# Out:
# ('iPhone', 'Lightning Charging Cable') 1002
# ('Google Phone', 'USB-C Charging Cable') 985
# ('iPhone', 'Wired Headphones') 447
# ('Google Phone', 'Wired Headphones') 413
# ('Vareebadd Phone', 'USB-C Charging Cable') 361
# ('iPhone', 'Apple Airpods Headphones') 360
# ('Google Phone', 'Bose SoundSport Headphones') 220
# ('USB-C Charging Cable', 'Wired Headphones') 159
# ('Vareebadd Phone', 'Wired Headphones') 143
# ('Lightning Charging Cable', 'Wired Headphones') 92
