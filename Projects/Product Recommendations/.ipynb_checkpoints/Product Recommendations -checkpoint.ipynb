# %% [markdown]
# # Product Recommendations

# %% [markdown]
# ## Importing libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import squarify as sq

# %% [markdown]
# ## Load data
#
# source: https://www.kaggle.com/hellbuoy/online-retail-k-means-hierarchical-clustering/data

# %%
df = pd.read_excel('./Datasets/Online_Retail.xlsx')

# %% [markdown]
# ### Check dimensions

# %%
df.head(10)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5    536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6    536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7    536366     22633               HAND WARMER UNION JACK         6
# 8    536366     22632            HAND WARMER RED POLKA DOT         6
# 9    536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 5 2010-12-01 08:26:00       7.65     17850.0  United Kingdom
# 6 2010-12-01 08:26:00       4.25     17850.0  United Kingdom
# 7 2010-12-01 08:28:00       1.85     17850.0  United Kingdom
# 8 2010-12-01 08:28:00       1.85     17850.0  United Kingdom
# 9 2010-12-01 08:34:00       1.69     13047.0  United Kingdom

# %%
df.shape
# Out:
# (541909, 8)

# %% [markdown]
# ### Check data types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %% [markdown]
# ## Data Cleaning and Preparation

# %% [markdown]
# ### Drop some columns

# %%
df.drop(['StockCode', 'CustomerID'], axis=1, inplace=True)

# %%
df.head()
# Out:
#   InvoiceNo                          Description  Quantity  \
# 0    536365   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365                  WHITE METAL LANTERN         6
# 2    536365       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice         Country
# 0 2010-12-01 08:26:00       2.55  United Kingdom
# 1 2010-12-01 08:26:00       3.39  United Kingdom
# 2 2010-12-01 08:26:00       2.75  United Kingdom
# 3 2010-12-01 08:26:00       3.39  United Kingdom
# 4 2010-12-01 08:26:00       3.39  United Kingdom

# %% [markdown]
# ### Eliminate the white spaces

# %%
df['Description'] = df['Description'].str.strip()

# %%
df.head()
# Out:
#   InvoiceNo                          Description  Quantity  \
# 0    536365   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365                  WHITE METAL LANTERN         6
# 2    536365       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice         Country
# 0 2010-12-01 08:26:00       2.55  United Kingdom
# 1 2010-12-01 08:26:00       3.39  United Kingdom
# 2 2010-12-01 08:26:00       2.75  United Kingdom
# 3 2010-12-01 08:26:00       3.39  United Kingdom
# 4 2010-12-01 08:26:00       3.39  United Kingdom

# %% [markdown]
# ### Check for nulls

# %%
df.isnull().any()
# Out:
# InvoiceNo      False
# Description     True
# Quantity       False
# InvoiceDate    False
# UnitPrice      False
# Country        False
# dtype: bool

# %% [markdown]
# #### Drop nulls

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (540454, 6)

# %% [markdown]
# ### Clear returned in InvoiceNo

# %%
df['InvoiceNo'].str.contains('C').value_counts()
# Out:
# True     9288
# False       3
# Name: InvoiceNo, dtype: int64

# %%
df['InvoiceNo'] = df['InvoiceNo'].astype(str)

# %%
df = df[-df['InvoiceNo'].str.contains('C')]

# %%
df.shape
# Out:
# (531166, 6)

# %% [markdown]
# ### Remove duplicates

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (525856, 6)

# %% [markdown]
# ### Remove Postage Invoice

# %%
postage = df['Description'] == 'POSTAGE'
postage.value_counts()
# Out:
# False    524730
# True       1126
# Name: Description, dtype: int64

# %%
df = df.drop(df[postage].index)

# %%
df.shape
# Out:
# (524730, 6)

# %% [markdown]
# ### Check for unique country values

# %%
df['Country'].value_counts()
# Out:
# United Kingdom          480895
# Germany                   8653
# France                    8093
# EIRE                      7883
# Spain                     2418
# Netherlands               2326
# Belgium                   1935
# Switzerland               1928
# Portugal                  1462
# Australia                 1183
# Norway                    1052
# Channel Islands            747
# Italy                      741
# Finland                    648
# Cyprus                     601
# Unspecified                442
# Sweden                     428
# Austria                    384
# Denmark                    367
# Poland                     325
# Japan                      321
# Israel                     291
# Hong Kong                  278
# Singapore                  222
# Iceland                    182
# USA                        179
# Canada                     150
# Greece                     142
# Malta                      109
# United Arab Emirates        67
# RSA                         58
# European Community          57
# Lebanon                     45
# Lithuania                   35
# Brazil                      32
# Czech Republic              24
# Bahrain                     18
# Saudi Arabia                 9
# Name: Country, dtype: int64

# %% [markdown]
# #### Filter for Germany, Spain, France, Netherlands  & Belgium

# %%
country_list = ['Germany', 'France', 'Spain', 'Netherlands', 'Belgium']
df = df.loc[df['Country'].isin(country_list)].reset_index().drop('index', axis=1)

# %%
df.shape
# Out:
# (23425, 6)

# %% [markdown]
# ## Data Exploration

# %% [markdown]
# ### Add a column for Total Prices

# %%
df['TotalPrice'] = df['Quantity']*df['UnitPrice']

# %%
df.head()
# Out:
#   InvoiceNo                      Description  Quantity         InvoiceDate  \
# 0    536370        ALARM CLOCK BAKELIKE PINK        24 2010-12-01 08:45:00
# 1    536370         ALARM CLOCK BAKELIKE RED        24 2010-12-01 08:45:00
# 2    536370       ALARM CLOCK BAKELIKE GREEN        12 2010-12-01 08:45:00
# 3    536370  PANDA AND BUNNIES STICKER SHEET        12 2010-12-01 08:45:00
# 4    536370                  STARS GIFT TAPE        24 2010-12-01 08:45:00
#
#    UnitPrice Country  TotalPrice
# 0       3.75  France        90.0
# 1       3.75  France        90.0
# 2       3.75  France        45.0
# 3       0.85  France        10.2
# 4       0.65  France        15.6

# %% [markdown]
# ### Add more dates formats

# %%
df.dtypes
# Out:
# InvoiceNo              object
# Description            object
# Quantity                int64
# InvoiceDate    datetime64[ns]
# UnitPrice             float64
# Country                object
# TotalPrice            float64
# dtype: object

# %%
df['Year'] = df['InvoiceDate'].dt.year
df['Month'] = df['InvoiceDate'].dt.month
df['Hour'] = df['InvoiceDate'].dt.hour
df['DayOfWeek'] = df['InvoiceDate'].dt.dayofweek
df['DayName'] = df['InvoiceDate'].dt.day_name()

# %%
df.sample(5)
# Out:
#       InvoiceNo                        Description  Quantity  \
# 3049     542629           PLASTERS IN TIN SPACEBOY        96
# 6793     551544        SET/6 RED SPOTTY PAPER CUPS        24
# 12055    562034               RED DINER WALL CLOCK         2
# 17722    571065  STRAWBERRY LUNCH BOX WITH CUTLERY        12
# 6270     550145          JUMBO BAG SPACEBOY DESIGN        10
#
#               InvoiceDate  UnitPrice  Country  TotalPrice  Year  Month  Hour  \
# 3049  2011-01-31 09:57:00       1.45   France       139.2  2011      1     9
# 6793  2011-05-03 09:33:00       0.65   France        15.6  2011      5     9
# 12055 2011-08-02 09:14:00       8.50  Belgium        17.0  2011      8     9
# 17722 2011-10-13 14:59:00       2.55  Germany        30.6  2011     10    14
# 6270  2011-04-14 14:15:00       2.08   France        20.8  2011      4    14
#
#        DayOfWeek   DayName
# 3049           0    Monday
# 6793           1   Tuesday
# 12055          1   Tuesday
# 17722          3  Thursday
# 6270           3  Thursday

# %% [markdown]
# #### Order By days

# %%
day_names = ['Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday']
df['DayName'] = pd.Categorical(df['DayName'], categories = day_names, ordered = True )

# %%
df.head()
# Out:
#   InvoiceNo                      Description  Quantity         InvoiceDate  \
# 0    536370        ALARM CLOCK BAKELIKE PINK        24 2010-12-01 08:45:00
# 1    536370         ALARM CLOCK BAKELIKE RED        24 2010-12-01 08:45:00
# 2    536370       ALARM CLOCK BAKELIKE GREEN        12 2010-12-01 08:45:00
# 3    536370  PANDA AND BUNNIES STICKER SHEET        12 2010-12-01 08:45:00
# 4    536370                  STARS GIFT TAPE        24 2010-12-01 08:45:00
#
#    UnitPrice Country  TotalPrice  Year  Month  Hour  DayOfWeek    DayName
# 0       3.75  France        90.0  2010     12     8          2  Wednesday
# 1       3.75  France        90.0  2010     12     8          2  Wednesday
# 2       3.75  France        45.0  2010     12     8          2  Wednesday
# 3       0.85  France        10.2  2010     12     8          2  Wednesday
# 4       0.65  France        15.6  2010     12     8          2  Wednesday

# %% [markdown]
# #### Sales by days

# %%
plt.figure(figsize=(12,8))

sns.barplot(x = 'DayName', y = 'TotalPrice', data=df)

plt.title('Sales by days')
plt.xlabel('Day')
plt.ylabel('Sales')

plt.show()

# %% [markdown]
# there is no sales on Saturdays?, best days for sales are Tuesday & Thursday

# %% [markdown]
# #### Sales by Month

# %%
df_pivot = df.pivot_table(index='Month', columns='DayName', values='TotalPrice', aggfunc='mean')
df_pivot
# Out:
# DayName     Sunday     Monday    Tuesday  Wednesday   Thursday     Friday
# Month
# 1        26.025000  24.766365  46.299746  40.338789  22.085097  38.347284
# 2        23.150000  74.194207  45.645154  18.233016  22.741106  25.395356
# 3        19.602969  18.164542  57.338449  27.440779  37.088345  27.024802
# 4        18.649273  20.037667  44.058643  30.422222  22.354359  23.642424
# 5        18.302639  21.383593  22.520855  34.793415  71.900937  24.977168
# 6        40.425342  18.821746  73.415069  38.850478  16.218297  31.145503
# 7        17.645641  32.434065  16.347103  19.859714  28.868000  18.439963
# 8        12.416514  24.139852  45.434715  29.926565  52.648891  39.625314
# 9        17.497778  60.180836  54.367273  18.050346  26.593925  23.590600
# 10       15.748333  14.791372  18.887305  25.394492  74.192019  53.689263
# 11       22.118882  20.819067  21.573020  48.430603  30.750851  18.314654
# 12       19.884133  22.206786  45.796738  44.319125  19.235773  28.643890

# %%
plt.figure(figsize=(12,8))

sns.heatmap(df_pivot, linewidths=1, annot=True)

plt.title('Avg Revenue')
plt.xlabel('Days of the Week')
plt.ylabel('Month')

plt.show()

# %% [markdown]
# there is no real pattern

# %% [markdown]
# #### 10 Most popular items

# %%
fig, ax = plt.subplots(figsize=(12,8))

df['Description'].value_counts().sort_values(ascending=False).head(10).plot.bar()
plt.title('Top 10 Most Popular Items')
plt.xlabel('Description')
plt.ylabel('Frequency')

plt.show()

# %%
plt.figure(figsize=(16,8))

x = df['Description'].value_counts().sort_values(ascending=False).head(10)

color = ['lime', 'pink', 'lightgreen', 'yellow', 'orange', 'red', 'lightblue', 'cyan', 'azure']

sq.plot(sizes=x, label=x.index, color=color).axis('off')

plt.title('Top 10 Most Popular Items')

plt.show()

# %% [markdown]
# ## Machine Learning for Product Recommendations

# %% [markdown]
# ### Items sold together

# %% [markdown]
# #### Keep only InvoiceNo & Description

# %%
df = df[['InvoiceNo', 'Description']]

# %%
df.head()
# Out:
#   InvoiceNo                      Description
# 0    536370        ALARM CLOCK BAKELIKE PINK
# 1    536370         ALARM CLOCK BAKELIKE RED
# 2    536370       ALARM CLOCK BAKELIKE GREEN
# 3    536370  PANDA AND BUNNIES STICKER SHEET
# 4    536370                  STARS GIFT TAPE

# %%
df = df.groupby('InvoiceNo').agg(','.join).reset_index()

# %%
df.head()
# Out:
#   InvoiceNo                                        Description
# 0    536370  ALARM CLOCK BAKELIKE PINK,ALARM CLOCK BAKELIKE...
# 1    536403                            HAND WARMER BIRD DESIGN
# 2    536527  SET OF 6 T-LIGHTS SANTA,ROTATING SILVER ANGELS...
# 3    536840  JAM MAKING SET PRINTED,JAM JAR WITH PINK LID,J...
# 4    536852  PICTURE DOMINOES,MINI JIGSAW SPACEBOY,MINI JIG...

# %%
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
from mlxtend.preprocessing import TransactionEncoder

# %%
item_list = [item.split(',') for item in df.Description]
item_list
# Out:
# [['ALARM CLOCK BAKELIKE PINK',
#   'ALARM CLOCK BAKELIKE RED',
#   'ALARM CLOCK BAKELIKE GREEN',
#   'PANDA AND BUNNIES STICKER SHEET',
#   'STARS GIFT TAPE',
#   'INFLATABLE POLITICAL GLOBE',
#   'VINTAGE HEADS AND TAILS CARD GAME',
#   'SET/2 RED RETROSPOT TEA TOWELS',
#   'ROUND SNACK BOXES SET OF4 WOODLAND',
#   'SPACEBOY LUNCH BOX',
#   'LUNCH BOX I LOVE LONDON',
#   'CIRCUS PARADE LUNCH BOX',
#   'CHARLOTTE BAG DOLLY GIRL DESIGN',
#   'RED TOADSTOOL LED NIGHT LIGHT',
#   'SET 2 TEA TOWELS I LOVE LONDON',
#   'VINTAGE SEASIDE JIGSAW PUZZLES',
#   'MINI JIGSAW CIRCUS PARADE',
#   'MINI JIGSAW SPACEBOY',
#   'MINI PAINT SET VINTAGE'],
#  ['HAND WARMER BIRD DESIGN'],
#  ['SET OF 6 T-LIGHTS SANTA',
#   'ROTATING SILVER ANGELS T-LIGHT HLDR',
#   'MULTI COLOUR SILVER T-LIGHT HOLDER',
#   '5 HOOK HANGER MAGIC TOADSTOOL',
#   '3 HOOK HANGER MAGIC GARDEN',
#   '5 HOOK HANGER RED MAGIC TOADSTOOL',
#   'ASSORTED COLOUR LIZARD SUCTION HOOK',
#   'JUMBO BAG WOODLAND ANIMALS',
#   'JUMBO BAG OWLS',
#   'HOT WATER BOTTLE BABUSHKA',
#   'HOMEMADE JAM SCENTED CANDLES',
#   "CHILDREN'S CIRCUS PARADE MUG",
#   'PACK 3 FIRE ENGINE/CAR PATCHES',
#   'PICTURE DOMINOES'],
#  ['JAM MAKING SET PRINTED',
#   'JAM JAR WITH PINK LID',
#   'JAM JAR WITH GREEN LID',
#   'SWEETHEART CAKESTAND 3 TIER',
#   '60 CAKE CASES VINTAGE CHRISTMAS',
#   '6 RIBBONS RUSTIC CHARM',
#   'CAKE STAND WHITE TWO TIER LACE',
#   'PACK OF 60 PINK PAISLEY CAKE CASES',
#   '60 TEATIME FAIRY CAKE CASES',
#   'PACK OF 72 RETROSPOT CAKE CASES'],
#  ['PICTURE DOMINOES',
#   'MINI JIGSAW SPACEBOY',
#   'MINI JIGSAW DOLLY GIRL',
#   'CHARLOTTE BAG DOLLY GIRL DESIGN',
#   'VINTAGE HEADS AND TAILS CARD GAME',
#   'POLKADOT RAIN HAT'],
#  ['FELTCRAFT 6 FLOWER FRIENDS',
#   '6 RIBBONS RUSTIC CHARM',
#   'WOODLAND  HEIGHT CHART STICKERS',
#   'CHILDS BREAKFAST SET CIRCUS PARADE',
#   'CHILDS BREAKFAST SET SPACEBOY',
#   'COFFEE MUG CAT + BIRD DESIGN',
#   'COFFEE MUG DOG + BALL DESIGN',
#   'BALLOONS  WRITING SET',
#   'DINOSAURS  WRITING SET'],
#  ['LUNCH BAG SUKI  DESIGN',
#   'LUNCH BAG PINK POLKADOT',
#   'LUNCH BAG  BLACK SKULL.',
#   'LUNCH BAG RED RETROSPOT',
#   'LUNCH BAG CARS BLUE'],
#  ['JUMBO BAG RED RETROSPOT'],
#  ['EDWARDIAN PARASOL BLACK',
#   'EDWARDIAN PARASOL PINK',
#   'EDWARDIAN PARASOL RED',
#   'RED  HARMONICA IN BOX',
#   'LUNCH BOX I LOVE LONDON',
#   'LUNCH BOX WITH CUTLERY RETROSPOT',
#   'SET OF SALT AND PEPPER TOADSTOOLS',
#   'TEA PARTY BIRTHDAY CARD',
#   'ASSORTED COLOUR MINI CASES',
#   'RED RETROSPOT MINI CASES',
#   'BIG DOUGHNUT FRIDGE MAGNETS',
#   "POPPY'S PLAYHOUSE KITCHEN",
#   'RIBBON REEL POLKADOTS',
#   'LUNCH BAG RED RETROSPOT',
#   'LUNCH BAG WOODLAND'],
#  ['WOODLAND PARTY BAG + STICKER SET',
#   'HAND WARMER OWL DESIGN',
#   '3 HOOK PHOTO SHELF ANTIQUE WHITE',
#   'IVORY GIANT GARDEN THERMOMETER',
#   'BLUE COAT RACK PARIS FASHION',
#   'HOT BATHS SOAP HOLDER',
#   'PENCIL CASE LIFE IS BEAUTIFUL',
#   'LARGE CHINESE STYLE SCISSOR'],
#  ['SET OF 20 KIDS COOKIE CUTTERS',
#   'RED RETROSPOT ROUND CAKE TINS',
#   'PACK OF 72 RETROSPOT CAKE CASES',
#   'PACK OF 60 PINK PAISLEY CAKE CASES',
#   'PACK OF 60 SPACEBOY CAKE CASES',
#   'PACK OF 60 DINOSAUR CAKE CASES',
#   'PACK OF 60 MUSHROOM CAKE CASES',
#   'PLASTERS IN TIN SPACEBOY',
#   'JUMBO BAG RED RETROSPOT',
#   'CHARLOTTE BAG SUKI DESIGN',
#   '72 SWEETHEART FAIRY CAKE CASES'],
#  ['HOT WATER BOTTLE BABUSHKA',
#   'BREAD BIN DINER STYLE RED',
#   'SET OF SALT AND PEPPER TOADSTOOLS',
#   'ROSE COTTAGE KEEPSAKE BOX',
#   'CLASSICAL ROSE SMALL VASE',
#   'RED RETROSPOT PURSE',
#   'POLKADOT RAIN HAT',
#   'RAIN PONCHO RETROSPOT',
#   'RED RETROSPOT MINI CASES',
#   'ASSORTED COLOUR MINI CASES',
#   'DECORATIVE CATS BATHROOM BOTTLE',
#   'SET/10 RED POLKADOT PARTY CANDLES',
#   'BASKET OF TOADSTOOLS',
#   'PARTY BUNTING',
#   'ALARM CLOCK BAKELIKE RED',
#   'ALARM CLOCK BAKELIKE GREEN',
#   'ALARM CLOCK BAKELIKE PINK',
#   'ALARM CLOCK BAKELIKE ORANGE',
#   '5 HOOK HANGER RED MAGIC TOADSTOOL',
#   'GUMBALL COAT RACK',
#   'FIVE HEART HANGING DECORATION',
#   'PINK  HONEYCOMB PAPER BALL',
#   'LUNCH BAG RED RETROSPOT',
#   'LUNCH BAG WOODLAND',
#   'LUNCH BAG CARS BLUE',
#   'STRAWBERRY LUNCH BOX WITH CUTLERY',
#   'ROUND SNACK BOXES SET OF4 WOODLAND',
#   'LUNCH BOX WITH CUTLERY RETROSPOT',
#   'CERAMIC STRAWBERRY TRINKET TRAY',
#   'RETROSPOT LARGE MILK JUG',
#   'RED RETROSPOT BUTTER DISH',
#   'REGENCY CAKESTAND 3 TIER',
#   'GREEN 3 PIECE POLKADOT CUTLERY SET',
#   'RED 3 PIECE RETROSPOT CUTLERY SET',
#   'BLUE 3 PIECE POLKADOT CUTLERY SET',
#   'CHERRY BLOSSOM  DECORATIVE FLASK',
#   'CHILDS BREAKFAST SET SPACEBOY',
#   'CHILDS BREAKFAST SET DOLLY GIRL',
#   'CHILDS BREAKFAST SET CIRCUS PARADE',
#   'RETROSPOT LAMP',
#   'PACK OF 12 RED RETROSPOT TISSUES',
#   'PACK OF 12 WOODLAND TISSUES',
#   'PACK OF 12 SUKI TISSUES',
#   'PACK OF 12 SPACEBOY TISSUES',
#   'PACK OF 12 CIRCUS PARADE TISSUES',
#   'BLUE GEISHA GIRL',
#   'GREEN GEISHA GIRL',
#   'PLASTERS IN TIN WOODLAND ANIMALS',
#   'PLASTERS IN TIN SPACEBOY',
#   'PARTY TIME PENCIL ERASERS',
#   'SET OF 6 3D KIT CARDS FOR KIDS',
#   'HAND WARMER RED RETROSPOT',
#   'DINOSAUR KEYRINGS ASSORTED',
#   'CERAMIC STRAWBERRY MONEY BOX',
#   'CERAMIC CHERRY CAKE MONEY BANK',
#   'PAPERWEIGHT CHILDHOOD MEMORIES',
#   'RED GINGHAM TEDDY BEAR',
#   "NURSE'S BAG SOFT TOY",
#   'TOOL BOX SOFT TOY',
#   'TRADITIONAL WOODEN CATCH CUP GAME',
#   'SET OF 6 SOLDIER SKITTLES',
#   'PINK PAINTED KASHMIRI CHAIR'],
#  ['BISCUIT TIN VINTAGE GREEN',
#   'BISCUIT TIN VINTAGE RED',
#   'JAM MAKING SET PRINTED',
#   'JAM JAR WITH PINK LID',
#   'JAM JAR WITH GREEN LID',
#   'PINK 3 PIECE POLKADOT CUTLERY SET',
#   'FRYING PAN RED RETROSPOT',
#   'FRYING PAN PINK POLKADOT',
#   'MEMO BOARD COTTAGE DESIGN',
#   'MEMO BOARD RETROSPOT  DESIGN',
#   'PINK HEART SHAPE EGG FRYING PAN',
#   'FRENCH ENAMEL UTENSIL HOLDER',
#   'SET OF 16 VINTAGE ROSE CUTLERY',
#   'IVORY KITCHEN SCALES',
#   'ROUND CAKE TIN VINTAGE GREEN',
#   'BREAD BIN DINER STYLE IVORY'],
#  ['DOORMAT RED RETROSPOT'],
#  ['GUMBALL MAGAZINE RACK',
#   'HAND WARMER OWL DESIGN',
#   'JAM MAKING SET WITH JARS',
#   'JAM MAKING SET PRINTED',
#   'JAM JAR WITH PINK LID',
#   'JAM JAR WITH GREEN LID',
#   '3 PIECE SPACEBOY COOKIE CUTTER SET',
#   "CHILDREN'S SPACEBOY MUG",
#   "CHILDREN'S CIRCUS PARADE MUG",
#   'SPACEBOY CHILDRENS EGG CUP',
#   'CIRCUS PARADE CHILDRENS EGG CUP',
#   'HAND WARMER BABUSHKA DESIGN',
#   'FELTCRAFT CUSHION OWL',
#   'SET OF 20 KIDS COOKIE CUTTERS',
#   'FELTCRAFT CHRISTMAS FAIRY',
#   'CHILDRENS APRON APPLES DESIGN',
#   'HOT WATER BOTTLE BABUSHKA',
#   'ROSE COTTAGE KEEPSAKE BOX',
#   'CARD MOTORBIKE SANTA',
#   'CARD CHRISTMAS VILLAGE',
#   'RED  HARMONICA IN BOX',
#   'BLUE HARMONICA IN BOX',
#   'RETROSPOT PARTY BAG + STICKER SET',
#   'DISCO BALL CHRISTMAS DECORATION',
#   'GLITTER CHRISTMAS TREE',
#   'ANGEL DECORATION PAINTED ZINC',
#   'ROCKING HORSE RED CHRISTMAS',
#   'ROCKING HORSE GREEN CHRISTMAS',
#   'WOODEN TREE CHRISTMAS SCANDINAVIAN',
#   'CHRISTMAS RETROSPOT ANGEL WOOD',
#   'SMALL PINK MAGIC CHRISTMAS TREE',
#   'SPACEBOY LUNCH BOX',
#   'ROUND SNACK BOXES SET OF4 WOODLAND',
#   'WOODLAND CHARLOTTE BAG',
#   'PLASTERS IN TIN CIRCUS PARADE',
#   'SET OF 2 TEA TOWELS APPLE AND PEARS',
#   'RED RETROSPOT MINI CASES',
#   'BIRD DECORATION RED RETROSPOT',
#   'RETROSPOT PADDED SEAT CUSHION',
#   '6 RIBBONS RUSTIC CHARM',
#   'SCANDINAVIAN REDS RIBBONS',
#   'BRIGHT BLUES RIBBONS',
#   'BABY BOOM RIBBONS',
#   'CHOCOLATE BOX RIBBONS',
#   'CHRISTMAS CRAFT TREE TOP ANGEL',
#   'CHRISTMAS CRAFT LITTLE FRIENDS',
#   'CHRISTMAS RETROSPOT HEART WOOD',
#   'CHRISTMAS RETROSPOT STAR WOOD',
#   'CHRISTMAS GINGHAM HEART',
#   'CHRISTMAS GINGHAM TREE',
#   'CHRISTMAS GINGHAM STAR',
#   'STAR WOODEN CHRISTMAS DECORATION',
#   'HEART WOODEN CHRISTMAS DECORATION',
#   'WOODEN HEART CHRISTMAS SCANDINAVIAN',
#   'WOODEN STAR CHRISTMAS SCANDINAVIAN',
#   'RED RETROSPOT CHARLOTTE BAG',
#   'REGENCY CAKESTAND 3 TIER',
#   'ROUND SNACK BOXES SET OF 4 FRUITS',
#   'CIRCUS PARADE LUNCH BOX',
#   'RIBBON REEL POLKADOTS',
#   'RIBBON REEL HEARTS DESIGN',
#   'RIBBON REEL LACE DESIGN',
#   'HAND WARMER BIRD DESIGN',
#   'GUMBALL COAT RACK',
#   '5 HOOK HANGER MAGIC TOADSTOOL',
#   '3 HOOK HANGER MAGIC GARDEN',
#   'HOOK',
#   ' 1 HANGER ',
#   'MAGIC GARDEN',
#   'SET/5 RED RETROSPOT LID GLASS BOWLS',
#   'CHILDS BREAKFAST SET CIRCUS PARADE'],
#  ['JUMBO BAG WOODLAND ANIMALS',
#   'WOODLAND CHARLOTTE BAG',
#   'PLASTERS IN TIN WOODLAND ANIMALS',
#   'PACK OF 12 WOODLAND TISSUES',
#   'JAM MAKING SET WITH JARS',
#   'JAM MAKING SET PRINTED',
#   'JAM JAR WITH PINK LID',
#   'JAM JAR WITH GREEN LID',
#   'PACK OF 12 PINK PAISLEY TISSUES',
#   'STARS GIFT TAPE',
#   'PLASTERS IN TIN VINTAGE PAISLEY',
#   'SMALL POPCORN HOLDER',
#   'PARTY PIZZA DISH GREEN POLKADOT',
#   'PARTY PIZZA DISH PINK POLKADOT',
#   'PARTY PIZZA DISH BLUE POLKADOT',
#   'FELTCRAFT 6 FLOWER FRIENDS',
#   'RED KITCHEN SCALES',
#   'IVORY KITCHEN SCALES',
#   'SCOTTIE DOG HOT WATER BOTTLE',
#   'FAWN BLUE HOT WATER BOTTLE',
#   'PINK FLOWER FABRIC PONY',
#   'SET/3 RED GINGHAM ROSE STORAGE BOX',
#   'PINK POLKADOT BOWL',
#   'PINK  POLKADOT PLATE',
#   'RED RETROSPOT SHOPPER BAG',
#   'JUMBO BAG PINK POLKADOT',
#   'JUMBO BAG RED RETROSPOT',
#   'RED RETROSPOT CUP',
#   'PINK  POLKADOT CUP'],
#  ['ENGLISH ROSE HOT WATER BOTTLE',
#   'SET 3 RETROSPOT TEA',
#   'COFFEE',
#   'SUGAR',
#   'ROUND SNACK BOXES SET OF4 WOODLAND',
#   'BLUE POLKADOT BOWL',
#   'BLUE POLKADOT CUP',
#   'RED RETROSPOT BOWL',
#   'RED RETROSPOT CUP',
#   'RED RETROSPOT PLATE',
#   'BLUE POLKADOT PLATE',
#   'GUMBALL COAT RACK',
#   'RIBBON REEL STRIPES DESIGN',
#   'ROUND SNACK BOXES SET OF 4 FRUITS',
#   'CHICK GREY HOT WATER BOTTLE'],
#  ['JAM MAKING SET PRINTED',
#   'SET/4 SKULL BADGES',
#   'ROUND SNACK BOXES SET OF4 WOODLAND',
#   'SET/10 BLUE POLKADOT PARTY CANDLES',
#   'SET/10 RED POLKADOT PARTY CANDLES',
#   'BLACK RECORD COVER FRAME',
#   'RECORD FRAME 7" SINGLE SIZE',
#   'ROBOT BIRTHDAY CARD',
#   'TEA PARTY BIRTHDAY CARD',
#   'FANCY FONT BIRTHDAY CARD',
#   '',
#   'BOOM BOX SPEAKER BOYS',
#   'RED RETROSPOT CUP',
#   'IVORY DINER WALL CLOCK',
#   'LUNCH BOX WITH CUTLERY RETROSPOT',
#   'STRAWBERRY LUNCH BOX WITH CUTLERY',
#   'SNOWSTORM PHOTO FRAME FRIDGE MAGNET',
#   'BIG DOUGHNUT FRIDGE MAGNETS',
#   'WOODLAND CHARLOTTE BAG',
#   'WOODLAND  STICKERS',
#   'PLASTERS IN TIN WOODLAND ANIMALS',
#   'PACK OF 72 RETROSPOT CAKE CASES',
#   'OFFICE MUG WARMER POLKADOT',
#   'OFFICE MUG WARMER PINK',
#   'COFFEE MUG CAT + BIRD DESIGN',
#   'COFFEE MUG DOG + BALL DESIGN',
#   'TABLECLOTH RED APPLES DESIGN',
#   'DOORMAT RESPECTABLE HOUSE',
#   'RED RETROSPOT CHILDRENS UMBRELLA',
#   'PINK POLKADOT CHILDRENS UMBRELLA',
#   'BOX OF 24 COCKTAIL PARASOLS',
#   'GUMBALL COAT RACK',
#   'METAL SIGN TAKE IT OR LEAVE IT',
#   'SET OF SALT AND PEPPER TOADSTOOLS',
#   'PACK OF 20 NAPKINS RED APPLES',
#   'TEA BAG PLATE RED RETROSPOT',
#   'LOVELY BONBON STICKER SHEET',
#   'CANDY SHOP  STICKER SHEET',
#   'SKULLS  WATER TRANSFER TATTOOS',
#   'SET OF 2 TEA TOWELS APPLE AND PEARS',
#   'RED TOADSTOOL LED NIGHT LIGHT'],
#  ['HOT WATER BOTTLE TEA AND SYMPATHY',
#   'RETROSPOT HEART HOT WATER BOTTLE',
#   'HOT WATER BOTTLE BABUSHKA',
#   'GREY HEART HOT WATER BOTTLE',
#   'SCOTTIE DOG HOT WATER BOTTLE',
#   'BIRD HOUSE HOT WATER BOTTLE',
#   'CLOTHES PEGS RETROSPOT PACK 24',
#   'FELTCRAFT PRINCESS CHARLOTTE DOLL',
#   'FELTCRAFT PRINCESS LOLA DOLL',
#   'FELTCRAFT DOLL MARIA',
#   'LUNCH BAG RED RETROSPOT',
#   'LUNCH BAG SUKI  DESIGN',
#   'LUNCH BAG SPACEBOY DESIGN',
#   '10 COLOUR SPACEBOY PEN',
#   "POPPY'S PLAYHOUSE BEDROOM",
#   "POPPY'S PLAYHOUSE KITCHEN",
#   "POPPY'S PLAYHOUSE BATHROOM",
#   'MAGIC DRAWING SLATE CIRCUS PARADE',
#   'DELUXE SEWING KIT'],
#  ['SET OF 16 VINTAGE PISTACHIO CUTLERY',
#   'SET OF 16 VINTAGE ROSE CUTLERY',
#   'BREAD BIN DINER STYLE RED',
#   'BREAD BIN DINER STYLE IVORY',
#   'TEA TIME OVEN GLOVE',
#   '3 HOOK HANGER MAGIC GARDEN',
#   'FRYING PAN RED RETROSPOT',
#   'FRYING PAN PINK POLKADOT',
#   'SET/2 RED RETROSPOT TEA TOWELS',
#   'MILK PAN RED RETROSPOT',
#   'MILK PAN PINK POLKADOT',
#   'RED TOADSTOOL LED NIGHT LIGHT',
#   'IVORY KITCHEN SCALES',
#   'KIDS RAIN MAC PINK',
#   'TOADSTOOL MONEY BOX',
#   'SET OF 6 STRAWBERRY CHOPSTICKS'],
#  ['RED GINGHAM ROSE JEWELLERY BOX',
#   'GUMBALL COAT RACK',
#   'RED KITCHEN SCALES',
#   'MINT KITCHEN SCALES',
#   'SCANDINAVIAN REDS RIBBONS',
#   '36 PENCILS TUBE RED RETROSPOT'],
#  ['WRAP I LOVE LONDON',
#   'VINTAGE CARAVAN GIFT WRAP',
#   'BLUE SCANDINAVIAN PAISLEY WRAP',
#   'PAPER CHAIN KIT VINTAGE CHRISTMAS',
#   "PAPER CHAIN KIT 50'S CHRISTMAS",
#   'MAKE YOUR OWN PLAYTIME CARD KIT',
#   'MAKE YOUR OWN MONSOON CARD KIT',
#   'FAIRY CAKE BIRTHDAY CANDLE SET',
#   'TEA TIME PARTY BUNTING',
#   'TRADITIONAL CHRISTMAS RIBBONS'],
#  ['BABUSHKA LIGHTS STRING OF 10',
#   'CHILDS BREAKFAST SET CIRCUS PARADE',
#   'SET 12 KIDS COLOUR  CHALK STICKS',
#   'VINTAGE HEADS AND TAILS CARD GAME',
#   '4 TRADITIONAL SPINNING TOPS',
#   'PLASTERS IN TIN CIRCUS PARADE',
#   'RETROSPOT CHILDRENS APRON',
#   'ROUND SNACK BOXES SET OF4 WOODLAND',
#   'ROUND SNACK BOXES SET OF 4 FRUITS'],
#  ['CHRISTMAS LIGHTS 10 VINTAGE BAUBLES',
#   '3 PIECE SPACEBOY COOKIE CUTTER SET',
#   "CHILDREN'S SPACEBOY MUG",
#   'PLASTERS IN TIN SPACEBOY',
#   'WOODLAND  STICKERS',
#   'WOODLAND PARTY BAG + STICKER SET',
#   'ROUND SNACK BOXES SET OF4 WOODLAND',
#   'ALARM CLOCK BAKELIKE IVORY',
#   'ALARM CLOCK BAKELIKE RED',
#   'ALARM CLOCK BAKELIKE CHOCOLATE',
#   'TEA FOR ONE POLKADOT',
#   'BROCADE RING PURSE',
#   'PACK OF 6 BIRDY GIFT TAGS'],
#  ['CHRISTMAS RETROSPOT ANGEL WOOD',
#   'CHARLOTTE BAG DOLLY GIRL DESIGN',
#   'FELT TOADSTOOL  SMALL',
#   'RED TOADSTOOL LED NIGHT LIGHT',
#   'SET 7 BABUSHKA NESTING BOXES',
#   'RED WOOLLY HOTTIE WHITE HEART.',
#   'FAWN BLUE HOT WATER BOTTLE',
#   'MEASURING TAPE BABUSHKA RED',
#   'CLOTHES PEGS RETROSPOT PACK 24',
#   'CHILDRENS DOLLY GIRL MUG',
#   'DOORMAT RED RETROSPOT',
#   'SET OF 2 ROUND TINS CAMEMBERT'],
#  ['RED RETROSPOT CAKE STAND', 'RECIPE BOX RETROSPOT'],
#  ['METAL 4 HOOK HANGER FRENCH CHATEAU',
#   '3 HOOK PHOTO SHELF ANTIQUE WHITE',
#   '12 PENCIL SMALL TUBE WOODLAND',
#   'FAWN BLUE HOT WATER BOTTLE',
#   'STRAWBERRY LUNCH BOX WITH CUTLERY',
#   'LUNCH BOX WITH CUTLERY RETROSPOT',
#   'HOLIDAY FUN LUDO',
#   'WOODEN FRAME ANTIQUE WHITE',
#   'BROCANTE COAT RACK',
#   'PINK PADDED MOBILE'],
#  ['WOODLAND PARTY BAG + STICKER SET',
#   'PACK OF 20 NAPKINS PANTRY DESIGN',
#   'PACK OF 20 NAPKINS RED APPLES',
#   'SET OF 20 VINTAGE CHRISTMAS NAPKINS',
#   'PINK CREAM FELT CRAFT TRINKET BOX',
#   'CUPCAKE LACE PAPER SET 6',
#   'PINK PARTY BAGS',
#   'BLUE PARTY BAGS',
#   'WRAP RED APPLES',
#   'TABLECLOTH RED APPLES DESIGN',
#   'SET OF 2 TEA TOWELS APPLE AND PEARS',
#   'OVEN MITT APPLES DESIGN',
#   'CHILDRENS APRON APPLES DESIGN',
#   'WRAP GREEN PEARS',
#   'CHILDS BREAKFAST SET CIRCUS PARADE',
#   'DOLLY GIRL LUNCH BOX',
#   "CHILDREN'S APRON DOLLY GIRL",
#   'RETROSPOT PARTY BAG + STICKER SET',
#   'PINK 3 PIECE POLKADOT CUTLERY SET',
#   'LUNCH BOX WITH CUTLERY RETROSPOT',
#   'STRAWBERRY LUNCH BOX WITH CUTLERY',
#   'EASTER TIN BUNNY BOUQUET',
#   '60 CAKE CASES DOLLY GIRL DESIGN',
#   '72 SWEETHEART FAIRY CAKE CASES',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES',
#   'RED RETROSPOT OVEN GLOVE',
#   'RED RETROSPOT CAKE STAND',
#   'SET OF 9 HEART SHAPED BALLOONS',
#   'SET OF 9 BLACK SKULL BALLOONS',
#   "CHILDREN'S SPACEBOY MUG",
#   "CHILDREN'S CIRCUS PARADE MUG",
#   'CHILDRENS DOLLY GIRL MUG',
#   'SPACEBOY CHILDRENS EGG CUP',
#   'CIRCUS PARADE CHILDRENS EGG CUP',
#   'DOLLY GIRL CHILDRENS EGG CUP',
#   'SET/10 RED POLKADOT PARTY CANDLES',
#   'SET/10 IVORY POLKADOT PARTY CANDLES',
#   'SET/10 BLUE POLKADOT PARTY CANDLES',
#   'SET/10 PINK POLKADOT PARTY CANDLES'],
#  ['RIBBON REEL MAKING SNOWMEN',
#   'RIBBON REEL SNOWY VILLAGE',
#   'EDWARDIAN PARASOL RED',
#   'EDWARDIAN PARASOL BLACK',
#   '6 RIBBONS RUSTIC CHARM',
#   'RED TOADSTOOL LED NIGHT LIGHT',
#   'VINTAGE HEADS AND TAILS CARD GAME',
#   '4 TRADITIONAL SPINNING TOPS',
#   'PLASTERS IN TIN SPACEBOY',
#   'PLASTERS IN TIN CIRCUS PARADE',
#   'JUMBO BAG PINK POLKADOT',
#   'JUMBO BAG SPACEBOY DESIGN',
#   'LUNCH BAG RED RETROSPOT',
#   'LUNCH BAG WOODLAND',
#   'LUNCH BAG SUKI  DESIGN',
#   'LUNCH BAG SPACEBOY DESIGN',
#   'STRAWBERRY LUNCH BOX WITH CUTLERY',
#   'SKULL LUNCH BOX WITH CUTLERY',
#   'JAM MAKING SET PRINTED',
#   'TOADSTOOL MONEY BOX',
#   'SET/3 DECOUPAGE STACKING TINS',
#   'ASSORTED COLOUR MINI CASES',
#   'RED RETROSPOT MINI CASES',
#   'PLASTERS IN TIN WOODLAND ANIMALS',
#   'BIG DOUGHNUT FRIDGE MAGNETS',
#   'SMALL POPCORN HOLDER',
#   'HAIRCLIPS FORTIES FABRIC ASSORTED',
#   'BIRD DECORATION RED RETROSPOT',
#   'SET OF 20 VINTAGE CHRISTMAS NAPKINS',
#   'METAL DECORATION NAUGHTY CHILDREN',
#   'INFLATABLE POLITICAL GLOBE',
#   'RIBBON REEL STRIPES DESIGN'],
#  ['CABIN BAG VINTAGE RETROSPOT',
#   'FOUR HOOK  WHITE LOVEBIRDS',
#   'BIRTHDAY PARTY CORDON BARRIER TAPE',
#   'DANISH ROSE PHOTO FRAME',
#   'LAVENDER SCENTED FABRIC HEART',
#   'BOX OF 24 COCKTAIL PARASOLS',
#   'PHOTO FRAME 3 CLASSIC HANGING',
#   'WHITE BAMBOO RIBS LAMPSHADE',
#   'CERAMIC STRAWBERRY CAKE MONEY BANK',
#   'STARS GIFT TAPE',
#   'HEARTS GIFT TAPE',
#   'EMERGENCY FIRST AID TIN',
#   'PARTY BUNTING',
#   'WHITE HANGING HEART T-LIGHT HOLDER',
#   'SET/3 RED GINGHAM ROSE STORAGE BOX',
#   'BLUE COAT RACK PARIS FASHION',
#   'RED COAT RACK PARIS FASHION',
#   'YELLOW COAT RACK PARIS FASHION',
#   'CIRCUS PARADE LUNCH BOX',
#   'SET OF 2 TINS VINTAGE BATHROOM',
#   'SET OF 20 VINTAGE CHRISTMAS NAPKINS',
#   'LOVE HEART NAPKIN BOX',
#   'ALARM CLOCK BAKELIKE GREEN',
#   'GLITTER BUTTERFLY CLIPS',
#   'GLITTER HANGING BUTTERFLY STRING',
#   'CUPID DESIGN SCENTED CANDLES',
#   'SET OF 2 TINS JARDIN DE PROVENCE',
#   'WOODEN HEART CHRISTMAS SCANDINAVIAN',
#   'WOODEN TREE CHRISTMAS SCANDINAVIAN',
#   'ROCKING HORSE RED CHRISTMAS',
#   'ROCKING HORSE GREEN CHRISTMAS',
#   'STAR DECORATION PAINTED ZINC',
#   'HEART DECORATION PAINTED ZINC',
#   'STAR WOODEN CHRISTMAS DECORATION',
#   'FOLKART ZINC STAR CHRISTMAS DEC',
#   'FOLKART ZINC HEART CHRISTMAS DEC',
#   'HEART OF WICKER SMALL',
#   'WICKER WREATH SMALL',
#   'RED RETROSPOT ROUND CAKE TINS',
#   'SET OF 6 T-LIGHTS SANTA'],
#  ['SET OF 72 RETROSPOT PAPER  DOILIES',
#   'PACK OF 72 RETROSPOT CAKE CASES',
#   'WOODLAND DESIGN  COTTON TOTE BAG',
#   'BIG DOUGHNUT FRIDGE MAGNETS',
#   'RECYCLED PENCIL WITH RABBIT ERASER',
#   'RED TOADSTOOL LED NIGHT LIGHT',
#   'RAIN PONCHO RETROSPOT',
#   'STRAWBERRY CERAMIC TRINKET BOX',
#   '6 RIBBONS RUSTIC CHARM',
#   'ROUND SNACK BOXES SET OF4 WOODLAND',
#   'REGENCY CAKESTAND 3 TIER',
#   'TV DINNER TRAY DOLLY GIRL',
#   'PENCIL CASE LIFE IS BEAUTIFUL',
#   'PLASTERS IN TIN WOODLAND ANIMALS',
#   'PLASTERS IN TIN CIRCUS PARADE',
#   'PLASTERS IN TIN STRONGMAN',
#   'CERAMIC STRAWBERRY CAKE MONEY BANK',
#   'CERAMIC CHERRY CAKE MONEY BANK',
#   'STRAWBERRY FAIRY CAKE TEAPOT',
#   'PACK OF 12 TRADITIONAL CRAYONS',
#   'PACK OF 20 NAPKINS PANTRY DESIGN',
#   'PACK OF 20 NAPKINS RED APPLES',
#   'OVEN MITT APPLES DESIGN',
#   'SET 7 BABUSHKA NESTING BOXES',
#   'BREAD BIN DINER STYLE PINK',
#   'ALARM CLOCK BAKELIKE PINK',
#   'HEN HOUSE W CHICK STANDING',
#   'ROSE COTTAGE KEEPSAKE BOX',
#   'PACK OF 12 COLOURED PENCILS',
#   'FUNKY DIVA PEN',
#   'CHEST OF DRAWERS GINGHAM HEART',
#   'TRADITIONAL KNITTING NANCY',
#   'BAKING MOULD CHOCOLATE CUPCAKES',
#   "POPPY'S PLAYHOUSE LIVINGROOM",
#   "POPPY'S PLAYHOUSE BEDROOM",
#   "POPPY'S PLAYHOUSE KITCHEN",
#   'LIPSTICK PEN RED',
#   'SET OF 3 NOTEBOOKS IN PARCEL',
#   'PICTURE DOMINOES',
#   'RED KITCHEN SCALES',
#   'SWEETHEART CERAMIC TRINKET BOX',
#   'SAVE THE PLANET COTTON TOTE BAG',
#   'SET OF 6 T-LIGHTS EASTER CHICKS',
#   'ASSORTED EASTER DECORATIONS  BELLS',
#   'EASTER TIN BUNNY BOUQUET',
#   'BAKING MOULD EASTER EGG WHITE CHOC'],
#  ['ASSORTED COLOUR BIRD ORNAMENT',
#   'INFLATABLE POLITICAL GLOBE',
#   'LUNCH BAG RED RETROSPOT',
#   'PICTURE DOMINOES',
#   'WOODEN BOX OF DOMINOES',
#   'TRADITIONAL MODELLING CLAY',
#   'RED  HARMONICA IN BOX',
#   'BLUE HARMONICA IN BOX',
#   'CLOTHES PEGS RETROSPOT PACK 24',
#   'RED RETROSPOT TRADITIONAL TEAPOT',
#   'RETROSPOT LARGE MILK JUG',
#   'ELEPHANT',
#   ' BIRTHDAY CARD',
#   '',
#   'RED RETROSPOT CHILDRENS UMBRELLA',
#   'DOORMAT UNION FLAG',
#   'DOORMAT RED RETROSPOT'],
#  ['ROTATING SILVER ANGELS T-LIGHT HLDR',
#   'HOME SWEET HOME METAL SIGN',
#   'FANCY FONT BIRTHDAY CARD',
#   '',
#   'EMPIRE BIRTHDAY CARD',
#   'BIRTHDAY CARD',
#   ' RETRO SPOT',
#   'GIN & TONIC DIET GREETING CARD',
#   'SWALLOWS GREETING CARD',
#   '4 TRADITIONAL SPINNING TOPS',
#   'WORLD WAR 2 GLIDERS ASSTD DESIGNS',
#   'PLASTERS IN TIN SKULLS',
#   'PLASTERS IN TIN CIRCUS PARADE',
#   'REGENCY CAKESTAND 3 TIER',
#   'WELCOME  WOODEN BLOCK LETTERS',
#   'HOME BUILDING BLOCK WORD',
#   'LOVE BUILDING BLOCK WORD',
#   'CLASSIC METAL BIRDCAGE PLANT HOLDER',
#   'WHITE SKULL HOT WATER BOTTLE',
#   'RED WOOLLY HOTTIE WHITE HEART.',
#   'HOT WATER BOTTLE BABUSHKA'],
#  ['CHILDS BREAKFAST SET CIRCUS PARADE', 'GLASS  BEURRE DISH'],
#  ['VINTAGE BILLBOARD TEA MUG',
#   'BALLOONS  WRITING SET',
#   'CIRCUS PARADE LUNCH BOX',
#   'FUNKY WASHING UP GLOVES ASSORTED',
#   'ASSTD DESIGN 3D PAPER STICKERS',
#   'KEEP OUT BOYS DOOR HANGER',
#   'NINJA RABBIT PINK',
#   'SPACE OWL',
#   'SET OF 9 HEART SHAPED BALLOONS',
#   '12 PENCILS TALL TUBE RED RETROSPOT',
#   'WICKER WREATH LARGE',
#   'HEART OF WICKER SMALL',
#   'S/6 SEW ON CROCHET FLOWERS',
#   'SPACE CADET RED',
#   'BLACK CANDELABRA T-LIGHT HOLDER',
#   'KEY FOB ',
#   ' BACK DOOR',
#   'KEY FOB ',
#   ' SHED',
#   'ETCHED GLASS COASTER',
#   '6 RIBBONS EMPIRE',
#   'SCANDINAVIAN REDS RIBBONS',
#   'URBAN BLACK RIBBONS',
#   'CHRISTMAS METAL TAGS ASSORTED',
#   'SET OF 4 NAPKIN CHARMS CROWNS',
#   'SET OF 4 NAPKIN CHARMS CUTLERY',
#   'PACK OF 12 PINK POLKADOT TISSUES',
#   'PACK OF 12 RED RETROSPOT TISSUES',
#   'PACK OF 12 HEARTS DESIGN TISSUES',
#   'PACK OF 12 WOODLAND TISSUES',
#   'PACK OF 12 SUKI TISSUES',
#   'SET OF 3 NOTEBOOKS IN PARCEL',
#   'PLACE SETTING WHITE HEART',
#   'SET OF 3 HEART COOKIE CUTTERS',
#   'RIBBON REEL CHRISTMAS SOCK BAUBLE',
#   'RIBBON REEL HEARTS DESIGN',
#   'RIBBON REEL LACE DESIGN',
#   'RIBBON REEL STRIPES DESIGN',
#   'STRAWBERRY BATH SPONGE',
#   'SANDWICH BATH SPONGE',
#   'SET OF 20 VINTAGE CHRISTMAS NAPKINS',
#   'PAPER CHAIN KIT VINTAGE CHRISTMAS',
#   'MAGNETS PACK OF 4 CHILDHOOD MEMORY',
#   'METAL SIGN TAKE IT OR LEAVE IT',
#   'MAGNETS PACK OF 4 VINTAGE LABELS',
#   'MAGNETS PACK OF 4 VINTAGE COLLAGE',
#   'ANTIQUE ALL GLASS CANDLESTICK',
#   'SET OF 3 CAKE TINS PANTRY DESIGN',
#   'AIRLINE BAG VINTAGE JET SET RED',
#   'AIRLINE BAG VINTAGE JET SET BROWN',
#   'WOODLAND DESIGN  COTTON TOTE BAG',
#   'LETS GO SHOPPING COTTON TOTE BAG',
#   'RED RETROSPOT TISSUE BOX',
#   'CAROUSEL DESIGN WASHBAG',
#   'SCOTTIES DESIGN WASHBAG',
#   'BLUE TEA TOWEL CLASSIC DESIGN',
#   'RED TEA TOWEL CLASSIC DESIGN',
#   'MOTORING TISSUE BOX',
#   'ANTIQUE GLASS PEDESTAL BOWL',
#   'PHOTO CUBE',
#   'ANTIQUE SILVER TEA GLASS ENGRAVED',
#   'ZINC METAL HEART DECORATION',
#   'AGED GLASS SILVER T-LIGHT HOLDER',
#   'GREY FLORAL FELTCRAFT SHOULDER BAG',
#   'FELTCRAFT PRINCESS CHARLOTTE DOLL',
#   'FELTCRAFT CHRISTMAS FAIRY',
#   'PINK CREAM FELT CRAFT TRINKET BOX',
#   'SQUARECUSHION COVER PINK UNION FLAG',
#   'REX CASH+CARRY JUMBO SHOPPER'],
#  ['LUNCH BAG DOLLY GIRL DESIGN'],
#  ['VINTAGE BEAD PINK SCARF',
#   'FAWN BLUE HOT WATER BOTTLE',
#   'EDWARDIAN PARASOL RED',
#   'RED RETROSPOT UMBRELLA'],
#  ['JUMBO  BAG BAROQUE BLACK WHITE',
#   'JUMBO BAG RED RETROSPOT',
#   'JUMBO BAG PINK POLKADOT',
#   'JUMBO BAG SCANDINAVIAN PAISLEY',
#   'JUMBO BAG WOODLAND ANIMALS',
#   'PARTY FOOD SHOPPER BAG',
#   'STRAWBERRY SHOPPER BAG',
#   'RED RETROSPOT SHOPPER BAG',
#   'SKULL SHOULDER BAG',
#   'SUKI  SHOULDER BAG'],
#  ['ANTIQUE GLASS PEDESTAL BOWL',
#   'VINTAGE CREAM CAT FOOD CONTAINER',
#   'LARGE CAKE STAND HANGING HEARTS',
#   'REGENCY CAKESTAND 3 TIER',
#   'SET OF 6 SOLDIER SKITTLES',
#   'VICTORIAN  METAL POSTCARD SPRING',
#   'EASTER TIN BUCKET',
#   'SILK PURSE BABUSHKA RED',
#   'MIRROR CORNICE',
#   'RECIPE BOX PANTRY YELLOW DESIGN'],
#  ['RED COAT RACK PARIS FASHION',
#   'FRIDGE MAGNETS LES ENFANTS ASSORTED',
#   'HOMEMADE JAM SCENTED CANDLES',
#   'JAM JAR WITH PINK LID',
#   'JAM MAKING SET PRINTED',
#   '3 PIECE SPACEBOY COOKIE CUTTER SET',
#   'GINGERBREAD MAN COOKIE CUTTER',
#   'MAKE YOUR OWN FLOWERPOWER CARD KIT',
#   'MAKE YOUR OWN MONSOON CARD KIT',
#   'SAVE THE PLANET COTTON TOTE BAG',
#   'WOODLAND DESIGN  COTTON TOTE BAG',
#   'BIG DOUGHNUT FRIDGE MAGNETS',
#   'RED TOADSTOOL LED NIGHT LIGHT',
#   'REGENCY CAKESTAND 3 TIER',
#   'ROUND SNACK BOXES SET OF4 WOODLAND',
#   'TV DINNER TRAY DOLLY GIRL',
#   'PENCIL CASE LIFE IS BEAUTIFUL',
#   'PLASTERS IN TIN WOODLAND ANIMALS',
#   'PLASTERS IN TIN STRONGMAN',
#   'PLASTERS IN TIN CIRCUS PARADE',
#   'RED KITCHEN SCALES',
#   'STRAWBERRY FAIRY CAKE TEAPOT',
#   'BREAD BIN DINER STYLE PINK',
#   'ALARM CLOCK BAKELIKE PINK',
#   'ROSE COTTAGE KEEPSAKE BOX',
#   'SET 7 BABUSHKA NESTING BOXES'],
#  ['SET OF 3 CAKE TINS PANTRY DESIGN'],
#  ['RETROSPOT HEART HOT WATER BOTTLE',
#   'VICTORIAN SEWING BOX LARGE',
#   'PARTY PIZZA DISH RED RETROSPOT',
#   'CABIN BAG VINTAGE RETROSPOT',
#   'CABIN BAG VINTAGE PAISLEY',
#   'SET/10 PINK POLKADOT PARTY CANDLES',
#   'DOORMAT RED RETROSPOT'],
#  ['SET OF 6 SPICE TINS PANTRY DESIGN',
#   '5 HOOK HANGER RED MAGIC TOADSTOOL',
#   'SET OF SALT AND PEPPER TOADSTOOLS',
#   'KIDS RAIN MAC PINK',
#   'RED KITCHEN SCALES',
#   'SALLE DE BAIN HOOK',
#   'MEASURING TAPE BABUSHKA PINK',
#   'ROSE COTTAGE KEEPSAKE BOX',
#   'MEMO BOARD COTTAGE DESIGN',
#   'BLACK KITCHEN SCALES'],
#  ['JAM MAKING SET WITH JARS',
#   'JAM MAKING SET PRINTED',
#   "CHILDREN'S CIRCUS PARADE MUG",
#   'CUTE CATS TAPE',
#   '6 RIBBONS SHIMMERING PINKS',
#   'LOCAL CAFE MUG',
#   'HAND WARMER BABUSHKA DESIGN',
#   'CHARLOTTE BAG SUKI DESIGN',
#   'PINK FELT EASTER RABBIT GARLAND',
#   'TRAVEL SEWING KIT',
#   'DELUXE SEWING KIT',
#   '6 RIBBONS RUSTIC CHARM',
#   'REGENCY CAKESTAND 3 TIER',
#   '12 PENCIL SMALL TUBE WOODLAND',
#   'SET 7 BABUSHKA NESTING BOXES',
#   'HOT WATER BOTTLE BABUSHKA',
#   'CHILDS BREAKFAST SET CIRCUS PARADE'],
#  ['FELT FARM ANIMAL WHITE BUNNY',
#   'MINI PAINT SET VINTAGE',
#   'FELT TOADSTOOL  SMALL',
#   'BLUE HARMONICA IN BOX',
#   'RETROSPOT PARTY BAG + STICKER SET'],
#  ['SET OF 3 CAKE TINS PANTRY DESIGN',
#   'SET OF 3 CAKE TINS SKETCHBOOK',
#   'SET OF 6 SPICE TINS PANTRY DESIGN',
#   'SET OF 6 HERB TINS SKETCHBOOK',
#   'RED RETROSPOT TAPE',
#   'PARTY PIZZA DISH RED RETROSPOT',
#   'PARTY PIZZA DISH PINK POLKADOT',
#   'PARTY PIZZA DISH BLUE POLKADOT',
#   'PARTY PIZZA DISH GREEN POLKADOT',
#   '12 PENCIL SMALL TUBE WOODLAND',
#   'RECYCLING BAG RETROSPOT',
#   'RED RETROSPOT CHARLOTTE BAG',
#   'CAKES AND BOWS GIFT  TAPE',
#   'STARS GIFT TAPE'],
#  ['RED TOADSTOOL LED NIGHT LIGHT',
#   'ROUND SNACK BOXES SET OF4 WOODLAND',
#   'RED RETROSPOT MINI CASES',
#   'TOADSTOOL MONEY BOX'],
#  ['HAND WARMER BABUSHKA DESIGN',
#   'PINK STITCHED WALL CLOCK',
#   'MAGIC SHEEP WOOL GROWING FROM PAPER',
#   'LOVE HEART POCKET WARMER',
#   'FLYING PIG WATERING CAN',
#   'BLACK STITCHED WALL CLOCK',
#   'WHITE STITCHED WALL CLOCK',
#   'HOT WATER BOTTLE BABUSHKA',
#   'FAWN BLUE HOT WATER BOTTLE',
#   'GREY HEART HOT WATER BOTTLE',
#   'ENGLISH ROSE HOT WATER BOTTLE',
#   'FELT TOADSTOOL LARGE',
#   'FELT TOADSTOOL  SMALL',
#   'ROUND SNACK BOXES SET OF4 WOODLAND',
#   'ROUND SNACK BOXES SET OF 4 FRUITS',
#   'LUNCH BOX I LOVE LONDON',
#   'WOODLAND STORAGE BOX SMALL',
#   'WOODLAND STORAGE BOX LARGE',
#   'RED TOADSTOOL LED NIGHT LIGHT',
#   'JUMBO BAG WOODLAND ANIMALS',
#   'STRAWBERRY CERAMIC TRINKET BOX',
#   'SWEETHEART CERAMIC TRINKET BOX',
#   'SET OF SALT AND PEPPER TOADSTOOLS',
#   'REGENCY CAKESTAND 3 TIER',
#   'CAKE STAND LOVEBIRD 2 TIER PINK',
#   'CAKE STAND 3 TIER MAGIC GARDEN',
#   'CAKE PLATE LOVEBIRD PINK',
#   'CAKE PLATE LOVEBIRD WHITE',
#   'SAVE THE PLANET MUG'],
#  ['DOLLY GIRL LUNCH BOX',
#   'RED RETROSPOT TAPE',
#   'HEARTS GIFT TAPE',
#   'PAPERWEIGHT CHILDHOOD MEMORIES',
#   'CABIN BAG VINTAGE RETROSPOT',
#   'POLKADOT PEN',
#   'SMALL RED BABUSHKA NOTEBOOK',
#   'SMALL PURPLE BABUSHKA NOTEBOOK',
#   'RECIPE BOX RETROSPOT',
#   'RECIPE BOX PANTRY YELLOW DESIGN',
#   "PINK B'FLY C/COVER W BOBBLES",
#   'POLYESTER FILLER PAD 30CMx30CM',
#   'SPACEBOY LUNCH BOX',
#   'CHARLOTTE BAG SUKI DESIGN',
#   'CHARLOTTE BAG PINK POLKADOT',
#   'WOODLAND CHARLOTTE BAG',
#   'RED RETROSPOT CHARLOTTE BAG',
#   'VICTORIAN SEWING BOX LARGE'],
#  ['RED RETROSPOT TAPE',
#   'CUTE CATS TAPE',
#   'CAKES AND BOWS GIFT  TAPE',
#   'METAL SIGN HER DINNER IS SERVED',
#   'WALL TIDY RETROSPOT',
#   'MAGNETS PACK OF 4 RETRO PHOTO',
#   'METAL SIGN',
#   'CUPCAKE SINGLE HOOK',
#   'METAL SIGN CUPCAKE SINGLE HOOK',
#   'SET OF 4 FAIRY CAKE PLACEMATS',
#   'SWEETHEART CERAMIC TRINKET BOX',
#   'STRAWBERRY CERAMIC TRINKET BOX',
#   'PINK DOUGHNUT TRINKET POT',
#   'CERAMIC CHERRY CAKE MONEY BANK',
#   'CERAMIC CAKE DESIGN SPOTTED MUG',
#   'TEA TIME KITCHEN APRON',
#   'TEA TIME TABLE CLOTH',
#   'DOORMAT FAIRY CAKE',
#   'SET/5 RED RETROSPOT LID GLASS BOWLS',
#   'SET/2 RED RETROSPOT TEA TOWELS',
#   'RED RETROSPOT TRADITIONAL TEAPOT',
#   'BEWARE OF THE CAT METAL SIGN',
#   'PLASTERS IN TIN WOODLAND ANIMALS',
#   'RED TOADSTOOL LED NIGHT LIGHT'],
#  ['PACK OF 12 WOODLAND TISSUES',
#   'PACK OF 12 PINK POLKADOT TISSUES',
#   'SET OF 3 CAKE TINS PANTRY DESIGN',
#   'JUMBO STORAGE BAG SUKI',
#   'PACK OF 20 SPACEBOY NAPKINS',
#   'FUNKY WASHING UP GLOVES ASSORTED',
#   'RED RETROSPOT BIG BOWL',
#   'JAM MAKING SET WITH JARS',
#   'CHARLOTTE BAG SUKI DESIGN',
#   'SET/10 IVORY POLKADOT PARTY CANDLES',
#   'PINK PARTY BAGS',
#   'WOODLAND PARTY BAG + STICKER SET',
#   'RETROSPOT PARTY BAG + STICKER SET',
#   '200 RED + WHITE BENDY STRAWS',
#   'PENCIL CASE LIFE IS BEAUTIFUL'],
#  ['RED TOADSTOOL LED NIGHT LIGHT',
#   'FAIRY TALE COTTAGE NIGHTLIGHT',
#   'ASS COLOUR GLOWING TIARAS',
#   'PINK HEART SHAPE EGG FRYING PAN',
#   'TOAST ITS - I LOVE YOU',
#   'LUNCH BAG WOODLAND',
#   'WOODLAND PARTY BAG + STICKER SET',
#   'RETROSPOT PARTY BAG + STICKER SET',
#   'RED RETROSPOT CHILDRENS UMBRELLA',
#   'PINK POLKADOT CHILDRENS UMBRELLA',
#   'EDWARDIAN PARASOL NATURAL',
#   'EDWARDIAN PARASOL PINK',
#   'RED DRAGONFLY HELICOPTER',
#   'HAND WARMER BABUSHKA DESIGN'],
#  ['PINK 3 PIECE POLKADOT CUTLERY SET',
#   'SET OF 2 TEA TOWELS APPLE AND PEARS',
#   'RED TOADSTOOL LED NIGHT LIGHT',
#   'CIRCUS PARADE CHILDRENS EGG CUP',
#   'GINGERBREAD MAN COOKIE CUTTER',
#   'LONDON BUS COFFEE MUG',
#   "CHILDREN'S CIRCUS PARADE MUG",
#   'BOOM BOX SPEAKER GIRLS',
#   'CABIN BAG VINTAGE RETROSPOT',
#   'SET/4 SKULL BADGES',
#   'CHARLOTTE BAG PINK POLKADOT',
#   'BLACK RECORD COVER FRAME',
#   'RECORD FRAME 7" SINGLE SIZE',
#   'SPACEBOY BIRTHDAY CARD',
#   'FANCY FONT BIRTHDAY CARD',
#   '',
#   'JAM MAKING SET PRINTED',
#   'BLUE POLKADOT CUP',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'PACK OF 6 SKULL PAPER CUPS',
#   'DOORMAT UNION FLAG',
#   'PLASTERS IN TIN STRONGMAN',
#   'PLASTERS IN TIN CIRCUS PARADE',
#   'PLASTERS IN TIN WOODLAND ANIMALS',
#   'NO SINGING METAL SIGN',
#   'METAL SIGN TAKE IT OR LEAVE IT',
#   'SMALL POPCORN HOLDER',
#   'LARGE POPCORN HOLDER',
#   'FIRST CLASS PASSPORT COVER',
#   'UNION JACK FLAG PASSPORT COVER',
#   'PINK UNION JACK  PASSPORT COVER',
#   'SET OF SALT AND PEPPER TOADSTOOLS',
#   'STARS GIFT TAPE',
#   'TRAVEL SEWING KIT',
#   'SET/20 RED RETROSPOT PAPER NAPKINS',
#   'LUNCH BOX WITH CUTLERY RETROSPOT',
#   'STRAWBERRY LUNCH BOX WITH CUTLERY',
#   'BIG DOUGHNUT FRIDGE MAGNETS',
#   'SNOWSTORM PHOTO FRAME FRIDGE MAGNET',
#   'RED RETROSPOT MINI CASES',
#   'PACK OF 72 SKULL CAKE CASES',
#   'PACK OF 60 MUSHROOM CAKE CASES',
#   'OFFICE MUG WARMER CHOC+BLUE',
#   'OFFICE MUG WARMER POLKADOT',
#   'COFFEE MUG PEARS  DESIGN',
#   'COFFEE MUG APPLES DESIGN',
#   'DOORMAT RESPECTABLE HOUSE'],
#  ['JAM MAKING SET PRINTED',
#   'JAM JAR WITH GREEN LID',
#   'JAM JAR WITH PINK LID',
#   'BREAD BIN DINER STYLE MINT',
#   'BREAD BIN DINER STYLE IVORY',
#   'IVORY KITCHEN SCALES',
#   'MINT KITCHEN SCALES',
#   'PENCIL CASE LIFE IS BEAUTIFUL',
#   'WOODLAND  STICKERS',
#   'SOAP DISH BROCANTE',
#   'TRAVEL SEWING KIT'],
#  ['DOORMAT RED RETROSPOT',
#   'PAPERWEIGHT CHILDHOOD MEMORIES',
#   'MAGNETS PACK OF 4 RETRO PHOTO',
#   'IVORY LOVE BIRD CANDLE',
#   'PINK LOVE BIRD CANDLE',
#   'S/4 VALENTINE DECOUPAGE HEART BOX',
#   'STRAWBERRY CHARLOTTE BAG',
#   'CHARLOTTE BAG DOLLY GIRL DESIGN',
#   'VICTORIAN  METAL POSTCARD SPRING',
#   'BOUDOIR SQUARE TISSUE BOX',
#   'LARGE RED RETROSPOT WINDMILL',
#   'EASTER TIN BUNNY BOUQUET',
#   'SET/3 POLKADOT STACKING TINS',
#   'ASSORTED COLOUR BIRD ORNAMENT',
#   'SET/6 PINK BIRD T-LIGHT CANDLES'],
#  ['CARRIAGE'],
#  ['BAKING MOULD EASTER EGG MILK CHOC',
#   'BAKING MOULD EASTER EGG WHITE CHOC',
#   'CLOTHES PEGS RETROSPOT PACK 24'],
#  ['PACK OF 72 RETROSPOT CAKE CASES',
#   'EASTER TIN KEEPSAKE',
#   'PINK METAL CHICKEN HEART',
#   'YELLOW METAL CHICKEN HEART',
#   'EASTER TIN BUNNY BOUQUET',
#   'ASSORTED EASTER DECORATIONS  BELLS',
#   'SUKI  SHOULDER BAG',
#   'LUNCH BAG SUKI  DESIGN',
#   'PACK OF 72 SKULL CAKE CASES',
#   'SKULL LUNCH BOX WITH CUTLERY',
#   'JUMBO STORAGE BAG SKULLS',
#   'PACK OF 60 SPACEBOY CAKE CASES',
#   'SPACEBOY TV DINNER TRAY',
#   'TV DINNER TRAY DOLLY GIRL',
#   'TV DINNER TRAY AIR HOSTESS',
#   'PLASTERS IN TIN STRONGMAN',
#   'FAWN BLUE HOT WATER BOTTLE',
#   'FELTCRAFT CUSHION RABBIT',
#   'FELTCRAFT CUSHION BUTTERFLY',
#   'FELTCRAFT DOLL MOLLY',
#   'FELTCRAFT PRINCESS LOLA DOLL',
#   'FELTCRAFT PRINCESS OLIVIA DOLL',
#   'FELTCRAFT PRINCESS CHARLOTTE DOLL',
#   'RED TOADSTOOL LED NIGHT LIGHT',
#   'LUNCH BOX WITH CUTLERY RETROSPOT',
#   'HAND WARMER BABUSHKA DESIGN',
#   'CLOTHES PEGS RETROSPOT PACK 24',
#   'SWISS ROLL TOWEL',
#   ' PINK  SPOTS',
#   'STRAWBERRY HONEYCOMB  GARLAND',
#   'DOLLY HONEYCOMB GARLAND',
#   'FELT FARM ANIMAL RABBIT',
#   'PARTY PIZZA DISH RED RETROSPOT',
#   'WALL TIDY RETROSPOT',
#   'PARTY PIZZA DISH PINK POLKADOT',
#   'PARTY PIZZA DISH GREEN POLKADOT',
#   'PARTY PIZZA DISH BLUE POLKADOT',
#   'MAGNETS PACK OF 4 RETRO PHOTO',
#   'HAND TOWEL PALE BLUE W FLOWERS',
#   'HAND TOWEL PINK FLOWER AND DAISY',
#   'LA PALMIERA TILE COASTER',
#   'CHILDRENS DOLLY GIRL MUG',
#   'GREEN 3 PIECE POLKADOT CUTLERY SET',
#   'RED 3 PIECE RETROSPOT CUTLERY SET',
#   'BLUE 3 PIECE POLKADOT CUTLERY SET',
#   'PINK 3 PIECE POLKADOT CUTLERY SET',
#   'RED RETROSPOT MINI CASES',
#   'ROUND SNACK BOXES SET OF4 WOODLAND',
#   'SPACEBOY LUNCH BOX',
#   'LUNCH BAG SPACEBOY DESIGN',
#   'WOODLAND CHARLOTTE BAG',
#   'LUNCH BAG WOODLAND',
#   'RED SPOTTY BISCUIT TIN',
#   'FELTCRAFT CUSHION OWL',
#   'CHARLOTTE BAG SUKI DESIGN'],
#  ['METAL SIGN CUPCAKE SINGLE HOOK',
#   'METAL SIGN',
#   'CUPCAKE SINGLE HOOK',
#   'CAKE PLATE LOVEBIRD PINK',
#   'CAKE PLATE LOVEBIRD WHITE'],
#  ['SET/10 RED POLKADOT PARTY CANDLES',
#   'SET/10 PINK POLKADOT PARTY CANDLES',
#   'SET/10 BLUE POLKADOT PARTY CANDLES',
#   'SET 6 FOOTBALL CELEBRATION CANDLES',
#   'SET OF 6 GIRLS CELEBRATION CANDLES',
#   'SET/10 IVORY POLKADOT PARTY CANDLES',
#   'SET 12 KIDS COLOUR  CHALK STICKS',
#   'MINI JIGSAW DOLLY GIRL',
#   'MINI JIGSAW SPACEBOY',
#   'MINI JIGSAW CIRCUS PARADE',
#   'MINI JIGSAW DINOSAUR',
#   'BAG 125g SWIRLY MARBLES',
#   '12 PENCIL SMALL TUBE WOODLAND',
#   '12 PENCILS SMALL TUBE SKULL',
#   '12 PENCILS SMALL TUBE RED RETROSPOT',
#   'POPART WOODEN PENCILS ASST',
#   'PACK OF 12 TRADITIONAL CRAYONS',
#   'BOX OF 24 COCKTAIL PARASOLS',
#   'PACK OF 72 RETROSPOT CAKE CASES',
#   'PACK OF 72 SKULL CAKE CASES',
#   'PACK OF 60 SPACEBOY CAKE CASES',
#   'PACK OF 60 DINOSAUR CAKE CASES',
#   'PACK OF 12 COLOURED PENCILS',
#   'MINI PAINT SET VINTAGE',
#   'RIBBON REEL POLKADOTS',
#   'RIBBON REEL STRIPES DESIGN',
#   'SET OF 6 SPICE TINS PANTRY DESIGN',
#   '200 RED + WHITE BENDY STRAWS',
#   'PAPER BUNTING RETROSPOT',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'PACK OF 6 SKULL PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'SET/20 RED RETROSPOT PAPER NAPKINS',
#   'PACK OF 20 SKULL PAPER NAPKINS',
#   '200 BENDY SKULL STRAWS'],
#  ['ROUND SNACK BOXES SET OF4 WOODLAND',
#   'JUMBO BAG WOODLAND ANIMALS',
#   '12 PENCILS TALL TUBE WOODLAND',
#   'WOODLAND PARTY BAG + STICKER SET',
#   'RETROSPOT PARTY BAG + STICKER SET',
#   'RED POLKADOT COFFEE  MUG',
#   'RED POLKADOT PUDDING BOWL',
#   'RED POLKADOT BEAKER'],
#  ['BAKING SET 9 PIECE RETROSPOT',
#   'ASSORTED COLOUR BIRD ORNAMENT',
#   'PAINTED METAL PEARS ASSORTED',
#   'WOODEN CROQUET GARDEN SET',
#   'WOODEN SKITTLES GARDEN SET',
#   'GLASS CLOCHE LARGE',
#   'GLASS CLOCHE SMALL',
#   'MULTI COLOUR SILVER T-LIGHT HOLDER',
#   'GIN + TONIC DIET METAL SIGN',
#   'HAND OVER THE CHOCOLATE   SIGN',
#   'METAL DECORATION NAUGHTY CHILDREN',
#   'MAGNETS PACK OF 4 SWALLOWS',
#   'MAGNETS PACK OF 4 CHILDHOOD MEMORY',
#   'MAGNETS PACK OF 4 HOME SWEET HOME',
#   '20 DOLLY PEGS RETROSPOT',
#   'CLOTHES PEGS RETROSPOT PACK 24',
#   'RED STRIPE CERAMIC DRAWER KNOB',
#   'BLUE STRIPE CERAMIC DRAWER KNOB',
#   'WHITE SPOT RED CERAMIC DRAWER KNOB',
#   'WHITE SPOT BLUE CERAMIC DRAWER KNOB',
#   'PINK DRAWER KNOB ACRYLIC EDWARDIAN',
#   'GREEN DRAWER KNOB ACRYLIC EDWARDIAN',
#   'BLUE DRAWER KNOB ACRYLIC EDWARDIAN',
#   'SQUARECUSHION COVER PINK UNION FLAG',
#   'CUSHION COVER PINK UNION JACK',
#   'SET OF 4 NAPKIN CHARMS CROWNS',
#   'SET OF 4 NAPKIN CHARMS 3 KEYS',
#   'SET OF 4 NAPKIN CHARMS CUTLERY',
#   '200 BENDY SKULL STRAWS',
#   '60 TEATIME FAIRY CAKE CASES',
#   '60 CAKE CASES DOLLY GIRL DESIGN',
#   'PACK OF 72 RETROSPOT CAKE CASES',
#   'PACK OF 60 DINOSAUR CAKE CASES',
#   'PACK OF 72 SKULL CAKE CASES',
#   'SET OF 36 TEATIME PAPER DOILIES',
#   '36 DOILIES DOLLY GIRL',
#   'SET OF 72 RETROSPOT PAPER  DOILIES',
#   'SET OF 72 PINK HEART PAPER DOILIES',
#   'SET OF 72 SKULL PAPER  DOILIES',
#   'SET OF 36 DINOSAUR PAPER DOILIES',
#   'REGENCY CAKESTAND 3 TIER',
#   'SET OF 3 CAKE TINS PANTRY DESIGN',
#   'JAM MAKING SET PRINTED',
#   'VINTAGE UNION JACK CUSHION COVER',
#   'VINTAGE UNION JACK APRON',
#   'EMPIRE TISSUE BOX',
#   '6 RIBBONS EMPIRE',
#   'SET 20 NAPKINS FAIRY CAKES DESIGN',
#   'GLITTER BUTTERFLY CLIPS',
#   'PACK OF 12 LONDON TISSUES',
#   'PACK OF 12 SKULL TISSUES',
#   'PACK OF 12 SUKI TISSUES',
#   'EMPIRE GIFT WRAP',
#   'TEA PARTY  WRAPPING PAPER',
#   'BIRTHDAY BANQUET GIFT WRAP',
#   'WRAP PINK FAIRY CAKES',
#   'WRAP COWBOYS',
#   'PINK BLUE FELT CRAFT TRINKET BOX',
#   'FELTCRAFT DOLL MARIA',
#   'FELTCRAFT PRINCESS OLIVIA DOLL',
#   'MAGIC DRAWING SLATE BAKE A CAKE',
#   'MAGIC DRAWING SLATE SPACEBOY',
#   'CHILDS BREAKFAST SET SPACEBOY',
#   'PLASTERS IN TIN STRONGMAN'],
#  ['GINGERBREAD MAN COOKIE CUTTER',
#   'CUTE CATS TAPE',
#   'CABIN BAG VINTAGE RETROSPOT',
#   '12 PENCIL SMALL TUBE WOODLAND',
#   '12 PENCILS SMALL TUBE RED RETROSPOT',
#   'SET OF 2 TEA TOWELS APPLE AND PEARS',
#   'TEA BAG PLATE RED RETROSPOT',
#   'PACK OF 20 SKULL PAPER NAPKINS',
#   'SET OF SALT AND PEPPER TOADSTOOLS',
#   'GUMBALL COAT RACK',
#   'FOLDING UMBRELLA CREAM POLKADOT',
#   'RED RETROSPOT CHILDRENS UMBRELLA',
#   "DOLLY MIXTURE CHILDREN'S UMBRELLA",
#   'FOLDING UMBRELLA RED/WHITE POLKADOT',
#   'PLASTERS IN TIN WOODLAND ANIMALS',
#   'PLASTERS IN TIN CIRCUS PARADE',
#   'TABLECLOTH RED APPLES DESIGN',
#   'DOORMAT RESPECTABLE HOUSE',
#   'OFFICE MUG WARMER PINK',
#   'OFFICE MUG WARMER CHOC+BLUE',
#   'PACK OF 72 RETROSPOT CAKE CASES',
#   'LUNCH BOX WITH CUTLERY RETROSPOT',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'RED RETROSPOT CUP',
#   'BOOM BOX SPEAKER BOYS',
#   'JAM MAKING SET PRINTED',
#   'POLKADOT RAIN HAT',
#   'TEA PARTY BIRTHDAY CARD',
#   'ROBOT BIRTHDAY CARD',
#   'SET/4 SKULL BADGES',
#   'CALENDAR PAPER CUT DESIGN',
#   'SKULLS  WATER TRANSFER TATTOOS',
#   '4 TRADITIONAL SPINNING TOPS'],
#  ['PACK OF 60 PINK PAISLEY CAKE CASES',
#   'PACK OF 60 MUSHROOM CAKE CASES',
#   'EDWARDIAN PARASOL BLACK',
#   'SILK PURSE BABUSHKA RED',
#   'BLUE ROSE FABRIC MIRROR',
#   'WOODLAND PARTY BAG + STICKER SET',
#   'SET OF 2 TEA TOWELS APPLE AND PEARS',
#   'CHERRY BLOSSOM  DECORATIVE FLASK',
#   'EASTER TIN BUNNY BOUQUET',
#   'CLOTHES PEGS RETROSPOT PACK 24',
#   'CALENDAR PAPER CUT DESIGN',
#   'SET OF 9 HEART SHAPED BALLOONS',
#   'VINTAGE HEADS AND TAILS CARD GAME',
#   'COFFEE MUG PEARS  DESIGN',
#   'INFLATABLE POLITICAL GLOBE',
#   'LUNCH BOX WITH CUTLERY RETROSPOT',
#   'STRAWBERRY LUNCH BOX WITH CUTLERY',
#   'ASSORTED BOTTLE TOP  MAGNETS',
#   'CIRCUS PARADE CHILDRENS EGG CUP',
#   'GINGERBREAD MAN COOKIE CUTTER',
#   'TEA FOR ONE POLKADOT',
#   'JAM JAR WITH PINK LID',
#   'ASSORTED COLOUR MINI CASES',
#   'RED RETROSPOT MINI CASES',
#   'JAM MAKING SET PRINTED',
#   'PINK DOUGHNUT TRINKET POT',
#   'PLASTERS IN TIN SPACEBOY',
#   'PLASTERS IN TIN WOODLAND ANIMALS',
#   'PLASTERS IN TIN CIRCUS PARADE',
#   'ROUND SNACK BOXES SET OF4 WOODLAND',
#   'ROUND SNACK BOXES SET OF 4 FRUITS',
#   'REGENCY CAKESTAND 3 TIER',
#   'EDWARDIAN PARASOL NATURAL',
#   'EDWARDIAN PARASOL PINK',
#   'EDWARDIAN PARASOL RED',
#   'RED  HARMONICA IN BOX',
#   'TEA PARTY BIRTHDAY CARD',
#   'PAPER BUNTING RETROSPOT',
#   'RETROSPOT PARTY BAG + STICKER SET'],
#  ['CERAMIC HEART FAIRY CAKE MONEY BANK',
#   'CERAMIC CHERRY CAKE MONEY BANK',
#   'CERAMIC PIRATE CHEST MONEY BANK',
#   'ROMANTIC IMAGES GIFT WRAP SET',
#   'WOOD STAMP SET HAPPY BIRTHDAY',
#   'MINI FUNKY DESIGN TAPES',
#   'PLASTERS IN TIN VINTAGE PAISLEY',
#   'PLASTERS IN TIN SPACEBOY',
#   'PACK OF 12 RED RETROSPOT TISSUES',
#   'LUNCH BAG RED RETROSPOT',
#   'PACK OF 72 RETROSPOT CAKE CASES',
#   'PACK OF 60 DINOSAUR CAKE CASES',
#   '60 CAKE CASES DOLLY GIRL DESIGN',
#   'WOODEN SKITTLES GARDEN SET',
#   'WOODEN CROQUET GARDEN SET',
#   'SET 12 KIDS COLOUR  CHALK STICKS',
#   'SET 12 KIDS  WHITE CHALK STICKS',
#   'TOOL BOX SOFT TOY',
#   "NURSE'S BAG SOFT TOY",
#   "DOCTOR'S BAG SOFT TOY",
#   'PIGGY BANK RETROSPOT'],
#  ["POPPY'S PLAYHOUSE KITCHEN",
#   'TOOL BOX SOFT TOY',
#   'BALLOONS  WRITING SET',
#   '10 COLOUR SPACEBOY PEN',
#   'STARS GIFT TAPE',
#   'BAKING SET 9 PIECE RETROSPOT',
#   'BAKING SET SPACEBOY DESIGN',
#   'ROUND SNACK BOXES SET OF4 WOODLAND',
#   'SET/6 RED SPOTTY PAPER PLATES',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/20 RED RETROSPOT PAPER NAPKINS',
#   'RED RETROSPOT PICNIC BAG',
#   'CHILDS BREAKFAST SET SPACEBOY',
#   'FELTCRAFT DOLL MOLLY',
#   'FELTCRAFT PRINCESS LOLA DOLL',
#   'EDWARDIAN PARASOL RED',
#   'BLACK/BLUE POLKADOT UMBRELLA',
#   'RED RETROSPOT MINI CASES',
#   'JUMBO BAG RED RETROSPOT',
#   'RED RETROSPOT SHOPPING BAG',
#   'CHARLOTTE BAG PINK POLKADOT',
#   'RED RETROSPOT CHARLOTTE BAG',
#   'CABIN BAG VINTAGE RETROSPOT'],
#  ['SET/4 WHITE RETRO STORAGE CUBES',
#   'PINK POLKADOT CHILDRENS UMBRELLA',
#   'RED RETROSPOT CHILDRENS UMBRELLA',
#   'JUMBO BAG PINK POLKADOT',
#   'JUMBO BAG RED RETROSPOT',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER PLATES',
#   'RED 3 PIECE RETROSPOT CUTLERY SET',
#   'RED TOADSTOOL LED NIGHT LIGHT',
#   'TOADSTOOL MONEY BOX',
#   'ROSE COTTAGE KEEPSAKE BOX',
#   'PAPER BUNTING RETROSPOT'],
#  ['RED RETROSPOT TAPE',
#   'STARS GIFT TAPE',
#   'RAIN PONCHO RETROSPOT',
#   'POLKADOT RAIN HAT',
#   'VICTORIAN GLASS HANGING T-LIGHT',
#   'RIDGED GLASS POSY VASE',
#   'BAKING SET 9 PIECE RETROSPOT',
#   'PEG BAG APPLES DESIGN',
#   'CLOTHES PEGS RETROSPOT PACK 24',
#   'ROUND SNACK BOXES SET OF4 WOODLAND',
#   'ROUND SNACK BOXES SET OF 4 FRUITS',
#   'MILK PAN RED RETROSPOT',
#   'OVEN MITT APPLES DESIGN',
#   'SET OF 2 TEA TOWELS APPLE AND PEARS',
#   'SET OF SALT AND PEPPER TOADSTOOLS',
#   'CAKE STAND WHITE TWO TIER LACE',
#   'PACK OF 20 NAPKINS PANTRY DESIGN',
#   'PACK OF 20 NAPKINS RED APPLES',
#   'TABLECLOTH RED APPLES DESIGN',
#   'PLASTERS IN TIN SPACEBOY',
#   'PLASTERS IN TIN CIRCUS PARADE',
#   'PACK OF 12 WOODLAND TISSUES',
#   'GINGHAM ROSE WRAP'],
#  ['SET/6 RED SPOTTY PAPER CUPS',
#   'SET/20 RED RETROSPOT PAPER NAPKINS',
#   'ALARM CLOCK BAKELIKE GREEN',
#   'ALARM CLOCK BAKELIKE RED',
#   'ALARM CLOCK BAKELIKE PINK',
#   'ALARM CLOCK BAKELIKE ORANGE',
#   'SET/10 RED POLKADOT PARTY CANDLES',
#   'ROUND SNACK BOXES SET OF4 WOODLAND',
#   'RED RETROSPOT MINI CASES',
#   'PLASTERS IN TIN SPACEBOY',
#   'PLASTERS IN TIN CIRCUS PARADE',
#   'PLASTERS IN TIN STRONGMAN',
#   'RED TOADSTOOL LED NIGHT LIGHT',
#   'PAPERWEIGHT CHILDHOOD MEMORIES',
#   'RETROSPOT PARTY BAG + STICKER SET',
#   'WOODLAND PARTY BAG + STICKER SET',
#   'WOODLAND CHARLOTTE BAG',
#   'STARS GIFT TAPE',
#   'RED RETROSPOT APRON',
#   'CHILDRENS APRON SPACEBOY DESIGN',
#   'SET/6 RED SPOTTY PAPER PLATES'],
#  ['CHARLOTTE BAG DOLLY GIRL DESIGN',
#   'WOODLAND CHARLOTTE BAG',
#   'RED RETROSPOT CHARLOTTE BAG',
#   'RETROSPOT PARTY BAG + STICKER SET',
#   'RED RETROSPOT SHOPPER BAG',
#   'RED RETROSPOT PURSE',
#   'RED RETROSPOT UMBRELLA',
#   'EDWARDIAN PARASOL RED',
#   'EDWARDIAN PARASOL BLACK',
#   'EDWARDIAN PARASOL NATURAL',
#   'SET/10 RED POLKADOT PARTY CANDLES',
#   'SET OF 6 GIRLS CELEBRATION CANDLES',
#   'SET 6 FOOTBALL CELEBRATION CANDLES',
#   'PINK BABY BUNTING',
#   'PINK PADDED MOBILE',
#   'HAIRCLIPS FORTIES FABRIC ASSORTED',
#   'RED RETROSPOT APRON',
#   'RETROSPOT CHILDRENS APRON',
#   'LARGE HEART MEASURING SPOONS',
#   'BAKING SET 9 PIECE RETROSPOT',
#   'BAKING SET SPACEBOY DESIGN',
#   'PACK OF 72 RETROSPOT CAKE CASES',
#   'FRYING PAN RED RETROSPOT',
#   'SKULL LUNCH BOX WITH CUTLERY',
#   'STRAWBERRY LUNCH BOX WITH CUTLERY',
#   'ROUND SNACK BOXES SET OF 4 SKULLS',
#   'ROUND SNACK BOXES SET OF 4 FRUITS',
#   'RED RETROSPOT BUTTER DISH',
#   'GREEN 3 PIECE POLKADOT CUTLERY SET',
#   'RED 3 PIECE RETROSPOT CUTLERY SET',
#   'BLUE 3 PIECE POLKADOT CUTLERY SET',
#   'PINK 3 PIECE POLKADOT CUTLERY SET',
#   'CHILDS BREAKFAST SET SPACEBOY',
#   'CHILDS BREAKFAST SET DOLLY GIRL',
#   'CHILDS BREAKFAST SET CIRCUS PARADE',
#   'RED RETROSPOT CUP',
#   'PINK  POLKADOT CUP',
#   'BLUE POLKADOT CUP',
#   'RED RETROSPOT PLATE',
#   'PINK  POLKADOT PLATE',
#   'BLUE POLKADOT PLATE',
#   'GREEN POLKADOT PLATE',
#   'GREEN POLKADOT BOWL',
#   'BLUE POLKADOT BOWL',
#   'RED RETROSPOT BOWL',
#   'PINK POLKADOT BOWL',
#   'SET/5 RED RETROSPOT LID GLASS BOWLS',
#   'BLUE  VOILE LAMPSHADE',
#   'PACK OF 12 WOODLAND TISSUES',
#   'PACK OF 12 RED RETROSPOT TISSUES',
#   'PACK OF 12 BLUE PAISLEY TISSUES',
#   'PACK OF 12 SKULL TISSUES',
#   '36 PENCILS TUBE WOODLAND',
#   '36 PENCILS TUBE SKULLS',
#   '36 PENCILS TUBE RED RETROSPOT',
#   'LIPSTICK PEN RED',
#   'CREAM HEART CARD HOLDER',
#   'SET3 BOOK BOX GREEN GINGHAM FLOWER',
#   'SET/3 RED GINGHAM ROSE STORAGE BOX',
#   'RED GINGHAM ROSE JEWELLERY BOX',
#   'WALL TIDY RETROSPOT',
#   'RED TOADSTOOL LED NIGHT LIGHT',
#   'PENS ASSORTED SPACEBALL',
#   'ASS FLORAL PRINT MULTI SCREWDRIVER',
#   'ASSTD DESIGN 3D PAPER STICKERS',
#   'ROSE DU SUD DRAWSTRING BAG',
#   'RED RETROSPOT MINI CASES',
#   'ASSORTED EASTER GIFT TAGS',
#   'FELTCRAFT 6 FLOWER FRIENDS',
#   'JAM MAKING SET PRINTED',
#   'SEWING BOX RETROSPOT DESIGN',
#   'DELUXE SEWING KIT',
#   'TRAVEL SEWING KIT',
#   'ROSE COTTAGE KEEPSAKE BOX',
#   'PAPER BUNTING WHITE LACE',
#   'PAPER BUNTING COLOURED LACE',
#   'PAPER BUNTING VINTAGE PAISLEY',
#   'PAPER BUNTING RETROSPOT',
#   'RED RETROSPOT ROUND CAKE TINS',
#   'CLOTHES PEGS RETROSPOT PACK 24',
#   'RED RETROSPOT PEG BAG',
#   'LUNCH BAG RED RETROSPOT',
#   'LUNCH BAG  BLACK SKULL.',
#   'ROUND CONTAINER SET OF 5 RETROSPOT',
#   'LUNCH BOX WITH CUTLERY RETROSPOT',
#   'PICNIC BOXES SET OF 3 RETROSPOT',
#   'MILK PAN RED RETROSPOT',
#   'RED RETROSPOT OVEN GLOVE DOUBLE',
#   'RED RETROSPOT OVEN GLOVE',
#   'SET 3 RETROSPOT TEA',
#   'COFFEE',
#   'SUGAR',
#   'RED RETROSPOT STORAGE JAR',
#   'SET/6 COLLAGE PAPER CUPS',
#   'SET/6 RED SPOTTY PAPER CUPS',
#   'SET/6 FRUIT SALAD PAPER CUPS',
#   'PACK OF 6 SKULL PAPER CUPS',
#   'SET/6 COLLAGE PAPER PLATES',
#   'SET/6 RED SPOTTY PAPER PLATES',
#   'SET/6 FRUIT SALAD  PAPER PLATES',
#   'PACK OF 6 SKULL PAPER PLATES',
#   'SET/20 RED RETROSPOT PAPER NAPKINS',
#   'PACK OF 20 SKULL PAPER NAPKINS',
#   'PICNIC BASKET WICKER SMALL',
#   'SET OF SALT AND PEPPER TOADSTOOLS',
#   'MINI CAKE STAND  HANGING STRAWBERY',
#   'BOX OF 24 COCKTAIL PARASOLS',
#   'CANDY SPOT EGG WARMER HARE',
#   'CANDY SPOT EGG WARMER RABBIT',
#   'FOOD CONTAINER SET 3 LOVE HEART',
#   'SMALL LICORICE DES PINK BOWL',
#   'SMALL CHOCOLATES PINK BOWL',
#   '12 RED ROSE PEG PLACE SETTINGS',
#   '12 IVORY ROSE PEG PLACE SETTINGS',
#   'PLACE SETTING WHITE HEART',
#   'HANGING PHOTO CLIP ROPE LADDER',
#   'MEMO BOARD COTTAGE DESIGN',
#   'MEMO BOARD RETROSPOT  DESIGN',
#   'TEA PARTY  WRAPPING PAPER',
#   'TOYBOX  WRAP',
#   'RED RETROSPOT WRAP',
#   'BLUE POLKADOT WRAP',
#   'PINK POLKADOT WRAP',
#   'PINK PAISLEY ROSE GIFT WRAP',
#   'BLUE SCANDINAVIAN PAISLEY WRAP',
#   'WRAP RED APPLES',
#   'WRAP MONSTER FUN',
#   'WRAP DOLLY GIRL',
#   'WRAP WEDDING DAY',
#   'WRAP CIRCUS PARADE',
#   'WRAP',
#   ' BILLBOARD FONTS DESIGN',
#   'GINGHAM ROSE WRAP',
#   'SET 12 KIDS  WHITE CHALK STICKS',
#   'SET 12 KIDS COLOUR  CHALK STICKS',
#   'S/6 SEW ON CROCHET FLOWERS',
#   "POPPY'S PLAYHOUSE BEDROOM",
#   "POPPY'S PLAYHOUSE LIVINGROOM",
#   "POPPY'S PLAYHOUSE BATHROOM",
#   "POPPY'S PLAYHOUSE KITCHEN",
#   'BOHEMIAN COLLAGE STATIONERY SET',
#   'VINTAGE PAISLEY STATIONERY SET',
#   'MINI FUNKY DESIGN TAPES',
#   'RED RETROSPOT TAPE',
#   'SKULLS TAPE',
#   'STARS GIFT TAPE',
#   'CAKES AND BOWS GIFT  TAPE',
#   'FELT EGG COSY LADYBIRD',
#   'MAGNETS PACK OF 4 VINTAGE LABELS',
#   'MAGNETS PACK OF 4 RETRO PHOTO',
#   'TV DINNER TRAY AIR HOSTESS'],
#  ['PLASTERS IN TIN CIRCUS PARADE',
#   'SET OF 20 KIDS COOKIE CUTTERS',
#   'BAKING SET 9 PIECE RETROSPOT',
#   'GUMBALL COAT RACK',
#   'PAPER BUNTING RETROSPOT',
#   'WOODEN SKITTLES GARDEN SET',
#   'WOODLAND DESIGN  COTTON TOTE BAG',
#   'SILK PURSE BABUSHKA PINK',
#   'RED RETROSPOT MINI CASES',
#   'CREAM FELT EASTER EGG BASKET',
#   'RED RETROSPOT CAKE STAND',
#   'RETROSPOT TEA SET CERAMIC 11 PC',
#   "NURSE'S BAG SOFT TOY",
#   'TEA PARTY BIRTHDAY CARD'],
#  ['CARD PARTY GAMES',
#   'PINK POLKADOT WRAP',
#   'SPACEBOY GIFT WRAP',
#   'WRAP CIRCUS PARADE',
#   'EMPIRE GIFT WRAP',
#   'GREETING CARD',
#   ' STICKY GORDON',
#   'GREETING CARD',
# ...
#   'ROLL WRAP VINTAGE CHRISTMAS',
#   "ROLL WRAP 50'S CHRISTMAS",
#   "6 GIFT TAGS 50'S CHRISTMAS",
#   'SPACEBOY CHILDRENS CUP',
#   '3 PIECE SPACEBOY COOKIE CUTTER SET',
#   'MAGIC DRAWING SLATE SPACEBOY',
#   'ROUND SNACK BOXES SET OF 4 FRUITS',
#   'TEA PARTY BIRTHDAY CARD',
#   'FELTCRAFT CHRISTMAS FAIRY',
#   'SPACEBOY CHILDRENS BOWL',
#   'PAPER BUNTING RETROSPOT',
#   'SPACEBOY BIRTHDAY CARD',
#   'FELTCRAFT DOLL ROSIE',
#   'ADVENT CALENDAR GINGHAM SACK',
#   'SET OF 20 VINTAGE CHRISTMAS NAPKINS',
#   'VINTAGE CHRISTMAS STOCKING',
#   'HAND WARMER OWL DESIGN',
#   'WHITE GOOSE FEATHER CHRISTMAS TREE',
#   'PLASTERS IN TIN SPACEBOY',
#   'PLASTERS IN TIN WOODLAND ANIMALS',
#   'PLASTERS IN TIN CIRCUS PARADE',
#   'FELTCRAFT PRINCESS LOLA DOLL',
#   'RABBIT NIGHT LIGHT'],
#  ['VINTAGE DOILY TRAVEL SEWING KIT',
#   'LUNCH BAG PAISLEY PARK',
#   'SET 7 BABUSHKA NESTING BOXES',
#   'HAND WARMER OWL DESIGN',
#   'FAWN BLUE HOT WATER BOTTLE',
#   'CHICK GREY HOT WATER BOTTLE',
#   'RABBIT NIGHT LIGHT',
#   'PACK OF 72 RETROSPOT CAKE CASES',
#   'SET OF 5 LUCKY CAT MAGNETS',
#   'KNICKERBOCKERGLORY MAGNET ASSORTED',
#   'SET OF 5 PANCAKE DAY MAGNETS',
#   'SET OF 5 MINI GROCERY MAGNETS',
#   'RECIPE BOX PANTRY YELLOW DESIGN',
#   'JUMBO BAG WOODLAND ANIMALS',
#   'SOMBRERO',
#   'JUMBO STORAGE BAG SUKI'],
#  ['ROUND SNACK BOXES SET OF4 WOODLAND',
#   'CHARLIE & LOLA WASTEPAPER BIN FLORA',
#   'TOADSTOOL MONEY BOX',
#   'RED RETROSPOT MINI CASES',
#   'CHARLIE+LOLA PINK HOT WATER BOTTLE',
#   'CHARLIE + LOLA RED HOT WATER BOTTLE',
#   'WOODLAND SMALL PINK FELT HEART',
#   'WOODLAND SMALL RED FELT HEART',
#   'WOODLAND SMALL BLUE FELT HEART',
#   'MINI LIGHTS WOODLAND MUSHROOMS'],
#  ['JUMBO BAG PAISLEY PARK',
#   'VINTAGE DOILY JUMBO BAG RED',
#   'LUNCH BAG PAISLEY PARK',
#   'PARTY CONE CHRISTMAS DECORATION',
#   "BISCUIT TIN 50'S CHRISTMAS",
#   "JUMBO BAG 50'S CHRISTMAS",
#   'RETROSPOT LARGE MILK JUG',
#   'TOY TIDY SPACEBOY',
#   '3 STRIPEY MICE FELTCRAFT',
#   'WALL TIDY RETROSPOT',
#   'RED RETROSPOT WRAP',
#   'SET OF 3 CAKE TINS PANTRY DESIGN',
#   'PACK OF 72 RETROSPOT CAKE CASES',
#   'SET OF 12 FAIRY CAKE BAKING CASES',
#   'LUNCH BAG RED VINTAGE DOILY',
#   'SET OF 12 MINI LOAF BAKING CASES',
#   'PLASTERS IN TIN CIRCUS PARADE',
#   'PLASTERS IN TIN STRONGMAN',
#   'JAM MAKING SET PRINTED',
#   'DOILY THANK YOU CARD',
#   'SET 12 VINTAGE DOILY CHALK',
#   'CHRISTMAS CRAFT LITTLE FRIENDS',
#   'PARISIENNE KEY CABINET',
#   'RED RETROSPOT SHOPPER BAG'],
#  ['VINTAGE DOILY TRAVEL SEWING KIT', 'RED SPOT CERAMIC DRAWER KNOB'],
#  ["BOX OF 6 MINI 50'S CRACKERS"],
#  ['RABBIT NIGHT LIGHT',
#   'ROSES REGENCY TEACUP AND SAUCER',
#   "POPPY'S PLAYHOUSE BEDROOM",
#   "POPPY'S PLAYHOUSE BATHROOM",
#   "POPPY'S PLAYHOUSE KITCHEN",
#   'WOODEN BOX OF DOMINOES',
#   'CIRCUS PARADE BABY GIFT SET',
#   'SPACEBOY BABY GIFT SET',
#   'FAWN BLUE HOT WATER BOTTLE',
#   'DOORMAT SPOTTY HOME SWEET HOME',
#   'DOORMAT RED RETROSPOT',
#   'DOORMAT 3 SMILEY CATS',
#   'MINI PAINT SET VINTAGE',
#   'ASSORTED COLOUR BIRD ORNAMENT',
#   'LUNCH BAG RED RETROSPOT',
#   'LUNCH BAG SPACEBOY DESIGN',
#   'SPACEBOY LUNCH BOX',
#   'LUNCH BAG DOLLY GIRL DESIGN',
#   'PACK OF 72 RETROSPOT CAKE CASES',
#   'SOLDIERS EGG CUP',
#   'RED RETROSPOT CHILDRENS UMBRELLA',
#   'MINI FUNKY DESIGN TAPES'],
#  ['MINI LIGHTS WOODLAND MUSHROOMS',
#   'JUMBO BAG PAISLEY PARK',
#   'WOODEN ADVENT CALENDAR RED',
#   'FOLKART STAR CHRISTMAS DECORATIONS',
#   'ADVENT CALENDAR GINGHAM SACK',
#   '6 RIBBONS ELEGANT CHRISTMAS',
#   'RIBBON REEL CHRISTMAS SOCK BAUBLE',
#   'SET OF 6 RIBBONS VINTAGE CHRISTMAS',
#   'RIBBON REEL CHRISTMAS PRESENT',
#   'RIBBON REEL SOCKS AND MITTENS',
#   'TRADITIONAL CHRISTMAS RIBBONS',
#   'RIBBON REEL POLKADOTS',
#   'JUMBO BAG PINK POLKADOT',
#   'CHARLOTTE BAG PINK POLKADOT',
#   'JUMBO BAG WOODLAND ANIMALS',
#   'WOODLAND CHARLOTTE BAG',
#   'ROUND SNACK BOXES SET OF4 WOODLAND',
#   'WOODLAND MINI BACKPACK',
#   'JUMBO STORAGE BAG SKULLS',
#   'RED RETROSPOT CHILDRENS UMBRELLA',
#   'RED GINGHAM ROSE JEWELLERY BOX',
#   '6 GIFT TAGS VINTAGE CHRISTMAS',
#   'RED SPOT PAPER GIFT BAG',
#   'PINK BABY BUNTING',
#   'MEMO BOARD COTTAGE DESIGN',
#   'RED RETROSPOT CHARLOTTE BAG',
#   'JUMBO BAG PINK VINTAGE PAISLEY',
#   'JUMBO BAG SPACEBOY DESIGN',
#   "JUMBO BAG 50'S CHRISTMAS",
#   'JUMBO BAG VINTAGE DOILY',
#   'JUMBO BAG RED RETROSPOT',
#   'RED RETROSPOT CUP',
#   'RED RETROSPOT BOWL',
#   'PARTY CONES CANDY DECORATION',
#   'DINOSAURS  WRITING SET'],
#  ['PACK OF 12 RED RETROSPOT TISSUES',
#   'PACK OF 12 SKULL TISSUES',
#   'PACK OF 12 WOODLAND TISSUES',
#   'SKULLS SQUARE TISSUE BOX'],
#  ['SWEETHEART 3 TIER CAKE STAND'],
#  ['RABBIT NIGHT LIGHT',
#   'SET OF 3 REGENCY CAKE TINS',
#   'SPACEBOY BIRTHDAY CARD',
#   '3 PIECE SPACEBOY COOKIE CUTTER SET',
#   'PLASTERS IN TIN SPACEBOY',
#   'LUNCH BAG SPACEBOY DESIGN',
#   'LUNCH BAG WOODLAND',
#   'SET OF 6 NATIVITY MAGNETS',
#   'BISCUIT TIN VINTAGE CHRISTMAS',
#   'REGENCY CAKESTAND 3 TIER',
#   'PARTY INVITES WOODLAND',
#   'PARTY INVITES SPACEMAN'],
#  ['RED ROCKING HORSE HAND PAINTED',
#   'HEART WREATH DECORATION WITH BELL',
#   'STAR WREATH DECORATION WITH BELL',
#   'WHITE ROCKING HORSE HAND PAINTED'],
#  ['CHILDRENS APRON APPLES DESIGN',
#   'ADULT APRON APPLE DELIGHT',
#   'WOODLAND CHARLOTTE BAG',
#   'STRAWBERRY CHARLOTTE BAG',
#   'RETROSPOT CHILDRENS APRON',
#   'BOX OF 6 CHRISTMAS CAKE DECORATIONS',
#   'MINI LIGHTS WOODLAND MUSHROOMS',
#   'CHILDRENS TOY COOKING UTENSIL SET',
#   'RETROSPOT TEA SET CERAMIC 11 PC',
#   'RED RETROSPOT CHARLOTTE BAG',
#   'CHRISTMAS CRAFT TREE TOP ANGEL',
#   'CHRISTMAS CRAFT LITTLE FRIENDS',
#   'SET/5 RED RETROSPOT LID GLASS BOWLS',
#   'PACK OF 12 WOODLAND TISSUES',
#   'PACK OF 12 CIRCUS PARADE TISSUES',
#   "ROLL WRAP 50'S CHRISTMAS",
#   'SET OF 6 RIBBONS VINTAGE CHRISTMAS',
#   'RIBBON REEL CHRISTMAS SOCK BAUBLE',
#   'ROLL WRAP VINTAGE CHRISTMAS',
#   '6 GIFT TAGS VINTAGE CHRISTMAS',
#   '60 CAKE CASES VINTAGE CHRISTMAS',
#   'SET OF 20 VINTAGE CHRISTMAS NAPKINS'],
#  ['CHRISTMAS CRAFT TREE TOP ANGEL',
#   'CHRISTMAS CRAFT LITTLE FRIENDS',
#   'FELTCRAFT PRINCESS LOLA DOLL',
#   'FELTCRAFT PRINCESS OLIVIA DOLL',
#   'FELTCRAFT PRINCESS CHARLOTTE DOLL',
#   'JAM MAKING SET WITH JARS'],
#  ['DOLLY GIRL CHILDRENS BOWL',
#   'DOLLY GIRL CHILDRENS CUP',
#   'PLASTERS IN TIN CIRCUS PARADE',
#   'PLASTERS IN TIN STRONGMAN',
#   'WORLD WAR 2 GLIDERS ASSTD DESIGNS',
#   'SET 12 KIDS  WHITE CHALK STICKS',
#   'RETROSPOT CHILDRENS APRON',
#   '4 TRADITIONAL SPINNING TOPS',
#   'PICTURE DOMINOES',
#   'TRADTIONAL ALPHABET STAMP SET',
#   'SET OF 6 SOLDIER SKITTLES'],
#  ['SET 7 BABUSHKA NESTING BOXES',
#   'FELTCRAFT PRINCESS CHARLOTTE DOLL',
#   'FELTCRAFT PRINCESS OLIVIA DOLL',
#   'FELTCRAFT DOLL MOLLY',
#   'BIRDS MOBILE VINTAGE DESIGN',
#   "POPPY'S PLAYHOUSE BEDROOM",
#   "POPPY'S PLAYHOUSE BATHROOM",
#   "POPPY'S PLAYHOUSE LIVINGROOM",
#   "POPPY'S PLAYHOUSE KITCHEN",
#   'CHRISTMAS CRAFT WHITE FAIRY',
#   'FELTCRAFT CHRISTMAS FAIRY',
#   'MOBILE VINTAGE HEARTS',
#   'PAPER CHAIN KIT RETROSPOT',
#   'SET OF 3 WOODEN STOCKING DECORATION',
#   'WOODEN TREE CHRISTMAS SCANDINAVIAN'],
#  ['SET 6 PAPER TABLE LANTERN HEARTS',
#   'MINI LIGHTS WOODLAND MUSHROOMS',
#   'TRADTIONAL ALPHABET STAMP SET',
#   'SET OF 3 REGENCY CAKE TINS',
#   'JAM MAKING SET PRINTED',
#   'PACK 3 BOXES BIRD PANNETONE',
#   'RABBIT NIGHT LIGHT',
#   'RED TOADSTOOL LED NIGHT LIGHT',
#   'SET OF 5 LUCKY CAT MAGNETS',
#   'SET OF 5 PANCAKE DAY MAGNETS',
#   'SET OF 6 SNACK LOAF BAKING CASES',
#   'REGENCY SUGAR BOWL GREEN',
#   'PANTRY MAGNETIC  SHOPPING LIST',
#   'SET OF 4 KNICK KNACK TINS LONDON',
#   "PACK OF 12 50'S CHRISTMAS TISSUES",
#   'ICE CREAM BUBBLES',
#   'I LOVE LONDON BEAKER',
#   'SPACEBOY GIFT WRAP',
#   'WRAP RED APPLES',
#   'WRAP GREEN PEARS',
#   'MAGIC SHEEP WOOL GROWING FROM PAPER',
#   'DOLLY GIRL CHILDRENS BOWL',
#   'SPACEBOY ROCKET LOLLY MAKERS',
#   'SKETCHBOOK MAGNETIC SHOPPING LIST',
#   'SET OF 60 PANTRY DESIGN CAKE CASES',
#   'SET OF 60 I LOVE LONDON CAKE CASES',
#   'TRADITIONAL KNITTING NANCY',
#   'ALARM CLOCK BAKELIKE PINK',
#   'SILVER STARS TABLE DECORATION',
#   'SILVER BELLS TABLE DECORATION',
#   'SET OF 10 LED DOLLY LIGHTS'],
#  ['ENCHANTED BIRD COATHANGER 5 HOOK',
#   'RECYCLING BAG RETROSPOT',
#   'RED GINGHAM ROSE JEWELLERY BOX',
#   'FOLDING UMBRELLA BLACKBLUE POLKADOT',
#   'FOLDING UMBRELLA RED/WHITE POLKADOT',
#   'CHICK GREY HOT WATER BOTTLE',
#   'SCOTTIE DOG HOT WATER BOTTLE',
#   'RED WOOLLY HOTTIE WHITE HEART.',
#   'PINK/WHITE CHRISTMAS TREE 60CM',
#   'BLACK CHRISTMAS TREE 120CM',
#   'ROTATING LEAVES T-LIGHT HOLDER',
#   'PARISIENNE KEY CABINET',
#   'METAL 4 HOOK HANGER FRENCH CHATEAU',
#   '3 DRAWER ANTIQUE WHITE WOOD CABINET',
#   'DOORMAT FANCY FONT HOME SWEET HOME',
#   'DOORMAT RESPECTABLE HOUSE',
#   'DOORMAT TOPIARY',
#   'DOORMAT HEARTS',
#   'DOORMAT FAIRY CAKE',
#   'DOORMAT WELCOME PUPPIES',
#   'POMPOM CURTAIN',
#   'RETROSPOT BABUSHKA DOORSTOP',
#   'RED STRIPE CERAMIC DRAWER KNOB',
#   'PINK PAPER PARASOL',
#   'BEWARE OF THE CAT METAL SIGN',
#   'CHOCOLATE THIS WAY METAL SIGN',
#   'IVORY DINER WALL CLOCK',
#   'RED DINER WALL CLOCK',
#   'FOUR HOOK  WHITE LOVEBIRDS',
#   'TRIPLE HOOK ANTIQUE IVORY ROSE',
#   'CREAM CUPID HEARTS COAT HANGER',
#   'SET/2 RED RETROSPOT TEA TOWELS',
#   'FRYING PAN RED RETROSPOT',
#   'BREAD BIN DINER STYLE RED',
#   'BROCANTE SHELF WITH HOOKS',
#   'WALL TIDY RETROSPOT',
#   'PACK OF 72 RETROSPOT CAKE CASES',
#   'RED KITCHEN SCALES',
#   'RED RETROSPOT ROUND CAKE TINS',
#   'ROUND CAKE TIN VINTAGE RED',
#   'SET OF 6 SPICE TINS PANTRY DESIGN',
#   'CREAM HEART CARD HOLDER',
#   'MEMO BOARD COTTAGE DESIGN',
#   'WOODLAND STORAGE BOX SMALL',
#   'SET/3 RED GINGHAM ROSE STORAGE BOX'],
#  ['WRAP  VINTAGE DOILY',
#   'ADVENT CALENDAR GINGHAM SACK',
#   'WOODEN ADVENT CALENDAR CREAM',
#   'BOX OF 6 MINI VINTAGE CRACKERS',
#   "GIANT 50'S CHRISTMAS CRACKER",
#   'NOEL WOODEN BLOCK LETTERS',
#   'SET OF 4 SANTA PLACE SETTINGS',
#   'FELTCRAFT CHRISTMAS FAIRY',
#   'CHRISTMAS CRAFT TREE TOP ANGEL',
#   'CHRISTMAS CRAFT LITTLE FRIENDS',
#   'GARLAND WITH STARS AND BELLS',
#   'GARLAND WITH HEARTS AND BELLS',
#   'GLITTER STAR GARLAND WITH BELLS',
#   'VINTAGE CHRISTMAS BUNTING',
#   'FOLKART STAR CHRISTMAS DECORATIONS',
#   'ZINC FOLKART SLEIGH BELLS',
#   'PASTEL COLOUR HONEYCOMB FAN',
#   'PINK  HONEYCOMB PAPER FAN',
#   'MIRRORED DISCO BALL',
#   'ABC TREASURE BOOK BOX',
#   'TREASURE ISLAND BOOK BOX',
#   'FELTCRAFT DOLL ROSIE',
#   'FELTCRAFT PRINCESS LOLA DOLL',
#   'FELTCRAFT PRINCESS OLIVIA DOLL',
#   'FELTCRAFT BOY JEAN-PAUL KIT',
#   'LUNCH BAG RED RETROSPOT',
#   'LUNCH BAG WOODLAND',
#   'SKULL LUNCH BOX WITH CUTLERY',
#   'ROUND SNACK BOXES SET OF4 WOODLAND',
#   'LUNCH BAG  BLACK SKULL.',
#   'ROUND SNACK BOXES SET OF 4 SKULLS',
#   'ROUND SNACK BOXES SET OF 4 FRUITS',
#   'SPACEBOY LUNCH BOX',
#   'PICNIC BOXES SET OF 3 RETROSPOT',
#   'LUNCH BOX WITH CUTLERY RETROSPOT',
#   'DOLLY GIRL LUNCH BOX',
#   'LUNCH BOX I LOVE LONDON',
#   'LUNCH BAG APPLE DESIGN',
#   'RED APPLES CHOPPING BOARD',
#   'SET 12 COLOUR PENCILS SPACEBOY',
#   'SET 12 COLOUR PENCILS DOLLY GIRL',
#   'SET 36 COLOUR PENCILS LOVE LONDON',
#   'GUMBALL MAGAZINE RACK',
#   'ASSORTED COLOUR BIRD ORNAMENT',
#   "WALL ART 70'S ALPHABET",
#   'WOODLAND  HEIGHT CHART STICKERS',
#   'ALUMINIUM STAMPED HEART',
#   'HANGING QUILTED PATCHWORK APPLES',
#   'PRETTY HANGING QUILTED HEARTS',
#   'ALARM CLOCK BAKELIKE PINK',
#   'ALARM CLOCK BAKELIKE RED',
#   'ALARM CLOCK BAKELIKE GREEN',
#   'GUMBALL COAT RACK',
#   'DOLLY HONEYCOMB GARLAND',
#   'DOLLY GIRL CHILDRENS BOWL',
#   'SPACEBOY CHILDRENS BOWL',
#   'SPACEBOY CHILDRENS CUP',
#   'DOLLY GIRL CHILDRENS CUP',
#   'CHILDRENS CUTLERY DOLLY GIRL',
#   'CHILDRENS CUTLERY POLKADOT PINK',
#   'CHILDRENS CUTLERY SPACEBOY',
#   'JUMBO BAG WOODLAND ANIMALS',
#   'TOY TIDY SPACEBOY',
#   'RECYCLING BAG RETROSPOT',
#   'JUMBO BAG SPACEBOY DESIGN',
#   'JUMBO BAG APPLES',
#   'JUMBO BAG PEARS',
#   'JUMBO BAG VINTAGE DOILY',
#   'JUMBO BAG VINTAGE CHRISTMAS',
#   'WOODLAND MINI BACKPACK',
#   'I LOVE LONDON MINI BACKPACK',
#   'SPACEBOY MINI BACKPACK',
#   'TOTE BAG I LOVE LONDON',
#   'TRAVEL CARD WALLET PANTRY',
#   'TRAVEL CARD WALLET I LOVE LONDON',
#   'FOLDING BUTTERFLY MIRROR HOT PINK',
#   'RED RETROSPOT MINI CASES',
#   'WRAP RED APPLES',
#   'SPACEBOY GIFT WRAP',
#   'WRAP GREEN PEARS'],
#  ['MINI LIGHTS WOODLAND MUSHROOMS',
#   'VINTAGE DOILY JUMBO BAG RED',
#   'WOODEN ADVENT CALENDAR CREAM',
#   'WOODEN ADVENT CALENDAR RED',
#   "BOX OF 6 MINI 50'S CRACKERS",
#   'BOX OF 6 MINI VINTAGE CRACKERS',
#   'STAR WREATH DECORATION WITH BELL',
#   'RED ROCKING HORSE HAND PAINTED',
#   'JUMBO BAG APPLES',
#   'JUMBO BAG VINTAGE DOILY',
#   'SET OF 4 KNICK KNACK TINS DOILY',
#   'LUNCH BAG RED RETROSPOT',
#   'LUNCH BAG RED VINTAGE DOILY',
#   'LUNCH BAG APPLE DESIGN',
#   'LUNCH BAG PAISLEY PARK',
#   'PAPERWEIGHT SAVE THE PLANET',
#   'PAPERWEIGHT CHILDHOOD MEMORIES',
#   'RABBIT NIGHT LIGHT'],
#  ['FRENCH STYLE EMBOSSED HEART CABINET',
#   'MEMO BOARD COTTAGE DESIGN',
#   'MEMO BOARD RETROSPOT  DESIGN',
#   'PINK AND WHITE CHRISTMAS TREE 120CM',
#   'TEA TIME OVEN GLOVE',
#   'RED RETROSPOT OVEN GLOVE'],
#  ['POLKADOT RAIN HAT',
#   'LUNCH BAG PAISLEY PARK',
#   'JUMBO BAG PAISLEY PARK',
#   "BOX OF 6 MINI 50'S CRACKERS",
#   'SET OF 2 CHRISTMAS DECOUPAGE CANDLE',
#   '3D TRADITIONAL CHRISTMAS STICKERS',
#   'SET OF 6 RIBBONS VINTAGE CHRISTMAS',
#   'CHRISTMAS CRAFT LITTLE FRIENDS',
#   'HOT WATER BOTTLE KEEP CALM',
#   'COSY HOUR CIGAR BOX MATCHES',
#   'JAM MAKING SET PRINTED',
#   'JAM MAKING SET WITH JARS',
#   'JAM JAR WITH PINK LID',
#   'REGENCY CAKESTAND 3 TIER',
#   'RECYCLED ACAPULCO MAT TURQUOISE',
#   'REGENCY TEAPOT ROSES',
#   'SET OF 36 PAISLEY FLOWER DOILIES',
#   'SET/3 DECOUPAGE STACKING TINS',
#   'SET OF 20 KIDS COOKIE CUTTERS',
#   'SET OF 6 SOLDIER SKITTLES',
#   'VINTAGE DONKEY TAIL GAME',
#   'VINTAGE CHRISTMAS TABLECLOTH',
#   'ZINC FOLKART SLEIGH BELLS',
#   '10 COLOUR SPACEBOY PEN',
#   'CHILDRENS CUTLERY SPACEBOY',
#   'KEY RING BASEBALL BOOT UNION JACK',
#   'OFFICE MUG WARMER POLKADOT',
#   'REGENCY SUGAR TONGS',
#   'REGENCY CAKE SLICE',
#   'REGENCY SUGAR BOWL GREEN',
#   'REGENCY MILK JUG PINK',
#   'SET OF 3 REGENCY CAKE TINS',
#   'REGENCY TEA PLATE ROSES',
#   'REGENCY TEA PLATE GREEN',
#   'REGENCY TEA PLATE PINK',
#   'REGENCY TEA STRAINER',
#   'GREEN REGENCY TEACUP AND SAUCER',
#   'PINK REGENCY TEACUP AND SAUCER',
#   'ROSES REGENCY TEACUP AND SAUCER',
#   'REGENCY TEA SPOON',
#   'REGENCY CAKE FORK',
#   'SET/5 RED RETROSPOT LID GLASS BOWLS',
#   'SET OF 72 RETROSPOT PAPER  DOILIES'],
#  ['RED KITCHEN SCALES',
#   'IVORY KITCHEN SCALES',
#   'SET/5 RED RETROSPOT LID GLASS BOWLS',
#   'SMALL RED RETROSPOT MUG IN BOX',
#   'SMALL WHITE RETROSPOT MUG IN BOX',
#   'RED RETROSPOT MUG',
#   'RED TOADSTOOL LED NIGHT LIGHT',
#   'PLASTERS IN TIN STRONGMAN',
#   'PLASTERS IN TIN SPACEBOY',
#   'CLASSIC CHROME BICYCLE BELL',
#   'PAPERWEIGHT CHILDHOOD MEMORIES',
#   'TV DINNER TRAY DOLLY GIRL',
#   'TV DINNER TRAY AIR HOSTESS',
#   'SPACEBOY TV DINNER TRAY',
#   'SET 36 COLOUR PENCILS DOLLY GIRL',
#   'SET 36 COLOUR PENCILS SPACEBOY',
#   'SET OF 3 NOTEBOOKS IN PARCEL',
#   'SET OF 4 KNICK KNACK TINS DOILY',
#   'TREASURE TIN BUFFALO BILL',
#   'TREASURE TIN GYMKHANA DESIGN',
#   'SET OF 4 KNICK KNACK TINS LONDON',
#   'BLUE HARMONICA IN BOX',
#   'METAL SIGN TAKE IT OR LEAVE IT',
#   'ALARM CLOCK BAKELIKE GREEN',
#   'ALARM CLOCK BAKELIKE RED',
#   'ALARM CLOCK BAKELIKE PINK',
#   'MINT DINER WALL CLOCK',
#   'RED DINER WALL CLOCK',
#   'BLUE DINER WALL CLOCK',
#   'SMALL RED BABUSHKA NOTEBOOK',
#   'SMALL PURPLE BABUSHKA NOTEBOOK',
#   'RAIN PONCHO RETROSPOT',
#   'RED RETROSPOT MINI CASES',
#   'ASSORTED COLOUR MINI CASES',
#   'TRADITIONAL PICK UP STICKS GAME',
#   'RETROSPOT CANDLE  MEDIUM',
#   'CARD DOLLY GIRL',
#   'SPACEBOY BIRTHDAY CARD',
#   'CARD MOTORBIKE SANTA',
#   'SET 7 BABUSHKA NESTING BOXES',
#   'VINTAGE DOILY TRAVEL SEWING KIT',
#   'SEWING SUSAN 21 NEEDLE SET',
#   'PHOTO CUBE',
#   'SET OF 3 HANGING OWLS OLLIE BEAK',
#   'LUNCH BAG WOODLAND',
#   'LUNCH BAG RED RETROSPOT',
#   'ROUND SNACK BOXES SET OF4 WOODLAND',
#   'ROUND SNACK BOXES SET OF 4 FRUITS',
#   'PICNIC BOXES SET OF 3 RETROSPOT',
#   'ROUND CONTAINER SET OF 5 RETROSPOT',
#   'SPACEBOY LUNCH BOX',
#   'DOLLY GIRL LUNCH BOX',
#   'RED SPOTTY BISCUIT TIN',
#   'BISCUIT TIN VINTAGE CHRISTMAS',
#   "BISCUIT TIN 50'S CHRISTMAS",
#   'PHARMACIE FIRST AID TIN',
#   'EMERGENCY FIRST AID TIN',
#   'RETRO MOD TRAY'],
#  ['SET/10 IVORY POLKADOT PARTY CANDLES',
#   'SET/10 PINK POLKADOT PARTY CANDLES',
#   'SET/10 RED POLKADOT PARTY CANDLES',
#   'PACK OF 72 RETROSPOT CAKE CASES'],
#  ['BREAD BIN DINER STYLE IVORY', 'BREAD BIN DINER STYLE RED'],
#  ...]

# %% [markdown]
# ### Encode

# %%
te = TransactionEncoder()

te_array = te.fit(item_list).transform(item_list)

te_array
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [ True, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])

# %%
item_df = pd.DataFrame(te_array, columns=te.columns_)
item_df
# Out:
#               1 HANGER    BACK DOOR   BILLBOARD FONTS DESIGN   BIRTHDAY CARD  \
# 0     False       False       False                    False           False
# 1     False       False       False                    False           False
# 2     False       False       False                    False           False
# 3     False       False       False                    False           False
# 4     False       False       False                    False           False
# ...     ...         ...         ...                      ...             ...
# 1111   True       False       False                    False           False
# 1112  False       False       False                    False           False
# 1113  False       False       False                    False           False
# 1114   True       False       False                    False           False
# 1115  False       False       False                    False           False
#
#        BREAKFAST IN BED   CHOCOLATE  SPOTS   DOUGHNUTS   NEW ENGLAND  \
# 0                 False              False       False         False
# 1                 False              False       False         False
# 2                 False              False       False         False
# 3                 False              False       False         False
# 4                 False              False       False         False
# ...                 ...                ...         ...           ...
# 1111              False              False       False         False
# 1112              False              False       False         False
# 1113              False              False       False         False
# 1114              False              False       False         False
# 1115              False              False       False         False
#
#        OVERCROWDED POOL.  ...  ZINC  HEART T-LIGHT HOLDER  \
# 0                  False  ...                       False
# 1                  False  ...                       False
# 2                  False  ...                       False
# 3                  False  ...                       False
# 4                  False  ...                       False
# ...                  ...  ...                         ...
# 1111               False  ...                       False
# 1112               False  ...                       False
# 1113               False  ...                       False
# 1114               False  ...                       False
# 1115               False  ...                       False
#
#       ZINC  STAR T-LIGHT HOLDER  ZINC BOX SIGN HOME  \
# 0                         False               False
# 1                         False               False
# 2                         False               False
# 3                         False               False
# 4                         False               False
# ...                         ...                 ...
# 1111                      False               False
# 1112                      False               False
# 1113                      False               False
# 1114                      False               False
# 1115                      False               False
#
#       ZINC FOLKART SLEIGH BELLS  ZINC HEART LATTICE T-LIGHT HOLDER  \
# 0                         False                              False
# 1                         False                              False
# 2                         False                              False
# 3                         False                              False
# 4                         False                              False
# ...                         ...                                ...
# 1111                      False                              False
# 1112                      False                              False
# 1113                      False                              False
# 1114                      False                              False
# 1115                      False                              False
#
#       ZINC HERB GARDEN CONTAINER  ZINC METAL HEART DECORATION  \
# 0                          False                        False
# 1                          False                        False
# 2                          False                        False
# 3                          False                        False
# 4                          False                        False
# ...                          ...                          ...
# 1111                       False                        False
# 1112                       False                        False
# 1113                       False                        False
# 1114                       False                        False
# 1115                       False                        False
#
#       ZINC T-LIGHT HOLDER STAR LARGE  ZINC T-LIGHT HOLDER STARS SMALL  \
# 0                              False                            False
# 1                              False                            False
# 2                              False                            False
# 3                              False                            False
# 4                              False                            False
# ...                              ...                              ...
# 1111                           False                            False
# 1112                           False                            False
# 1113                           False                            False
# 1114                           False                            False
# 1115                           False                            False
#
#       ZINC WILLIE WINKIE  CANDLE STICK
# 0                                False
# 1                                False
# 2                                False
# 3                                False
# 4                                False
# ...                                ...
# 1111                             False
# 1112                             False
# 1113                             False
# 1114                             False
# 1115                             False
#
# [1116 rows x 2369 columns]

# %%
item_df[''].value_counts()
# Out:
# False    1092
# True       24
# Name: , dtype: int64

# %%
item_df = item_df.drop('', axis=1)

# %%
item_df.shape
# Out:
# (1116, 2368)

# %% [markdown]
# ### Some query

# %%
space_boy_df = item_df[item_df['SPACEBOY LUNCH BOX'] == True]

# %%
space_boy_df[['SPACEBOY LUNCH BOX']]
# Out:
#       SPACEBOY LUNCH BOX
# 0                   True
# 14                  True
# 48                  True
# 57                  True
# 71                  True
# ...                  ...
# 1052                True
# 1083                True
# 1106                True
# 1107                True
# 1115                True
#
# [159 rows x 1 columns]

# %%
space_dolly_df = item_df[(item_df['SPACEBOY LUNCH BOX'] == True) & (item_df['DOLLY GIRL LUNCH BOX'] == True)]
space_dolly_df[['SPACEBOY LUNCH BOX', 'DOLLY GIRL LUNCH BOX']]
# Out:
#       SPACEBOY LUNCH BOX  DOLLY GIRL LUNCH BOX
# 48                  True                  True
# 74                  True                  True
# 87                  True                  True
# 96                  True                  True
# 105                 True                  True
# ...                  ...                   ...
# 993                 True                  True
# 997                 True                  True
# 1017                True                  True
# 1029                True                  True
# 1083                True                  True
#
# [80 rows x 2 columns]

# %% [markdown]
# ### Apriori algorithm
# Refers to an algorithm that is used in mining frequent products sets and relevant association rules. Generally, the apriori algorithm operates on a database containing a huge number of transactions.

# %%
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ### 10% of transactions

# %%
freq_items = apriori(item_df, min_support = 0.1, use_colnames=True)
freq_items.sort_values('support', ascending=False)
# Out:
#      support  \
# 8   0.223118
# 3   0.142473
# 9   0.142473
# 6   0.141577
# 7   0.139785
# 1   0.129032
# 5   0.128136
# 2   0.115591
# 11  0.107527
# 10  0.104839
# 4   0.103943
# 0   0.103047
#
#                                                                    itemsets
# 8                                      (ROUND SNACK BOXES SET OF4 WOODLAND)
# 3                                        (PLASTERS IN TIN WOODLAND ANIMALS)
# 9                                                      (SPACEBOY LUNCH BOX)
# 6                                                (REGENCY CAKESTAND 3 TIER)
# 7                                       (ROUND SNACK BOXES SET OF 4 FRUITS)
# 1                                           (PLASTERS IN TIN CIRCUS PARADE)
# 5                                           (RED TOADSTOOL LED NIGHT LIGHT)
# 2                                                (PLASTERS IN TIN SPACEBOY)
# 11  (ROUND SNACK BOXES SET OF4 WOODLAND, ROUND SNACK BOXES SET OF 4 FRUITS)
# 10                                                 (WOODLAND CHARLOTTE BAG)
# 4                                                      (RABBIT NIGHT LIGHT)
# 0                                         (PACK OF 72 RETROSPOT CAKE CASES)

# %% [markdown]
# ### 5% of transactions

# %%
freq_items = apriori(item_df, min_support = 0.05, use_colnames=True)
freq_items.sort_values('support', ascending=False)
# Out:
#      support  \
# 43  0.223118
# 52  0.142473
# 32  0.142473
# 39  0.141577
# 42  0.139785
# ..       ...
# 16  0.051075
# 51  0.050179
# 44  0.050179
# 55  0.050179
# 71  0.050179
#
#                                                                                             itemsets
# 43                                                              (ROUND SNACK BOXES SET OF4 WOODLAND)
# 52                                                                              (SPACEBOY LUNCH BOX)
# 32                                                                (PLASTERS IN TIN WOODLAND ANIMALS)
# 39                                                                        (REGENCY CAKESTAND 3 TIER)
# 42                                                               (ROUND SNACK BOXES SET OF 4 FRUITS)
# ..                                                                                               ...
# 16                                                                        (JAM MAKING SET WITH JARS)
# 51                                                                         (SPACEBOY CHILDRENS BOWL)
# 44                                                             (SET OF 2 TEA TOWELS APPLE AND PEARS)
# 55                                            (ALARM CLOCK BAKELIKE RED, ALARM CLOCK BAKELIKE GREEN)
# 71  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED SPOTTY PAPER CUPS, SET/6 RED SPOTTY PAPER PLATES)
#
# [72 rows x 2 columns]

# %% [markdown]
# ### 2% of transactions

# %%
freq_items = apriori(item_df, min_support = 0.02, use_colnames=True)
freq_items.sort_values('support', ascending=False)
# Out:
#       support                                                         itemsets
# 197  0.223118                             (ROUND SNACK BOXES SET OF4 WOODLAND)
# 247  0.142473                                             (SPACEBOY LUNCH BOX)
# 154  0.142473                               (PLASTERS IN TIN WOODLAND ANIMALS)
# 183  0.141577                                       (REGENCY CAKESTAND 3 TIER)
# 196  0.139785                              (ROUND SNACK BOXES SET OF 4 FRUITS)
# ..        ...                                                              ...
# 301  0.020609          (CHARLOTTE BAG DOLLY GIRL DESIGN, DOLLY GIRL LUNCH BOX)
# 296  0.020609  (PLASTERS IN TIN WOODLAND ANIMALS, CHARLOTTE BAG APPLES DESIGN)
# 285  0.020609             (ALARM CLOCK BAKELIKE RED, PLASTERS IN TIN SPACEBOY)
# 415  0.020609              (RED RETROSPOT PICNIC BAG, LUNCH BAG RED RETROSPOT)
# 566  0.020609     (WOODLAND MINI BACKPACK, ROUND SNACK BOXES SET OF4 WOODLAND)
#
# [670 rows x 2 columns]

# %% [markdown]
# ### Association Rules

# %% [markdown]
# #### Support

# %%
assoc_rules = association_rules(freq_items, metric='support', min_threshold = 0.10)
assoc_rules
# Out:
#                             antecedents                           consequents  \
# 0  (ROUND SNACK BOXES SET OF4 WOODLAND)   (ROUND SNACK BOXES SET OF 4 FRUITS)
# 1   (ROUND SNACK BOXES SET OF 4 FRUITS)  (ROUND SNACK BOXES SET OF4 WOODLAND)
#
#    antecedent support  consequent support   support  confidence      lift  \
# 0            0.223118            0.139785  0.107527    0.481928  3.447637
# 1            0.139785            0.223118  0.107527    0.769231  3.447637
#
#    leverage  conviction
# 0  0.076338    1.660415
# 1  0.076338    3.366487

# %% [markdown]
# #### Confidence

# %%
assoc_rules = association_rules(freq_items, metric='confidence', min_threshold = 1)
assoc_rules
# Out:
#                                                                     antecedents  \
# 0                           (DOLLY GIRL CHILDRENS CUP, SPACEBOY CHILDRENS BOWL)
# 1                           (SPACEBOY CHILDRENS CUP, DOLLY GIRL CHILDRENS BOWL)
# 2                   (SET/6 RED SPOTTY PAPER CUPS, PACK OF 6 SKULL PAPER PLATES)
# 3   (SPACEBOY CHILDRENS CUP, DOLLY GIRL CHILDRENS CUP, SPACEBOY CHILDRENS BOWL)
# 4  (SPACEBOY CHILDRENS CUP, DOLLY GIRL CHILDRENS BOWL, SPACEBOY CHILDRENS BOWL)
#
#                        consequents  antecedent support  consequent support  \
# 0      (DOLLY GIRL CHILDRENS BOWL)            0.027778            0.037634
# 1       (DOLLY GIRL CHILDRENS CUP)            0.025090            0.034946
# 2  (SET/6 RED SPOTTY PAPER PLATES)            0.021505            0.077957
# 3      (DOLLY GIRL CHILDRENS BOWL)            0.024194            0.037634
# 4       (DOLLY GIRL CHILDRENS CUP)            0.024194            0.034946
#
#     support  confidence       lift  leverage  conviction
# 0  0.027778         1.0  26.571429  0.026732         inf
# 1  0.025090         1.0  28.615385  0.024213         inf
# 2  0.021505         1.0  12.827586  0.019829         inf
# 3  0.024194         1.0  26.571429  0.023283         inf
# 4  0.024194         1.0  28.615385  0.023348         inf

# %%
assoc_rules = association_rules(freq_items, metric='confidence', min_threshold = 0.9)
assoc_rules
# Out:
#                                                                       antecedents  \
# 0                                                      (DOLLY GIRL CHILDRENS CUP)
# 1                                                        (JAM JAR WITH GREEN LID)
# 2                             (DOLLY GIRL CHILDRENS CUP, SPACEBOY CHILDRENS BOWL)
# 3                              (SPACEBOY CHILDRENS CUP, DOLLY GIRL CHILDRENS CUP)
# 4                             (SPACEBOY CHILDRENS CUP, DOLLY GIRL CHILDRENS BOWL)
# 5                 (ROUND SNACK BOXES SET OF4 WOODLAND, DOLLY GIRL CHILDRENS BOWL)
# 6                             (SPACEBOY CHILDRENS CUP, DOLLY GIRL CHILDRENS BOWL)
# 7                   (PLASTERS IN TIN WOODLAND ANIMALS, LUNCH BAG SPACEBOY DESIGN)
# 8                    (PACK OF 6 SKULL PAPER CUPS, PACK OF 20 SKULL PAPER NAPKINS)
# 9                  (PACK OF 6 SKULL PAPER PLATES, PACK OF 20 SKULL PAPER NAPKINS)
# 10                (PACK OF 20 SKULL PAPER NAPKINS, SET/6 RED SPOTTY PAPER PLATES)
# 11                  (SET/6 RED SPOTTY PAPER CUPS, PACK OF 20 SKULL PAPER NAPKINS)
# 12                (PACK OF 20 SKULL PAPER NAPKINS, SET/6 RED SPOTTY PAPER PLATES)
# 13                    (PACK OF 6 SKULL PAPER CUPS, SET/6 RED SPOTTY PAPER PLATES)
# 14                    (SET/6 RED SPOTTY PAPER CUPS, PACK OF 6 SKULL PAPER PLATES)
# 15                      (POPPY'S PLAYHOUSE BEDROOM, POPPY'S PLAYHOUSE LIVINGROOM)
# 16                      (POPPY'S PLAYHOUSE KITCHEN, POPPY'S PLAYHOUSE LIVINGROOM)
# 17              (SET/6 RED SPOTTY PAPER CUPS, SET/20 RED RETROSPOT PAPER NAPKINS)
# 18            (SET/6 RED SPOTTY PAPER PLATES, SET/20 RED RETROSPOT PAPER NAPKINS)
# 19  (SPACEBOY CHILDRENS CUP, DOLLY GIRL CHILDRENS CUP, DOLLY GIRL CHILDRENS BOWL)
# 20    (SPACEBOY CHILDRENS CUP, DOLLY GIRL CHILDRENS CUP, SPACEBOY CHILDRENS BOWL)
# 21   (SPACEBOY CHILDRENS CUP, DOLLY GIRL CHILDRENS BOWL, SPACEBOY CHILDRENS BOWL)
# 22                            (SPACEBOY CHILDRENS CUP, DOLLY GIRL CHILDRENS BOWL)
# 23  (ROUND SNACK BOXES SET OF 4 FRUITS, DOLLY GIRL LUNCH BOX, SPACEBOY LUNCH BOX)
#
#                                             consequents  antecedent support  \
# 0                           (DOLLY GIRL CHILDRENS BOWL)            0.034946
# 1                               (JAM JAR WITH PINK LID)            0.022401
# 2                           (DOLLY GIRL CHILDRENS BOWL)            0.027778
# 3                           (DOLLY GIRL CHILDRENS BOWL)            0.027778
# 4                            (DOLLY GIRL CHILDRENS CUP)            0.025090
# 5                             (SPACEBOY CHILDRENS BOWL)            0.021505
# 6                             (SPACEBOY CHILDRENS BOWL)            0.025090
# 7                            (PLASTERS IN TIN SPACEBOY)            0.027778
# 8                        (PACK OF 6 SKULL PAPER PLATES)            0.027778
# 9                          (PACK OF 6 SKULL PAPER CUPS)            0.027778
# 10                       (PACK OF 6 SKULL PAPER PLATES)            0.022401
# 11                      (SET/6 RED SPOTTY PAPER PLATES)            0.021505
# 12                        (SET/6 RED SPOTTY PAPER CUPS)            0.022401
# 13                        (SET/6 RED SPOTTY PAPER CUPS)            0.023297
# 14                      (SET/6 RED SPOTTY PAPER PLATES)            0.021505
# 15                          (POPPY'S PLAYHOUSE KITCHEN)            0.021505
# 16                          (POPPY'S PLAYHOUSE BEDROOM)            0.022401
# 17                      (SET/6 RED SPOTTY PAPER PLATES)            0.051971
# 18                        (SET/6 RED SPOTTY PAPER CUPS)            0.054659
# 19                            (SPACEBOY CHILDRENS BOWL)            0.025090
# 20                          (DOLLY GIRL CHILDRENS BOWL)            0.024194
# 21                           (DOLLY GIRL CHILDRENS CUP)            0.024194
# 22  (DOLLY GIRL CHILDRENS CUP, SPACEBOY CHILDRENS BOWL)            0.025090
# 23                 (ROUND SNACK BOXES SET OF4 WOODLAND)            0.022401
#
#     consequent support   support  confidence       lift  leverage  conviction
# 0             0.037634  0.032258    0.923077  24.527473  0.030943   12.510753
# 1             0.041219  0.021505    0.960000  23.290435  0.020582   23.969534
# 2             0.037634  0.027778    1.000000  26.571429  0.026732         inf
# 3             0.037634  0.025090    0.903226  24.000000  0.024044    9.944444
# 4             0.034946  0.025090    1.000000  28.615385  0.024213         inf
# 5             0.050179  0.020609    0.958333  19.098214  0.019530   22.795699
# 6             0.050179  0.024194    0.964286  19.216837  0.022935   26.594982
# 7             0.115591  0.025986    0.935484   8.093023  0.022775   13.708333
# 8             0.035842  0.025090    0.903226  25.200000  0.024094    9.962963
# 9             0.038530  0.025090    0.903226  23.441860  0.024019    9.935185
# 10            0.035842  0.021505    0.960000  26.784000  0.020702   24.103943
# 11            0.077957  0.020609    0.958333  12.293103  0.018933   22.129032
# 12            0.078853  0.020609    0.920000  11.667273  0.018843   11.514337
# 13            0.078853  0.022401    0.961538  12.194056  0.020564   23.949821
# 14            0.077957  0.021505    1.000000  12.827586  0.019829         inf
# 15            0.037634  0.020609    0.958333  25.464286  0.019800   23.096774
# 16            0.034946  0.020609    0.920000  26.326154  0.019826   12.063172
# 17            0.077957  0.050179    0.965517  12.385256  0.046128   26.739247
# 18            0.078853  0.050179    0.918033  11.642325  0.045869   11.237993
# 19            0.050179  0.024194    0.964286  19.216837  0.022935   26.594982
# 20            0.037634  0.024194    1.000000  26.571429  0.023283         inf
# 21            0.034946  0.024194    1.000000  28.615385  0.023348         inf
# 22            0.027778  0.024194    0.964286  34.714286  0.023497   27.222222
# 23            0.223118  0.020609    0.920000   4.123373  0.015611    9.711022

# %% [markdown]
# #### Lift

# %%
assoc_rules = association_rules(freq_items, metric='lift', min_threshold = 28)
assoc_rules
# Out:
#                                                                     antecedents  \
# 0                           (SPACEBOY CHILDRENS CUP, DOLLY GIRL CHILDRENS BOWL)
# 1                                                    (DOLLY GIRL CHILDRENS CUP)
# 2                        (POPPY'S PLAYHOUSE BEDROOM, POPPY'S PLAYHOUSE KITCHEN)
# 3                                                (POPPY'S PLAYHOUSE LIVINGROOM)
# 4  (SPACEBOY CHILDRENS CUP, DOLLY GIRL CHILDRENS BOWL, SPACEBOY CHILDRENS BOWL)
# 5                           (SPACEBOY CHILDRENS CUP, DOLLY GIRL CHILDRENS BOWL)
# 6                           (DOLLY GIRL CHILDRENS CUP, SPACEBOY CHILDRENS BOWL)
# 7                                                    (DOLLY GIRL CHILDRENS CUP)
#
#                                                                     consequents  \
# 0                                                    (DOLLY GIRL CHILDRENS CUP)
# 1                           (SPACEBOY CHILDRENS CUP, DOLLY GIRL CHILDRENS BOWL)
# 2                                                (POPPY'S PLAYHOUSE LIVINGROOM)
# 3                        (POPPY'S PLAYHOUSE BEDROOM, POPPY'S PLAYHOUSE KITCHEN)
# 4                                                    (DOLLY GIRL CHILDRENS CUP)
# 5                           (DOLLY GIRL CHILDRENS CUP, SPACEBOY CHILDRENS BOWL)
# 6                           (SPACEBOY CHILDRENS CUP, DOLLY GIRL CHILDRENS BOWL)
# 7  (SPACEBOY CHILDRENS CUP, DOLLY GIRL CHILDRENS BOWL, SPACEBOY CHILDRENS BOWL)
#
#    antecedent support  consequent support   support  confidence       lift  \
# 0            0.025090            0.034946  0.025090    1.000000  28.615385
# 1            0.034946            0.025090  0.025090    0.717949  28.615385
# 2            0.027778            0.025090  0.020609    0.741935  29.571429
# 3            0.025090            0.027778  0.020609    0.821429  29.571429
# 4            0.024194            0.034946  0.024194    1.000000  28.615385
# 5            0.025090            0.027778  0.024194    0.964286  34.714286
# 6            0.027778            0.025090  0.024194    0.870968  34.714286
# 7            0.034946            0.024194  0.024194    0.692308  28.615385
#
#    leverage  conviction
# 0  0.024213         inf
# 1  0.024213    3.456500
# 2  0.019912    3.777778
# 3  0.019912    5.444444
# 4  0.023348         inf
# 5  0.023497   27.222222
# 6  0.023497    7.555556
# 7  0.023348    3.171371

# %% [markdown]
# ### Filter

# %%
assoc_rules = association_rules(freq_items, metric='support', min_threshold = 0.02)
assoc_rules.shape
# Out:
# (1188, 9)

# %%
assoc_rules[(assoc_rules['confidence'] >= 0.9) & (assoc_rules['lift'] >= 25)].sort_values('confidence', ascending=False)
# Out:
#                                                                        antecedents  \
# 679                            (DOLLY GIRL CHILDRENS CUP, SPACEBOY CHILDRENS BOWL)
# 685                            (SPACEBOY CHILDRENS CUP, DOLLY GIRL CHILDRENS BOWL)
# 1105   (SPACEBOY CHILDRENS CUP, DOLLY GIRL CHILDRENS CUP, SPACEBOY CHILDRENS BOWL)
# 1106  (SPACEBOY CHILDRENS CUP, DOLLY GIRL CHILDRENS BOWL, SPACEBOY CHILDRENS BOWL)
# 1109                           (SPACEBOY CHILDRENS CUP, DOLLY GIRL CHILDRENS BOWL)
# 872                (PACK OF 20 SKULL PAPER NAPKINS, SET/6 RED SPOTTY PAPER PLATES)
# 1039                     (POPPY'S PLAYHOUSE BEDROOM, POPPY'S PLAYHOUSE LIVINGROOM)
# 1040                     (POPPY'S PLAYHOUSE KITCHEN, POPPY'S PLAYHOUSE LIVINGROOM)
# 864                   (PACK OF 6 SKULL PAPER CUPS, PACK OF 20 SKULL PAPER NAPKINS)
#
#                                               consequents  antecedent support  \
# 679                           (DOLLY GIRL CHILDRENS BOWL)            0.027778
# 685                            (DOLLY GIRL CHILDRENS CUP)            0.025090
# 1105                          (DOLLY GIRL CHILDRENS BOWL)            0.024194
# 1106                           (DOLLY GIRL CHILDRENS CUP)            0.024194
# 1109  (DOLLY GIRL CHILDRENS CUP, SPACEBOY CHILDRENS BOWL)            0.025090
# 872                        (PACK OF 6 SKULL PAPER PLATES)            0.022401
# 1039                          (POPPY'S PLAYHOUSE KITCHEN)            0.021505
# 1040                          (POPPY'S PLAYHOUSE BEDROOM)            0.022401
# 864                        (PACK OF 6 SKULL PAPER PLATES)            0.027778
#
#       consequent support   support  confidence       lift  leverage  \
# 679             0.037634  0.027778    1.000000  26.571429  0.026732
# 685             0.034946  0.025090    1.000000  28.615385  0.024213
# 1105            0.037634  0.024194    1.000000  26.571429  0.023283
# 1106            0.034946  0.024194    1.000000  28.615385  0.023348
# 1109            0.027778  0.024194    0.964286  34.714286  0.023497
# 872             0.035842  0.021505    0.960000  26.784000  0.020702
# 1039            0.037634  0.020609    0.958333  25.464286  0.019800
# 1040            0.034946  0.020609    0.920000  26.326154  0.019826
# 864             0.035842  0.025090    0.903226  25.200000  0.024094
#
#       conviction
# 679          inf
# 685          inf
# 1105         inf
# 1106         inf
# 1109   27.222222
# 872    24.103943
# 1039   23.096774
# 1040   12.063172
# 864     9.962963

# %%
plt.figure(figsize=(12,8))

sns.scatterplot(x = assoc_rules['support'], y = assoc_rules['confidence'], hue = assoc_rules['lift'], s=100)

plt.title('Support vs Confidence')
plt.xlabel('Support')
plt.ylabel('Confidence')

plt.show()

# %% [markdown]
# ## Make Recommendations

# %%
type(assoc_rules['antecedents'][0])
# Out:
# frozenset

# %%
assoc_rules[assoc_rules['antecedents'] == {'SPACEBOY CHILDRENS BOWL'}]
# Out:
#                     antecedents  \
# 129   (SPACEBOY CHILDRENS BOWL)
# 135   (SPACEBOY CHILDRENS BOWL)
# 579   (SPACEBOY CHILDRENS BOWL)
# 613   (SPACEBOY CHILDRENS BOWL)
# 683   (SPACEBOY CHILDRENS BOWL)
# 695   (SPACEBOY CHILDRENS BOWL)
# 701   (SPACEBOY CHILDRENS BOWL)
# 707   (SPACEBOY CHILDRENS BOWL)
# 1097  (SPACEBOY CHILDRENS BOWL)
# 1117  (SPACEBOY CHILDRENS BOWL)
#
#                                                                         consequents  \
# 129                                                     (DOLLY GIRL CHILDRENS BOWL)
# 135                                                      (DOLLY GIRL CHILDRENS CUP)
# 579                                            (ROUND SNACK BOXES SET OF4 WOODLAND)
# 613                                                        (SPACEBOY CHILDRENS CUP)
# 683                           (DOLLY GIRL CHILDRENS CUP, DOLLY GIRL CHILDRENS BOWL)
# 695                 (ROUND SNACK BOXES SET OF4 WOODLAND, DOLLY GIRL CHILDRENS BOWL)
# 701                             (SPACEBOY CHILDRENS CUP, DOLLY GIRL CHILDRENS BOWL)
# 707                              (SPACEBOY CHILDRENS CUP, DOLLY GIRL CHILDRENS CUP)
# 1097                   (ROUND SNACK BOXES SET OF4 WOODLAND, SPACEBOY CHILDRENS CUP)
# 1117  (SPACEBOY CHILDRENS CUP, DOLLY GIRL CHILDRENS CUP, DOLLY GIRL CHILDRENS BOWL)
#
#       antecedent support  consequent support   support  confidence       lift  \
# 129             0.050179            0.037634  0.032258    0.642857  17.081633
# 135             0.050179            0.034946  0.027778    0.553571  15.840659
# 579             0.050179            0.223118  0.029570    0.589286   2.641136
# 613             0.050179            0.043011  0.036738    0.732143  17.022321
# 683             0.050179            0.032258  0.027778    0.553571  17.160714
# 695             0.050179            0.021505  0.020609    0.410714  19.098214
# 701             0.050179            0.025090  0.024194    0.482143  19.216837
# 707             0.050179            0.027778  0.024194    0.482143  17.357143
# 1097            0.050179            0.024194  0.020609    0.410714  16.976190
# 1117            0.050179            0.025090  0.024194    0.482143  19.216837
#
#       leverage  conviction
# 129   0.030370    2.694624
# 135   0.026024    2.161720
# 579   0.018374    1.891538
# 613   0.034580    3.572760
# 683   0.026159    2.167742
# 695   0.019530    1.660476
# 701   0.022935    1.882586
# 707   0.022800    1.877395
# 1097  0.019395    1.655914
# 1117  0.022935    1.882586

# %%
assoc_rules[assoc_rules['antecedents'] == {'SPACEBOY CHILDRENS CUP', 'DOLLY GIRL CHILDRENS CUP'}]
# Out:
#                                              antecedents  \
# 684   (SPACEBOY CHILDRENS CUP, DOLLY GIRL CHILDRENS CUP)
# 702   (SPACEBOY CHILDRENS CUP, DOLLY GIRL CHILDRENS CUP)
# 1108  (SPACEBOY CHILDRENS CUP, DOLLY GIRL CHILDRENS CUP)
#
#                                                consequents  \
# 684                            (DOLLY GIRL CHILDRENS BOWL)
# 702                              (SPACEBOY CHILDRENS BOWL)
# 1108  (DOLLY GIRL CHILDRENS BOWL, SPACEBOY CHILDRENS BOWL)
#
#       antecedent support  consequent support   support  confidence       lift  \
# 684             0.027778            0.037634  0.025090    0.903226  24.000000
# 702             0.027778            0.050179  0.024194    0.870968  17.357143
# 1108            0.027778            0.032258  0.024194    0.870968  27.000000
#
#       leverage  conviction
# 684   0.024044    9.944444
# 702   0.022800    7.361111
# 1108  0.023297    7.500000

# %%
assoc_rules[assoc_rules['consequents'] == {'ALARM CLOCK BAKELIKE RED'}]
# Out:
#                                                           antecedents  \
# 3                                    (ALARM CLOCK BAKELIKE CHOCOLATE)
# 7                                        (ALARM CLOCK BAKELIKE GREEN)
# 13                                      (ALARM CLOCK BAKELIKE ORANGE)
# 15                                        (ALARM CLOCK BAKELIKE PINK)
# 27                                         (PLASTERS IN TIN SPACEBOY)
# 29                               (ROUND SNACK BOXES SET OF4 WOODLAND)
# 31                                               (SPACEBOY LUNCH BOX)
# 626           (ALARM CLOCK BAKELIKE GREEN, ALARM CLOCK BAKELIKE PINK)
# 638  (ALARM CLOCK BAKELIKE GREEN, ROUND SNACK BOXES SET OF4 WOODLAND)
# 644   (ROUND SNACK BOXES SET OF4 WOODLAND, ALARM CLOCK BAKELIKE PINK)
#
#                     consequents  antecedent support  consequent support  \
# 3    (ALARM CLOCK BAKELIKE RED)            0.026882            0.069892
# 7    (ALARM CLOCK BAKELIKE RED)            0.065412            0.069892
# 13   (ALARM CLOCK BAKELIKE RED)            0.028674            0.069892
# 15   (ALARM CLOCK BAKELIKE RED)            0.078853            0.069892
# 27   (ALARM CLOCK BAKELIKE RED)            0.115591            0.069892
# 29   (ALARM CLOCK BAKELIKE RED)            0.223118            0.069892
# 31   (ALARM CLOCK BAKELIKE RED)            0.142473            0.069892
# 626  (ALARM CLOCK BAKELIKE RED)            0.043907            0.069892
# 638  (ALARM CLOCK BAKELIKE RED)            0.029570            0.069892
# 644  (ALARM CLOCK BAKELIKE RED)            0.032258            0.069892
#
#       support  confidence       lift  leverage  conviction
# 3    0.021505    0.800000  11.446154  0.019627    4.650538
# 7    0.050179    0.767123  10.975764  0.045607    3.993991
# 13   0.022401    0.781250  11.177885  0.020397    4.251920
# 15   0.046595    0.590909   8.454545  0.041084    2.273596
# 27   0.020609    0.178295   2.550984  0.012530    1.131923
# 29   0.036738    0.164659   2.355885  0.021144    1.113446
# 31   0.025090    0.176101   2.519594  0.015132    1.128909
# 626  0.036738    0.836735  11.971743  0.033670    5.696909
# 638  0.024194    0.818182  11.706294  0.022127    5.115591
# 644  0.024194    0.750000  10.730769  0.021939    3.720430

# %% [markdown]
# ## Frequently items

# %%
freq_items = apriori(item_df, min_support = 0.01, use_colnames=True)
freq_items
# Out:
#        support  \
# 0     0.013441
# 1     0.010753
# 2     0.026882
# 3     0.017025
# 4     0.013441
# ...        ...
# 3541  0.016129
# 3542  0.010753
# 3543  0.016129
# 3544  0.012545
# 3545  0.015233
#
#                                                                                                                                                                                         itemsets
# 0                                                                                                                                                                               ( BIRTHDAY CARD)
# 1                                                                                                                                                                                  ( RETRO SPOT)
# 2                                                                                                                                                                       (10 COLOUR SPACEBOY PEN)
# 3                                                                                                                                                                (12 PENCIL SMALL TUBE WOODLAND)
# 4                                                                                                                                                          (12 PENCILS SMALL TUBE RED RETROSPOT)
# ...                                                                                                                                                                                          ...
# 3541                                  (SET/6 RED SPOTTY PAPER CUPS, SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED SPOTTY PAPER PLATES, PACK OF 6 SKULL PAPER PLATES, PACK OF 6 SKULL PAPER CUPS)
# 3542                                  (PLASTERS IN TIN WOODLAND ANIMALS, PLASTERS IN TIN CIRCUS PARADE, PLASTERS IN TIN SPACEBOY, PLASTERS IN TIN STRONGMAN, ROUND SNACK BOXES SET OF4 WOODLAND)
# 3543                          (PLASTERS IN TIN WOODLAND ANIMALS, PLASTERS IN TIN CIRCUS PARADE, ROUND SNACK BOXES SET OF 4 FRUITS, PLASTERS IN TIN SPACEBOY, ROUND SNACK BOXES SET OF4 WOODLAND)
# 3544                         (PLASTERS IN TIN WOODLAND ANIMALS, PLASTERS IN TIN CIRCUS PARADE, ROUND SNACK BOXES SET OF 4 FRUITS, PLASTERS IN TIN STRONGMAN, ROUND SNACK BOXES SET OF4 WOODLAND)
# 3545  (SET/6 RED SPOTTY PAPER CUPS, SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED SPOTTY PAPER PLATES, PACK OF 6 SKULL PAPER PLATES, PACK OF 6 SKULL PAPER CUPS, PACK OF 20 SKULL PAPER NAPKINS)
#
# [3546 rows x 2 columns]

# %%
assoc_rules = association_rules(freq_items, metric='support', min_threshold = 0.01)
assoc_rules.sort_values('support', ascending =False)
# Out:
#                                antecedents  \
# 2970  (ROUND SNACK BOXES SET OF4 WOODLAND)
# 2971   (ROUND SNACK BOXES SET OF 4 FRUITS)
# 3050  (ROUND SNACK BOXES SET OF4 WOODLAND)
# 3051                  (SPACEBOY LUNCH BOX)
# 2451            (PLASTERS IN TIN SPACEBOY)
# ...                                    ...
# 2799                 (RED RETROSPOT PLATE)
# 2800                 (RED RETROSPOT PLATE)
# 2801       (SET/6 RED SPOTTY PAPER PLATES)
# 2802                 (RED RETROSPOT PLATE)
# 9701      (SET OF 6 TEA TIME BAKING CASES)
#
#                                                                consequents  \
# 2970                                   (ROUND SNACK BOXES SET OF 4 FRUITS)
# 2971                                  (ROUND SNACK BOXES SET OF4 WOODLAND)
# 3050                                                  (SPACEBOY LUNCH BOX)
# 3051                                  (ROUND SNACK BOXES SET OF4 WOODLAND)
# 2451                                    (PLASTERS IN TIN WOODLAND ANIMALS)
# ...                                                                    ...
# 2799                                         (SET/6 RED SPOTTY PAPER CUPS)
# 2800                                       (SET/6 RED SPOTTY PAPER PLATES)
# 2801                                                 (RED RETROSPOT PLATE)
# 2802                                                  (SPACEBOY LUNCH BOX)
# 9701  (SET OF 12 MINI LOAF BAKING CASES, SET OF 6 SNACK LOAF BAKING CASES)
#
#       antecedent support  consequent support   support  confidence       lift  \
# 2970            0.223118            0.139785  0.107527    0.481928   3.447637
# 2971            0.139785            0.223118  0.107527    0.769231   3.447637
# 3050            0.223118            0.142473  0.077957    0.349398   2.452376
# 3051            0.142473            0.223118  0.077957    0.547170   2.452376
# 2451            0.115591            0.142473  0.077061    0.666667   4.679245
# ...                  ...                 ...       ...         ...        ...
# 2799            0.042115            0.078853  0.010753    0.255319   3.237911
# 2800            0.042115            0.077957  0.010753    0.255319   3.275128
# 2801            0.077957            0.042115  0.010753    0.137931   3.275128
# 2802            0.042115            0.142473  0.010753    0.255319   1.792051
# 9701            0.025986            0.017025  0.010753    0.413793  24.304900
#
#       leverage  conviction
# 2970  0.076338    1.660415
# 2971  0.076338    3.366487
# 3050  0.046169    1.318051
# 3051  0.046169    1.715614
# 2451  0.060592    2.572581
# ...        ...         ...
# 2799  0.007432    1.236969
# 2800  0.007470    1.238172
# 2801  0.007470    1.111147
# 2802  0.004752    1.151536
# 9701  0.010310    1.676840
#
# [13876 rows x 9 columns]

# %%
round_snacks = assoc_rules[assoc_rules['antecedents'] == {'ROUND SNACK BOXES SET OF4 WOODLAND'}]
round_snacks = round_snacks.sort_values('support', ascending =False).head(5)
round_snacks
# Out:
#                                antecedents  \
# 2970  (ROUND SNACK BOXES SET OF4 WOODLAND)
# 3050  (ROUND SNACK BOXES SET OF4 WOODLAND)
# 2573  (ROUND SNACK BOXES SET OF4 WOODLAND)
# 2478  (ROUND SNACK BOXES SET OF4 WOODLAND)
# 3078  (ROUND SNACK BOXES SET OF4 WOODLAND)
#
#                               consequents  antecedent support  \
# 2970  (ROUND SNACK BOXES SET OF 4 FRUITS)            0.223118
# 3050                 (SPACEBOY LUNCH BOX)            0.223118
# 2573   (PLASTERS IN TIN WOODLAND ANIMALS)            0.223118
# 2478           (PLASTERS IN TIN SPACEBOY)            0.223118
# 3078             (WOODLAND CHARLOTTE BAG)            0.223118
#
#       consequent support   support  confidence      lift  leverage  conviction
# 2970            0.139785  0.107527    0.481928  3.447637  0.076338    1.660415
# 3050            0.142473  0.077957    0.349398  2.452376  0.046169    1.318051
# 2573            0.142473  0.065412    0.293173  2.057740  0.033624    1.213206
# 2478            0.115591  0.054659    0.244980  2.119361  0.028869    1.171371
# 3078            0.104839  0.051971    0.232932  2.221810  0.028580    1.166990

# %% [markdown]
# ## Top 5 Product Recommendations

# %%
plt.figure(figsize=(12,8))

sns.barplot(x = 'support', y = 'consequents', data = round_snacks, color='red')

plt.title('Top 5 Recomendations')
plt.xlabel('Support')
plt.ylabel('Recommend')

plt.show()
