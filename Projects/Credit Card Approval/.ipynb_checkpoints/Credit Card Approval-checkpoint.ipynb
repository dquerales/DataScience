# %% [markdown]
# # Credit Card Approval

# %% [markdown]
# ## Importing libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style='darkgrid')

# %% [markdown]
# ## Load data

# %% [markdown]
# data source: https://www.kaggle.com/datasets/rikdifos/credit-card-approval-prediction

# %%
application_details = pd.read_csv('Datasets/application_record.csv')
credit_record = pd.read_csv('Datasets/credit_record.csv')

# %% [markdown]
# ### Merge By ID

# %%
df = application_details.merge(credit_record, how='inner', on=['ID'])

# %% [markdown]
# ## Check dimensions

# %%
df.head()
# Out:
#         ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0  5008804           M            Y               Y             0
# 1  5008804           M            Y               Y             0
# 2  5008804           M            Y               Y             0
# 3  5008804           M            Y               Y             0
# 4  5008804           M            Y               Y             0
#
#    AMT_INCOME_TOTAL NAME_INCOME_TYPE NAME_EDUCATION_TYPE NAME_FAMILY_STATUS  \
# 0          427500.0          Working    Higher education     Civil marriage
# 1          427500.0          Working    Higher education     Civil marriage
# 2          427500.0          Working    Higher education     Civil marriage
# 3          427500.0          Working    Higher education     Civil marriage
# 4          427500.0          Working    Higher education     Civil marriage
#
#   NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  FLAG_MOBIL  FLAG_WORK_PHONE  \
# ...

# %%
df.shape
# Out:
# (777715, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 777715 entries, 0 to 777714
# Data columns (total 20 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ID                   777715 non-null  int64
#  1   CODE_GENDER          777715 non-null  object
#  2   FLAG_OWN_CAR         777715 non-null  object
#  3   FLAG_OWN_REALTY      777715 non-null  object
#  4   CNT_CHILDREN         777715 non-null  int64
#  5   AMT_INCOME_TOTAL     777715 non-null  float64
#  6   NAME_INCOME_TYPE     777715 non-null  object
#  7   NAME_EDUCATION_TYPE  777715 non-null  object
#  8   NAME_FAMILY_STATUS   777715 non-null  object
#  9   NAME_HOUSING_TYPE    777715 non-null  object
#  10  DAYS_BIRTH           777715 non-null  int64
#  11  DAYS_EMPLOYED        777715 non-null  int64
#  12  FLAG_MOBIL           777715 non-null  int64
#  13  FLAG_WORK_PHONE      777715 non-null  int64
#  14  FLAG_PHONE           777715 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# ID                          0
# CODE_GENDER                 0
# FLAG_OWN_CAR                0
# FLAG_OWN_REALTY             0
# CNT_CHILDREN                0
# AMT_INCOME_TOTAL            0
# NAME_INCOME_TYPE            0
# NAME_EDUCATION_TYPE         0
# NAME_FAMILY_STATUS          0
# NAME_HOUSING_TYPE           0
# DAYS_BIRTH                  0
# DAYS_EMPLOYED               0
# FLAG_MOBIL                  0
# FLAG_WORK_PHONE             0
# FLAG_PHONE                  0
# FLAG_EMAIL                  0
# OCCUPATION_TYPE        240048
# CNT_FAM_MEMBERS             0
# MONTHS_BALANCE              0
# STATUS                      0
# dtype: int64

# %% [markdown]
# ## Data Exploration & Visualization

# %%
plt.figure(figsize=(9, 9))
sns.countplot(x= 'CODE_GENDER', data=df)
plt.show()

# %%
plt.figure(figsize=(9, 9))
sns.violinplot(x= 'AMT_INCOME_TOTAL', data=df)
plt.show()

# %%
df.head(5)
# Out:
#         ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0  5008804           M            Y               Y             0
# 1  5008804           M            Y               Y             0
# 2  5008804           M            Y               Y             0
# 3  5008804           M            Y               Y             0
# 4  5008804           M            Y               Y             0
#
#    AMT_INCOME_TOTAL NAME_INCOME_TYPE NAME_EDUCATION_TYPE NAME_FAMILY_STATUS  \
# 0          427500.0          Working    Higher education     Civil marriage
# 1          427500.0          Working    Higher education     Civil marriage
# 2          427500.0          Working    Higher education     Civil marriage
# 3          427500.0          Working    Higher education     Civil marriage
# 4          427500.0          Working    Higher education     Civil marriage
#
#   NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  FLAG_MOBIL  FLAG_WORK_PHONE  \
# ...

# %%
df = pd.concat([df, pd.get_dummies(df['CODE_GENDER'], prefix='gENDER', drop_first=True)], axis=1)

# %%
df.sample(20)
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 500426  5096201           F            N               N             0
# 622063  5117283           M            Y               Y             1
# 701721  5140178           F            N               Y             0
# 723311  5143244           F            N               N             0
# 598434  5115860           F            Y               Y             1
# 35278   5010893           F            N               Y             0
# 513969  5097189           F            N               Y             0
# 640833  5125191           M            N               Y             0
# 74433   5023232           F            Y               Y             0
# 632355  5118157           F            N               N             1
# 374778  5067951           F            N               Y             0
# 86734   5023977           M            Y               Y             1
# ...

# %%
plt.figure(figsize=(9,9))
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(9,9))
sns.kdeplot(x=df['CNT_CHILDREN'], data=df)
# Out:
# <AxesSubplot:xlabel='CNT_CHILDREN', ylabel='Density'>

# %%
plt.figure(figsize=(9,9))
sns.histplot(x=df['CNT_CHILDREN'], data=df)
# Out:
# <AxesSubplot:xlabel='CNT_CHILDREN', ylabel='Count'>
