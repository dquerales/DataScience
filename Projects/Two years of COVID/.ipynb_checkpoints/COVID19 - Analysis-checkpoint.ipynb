# %% [markdown]
# # COVID 2020-2021 Analysis

# %% [markdown]
# Update History:
# * 31/12/2021 File created

# %%
import pandas as pd                 # pandas is a dataframe library
import matplotlib.pyplot as plt

# %% [markdown]
# ## Loading the Data
#
# source: https://ourworldindata.org/coronavirus-source-data, https://covid.ourworldindata.org/data/owid-covid-data.csv

# %%
df = pd.read_csv("Datasets/owid-covid-data.csv") #from 31/12/2021

# %% [markdown]
# ## Check the dimensions

# %%
df.shape
# Out:
# (151085, 67)

# %%
df.head(5)
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    female_smokers  male_smokers  handwashing_facilities  \
# 0             NaN           NaN                  37.746
# 1             NaN           NaN                  37.746
# 2             NaN           NaN                  37.746
# 3             NaN           NaN                  37.746
# 4             NaN           NaN                  37.746
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                         0.5            64.83                    0.511
# 1                         0.5            64.83                    0.511
# 2                         0.5            64.83                    0.511
# 3                         0.5            64.83                    0.511
# 4                         0.5            64.83                    0.511
#
#    excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                   NaN                          NaN
# 1                                   NaN                          NaN
# 2                                   NaN                          NaN
# 3                                   NaN                          NaN
# 4                                   NaN                          NaN
#
#    excess_mortality  excess_mortality_cumulative_per_million
# 0               NaN                                      NaN
# 1               NaN                                      NaN
# 2               NaN                                      NaN
# 3               NaN                                      NaN
# 4               NaN                                      NaN
#
# [5 rows x 67 columns]

# %%
df.tail(5)
# Out:
#        iso_code continent  location        date  total_cases  new_cases  \
# 151080      ZWE    Africa  Zimbabwe  2021-12-26     204351.0      605.0
# 151081      ZWE    Africa  Zimbabwe  2021-12-27     205449.0     1098.0
# 151082      ZWE    Africa  Zimbabwe  2021-12-28     207548.0     2099.0
# 151083      ZWE    Africa  Zimbabwe  2021-12-29     207548.0        0.0
# 151084      ZWE    Africa  Zimbabwe  2021-12-30     211728.0     4180.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 151080            1811.143        4891.0         6.0               15.571
# 151081            1481.429        4908.0        17.0               14.714
# 151082            1397.143        4940.0        32.0               17.286
# 151083            1163.429        4940.0         0.0               16.000
# 151084            1483.429        4997.0        57.0               20.286
#
#         ...  female_smokers  male_smokers  handwashing_facilities  \
# 151080  ...             1.6          30.7                  36.791
# 151081  ...             1.6          30.7                  36.791
# 151082  ...             1.6          30.7                  36.791
# 151083  ...             1.6          30.7                  36.791
# 151084  ...             1.6          30.7                  36.791
#
#         hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 151080                         1.7            61.49                    0.571
# 151081                         1.7            61.49                    0.571
# 151082                         1.7            61.49                    0.571
# 151083                         1.7            61.49                    0.571
# 151084                         1.7            61.49                    0.571
#
#         excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 151080                                   NaN                          NaN
# 151081                                   NaN                          NaN
# 151082                                   NaN                          NaN
# 151083                                   NaN                          NaN
# 151084                                   NaN                          NaN
#
#         excess_mortality  excess_mortality_cumulative_per_million
# 151080               NaN                                      NaN
# 151081               NaN                                      NaN
# 151082               NaN                                      NaN
# 151083               NaN                                      NaN
# 151084               NaN                                      NaN
#
# [5 rows x 67 columns]

# %% [markdown]
# ## Check for null values

# %%
df.isnull().values.any()
# Out:
# True

# %% [markdown]
# ## Replace Blank for Nulls

# %%
df = df.fillna('NULL')

# %% [markdown]
# ## Checking changes

# %%
df
# Out:
#        iso_code continent     location        date total_cases new_cases  \
# 0           AFG      Asia  Afghanistan  2020-02-24         5.0       5.0
# 1           AFG      Asia  Afghanistan  2020-02-25         5.0       0.0
# 2           AFG      Asia  Afghanistan  2020-02-26         5.0       0.0
# 3           AFG      Asia  Afghanistan  2020-02-27         5.0       0.0
# 4           AFG      Asia  Afghanistan  2020-02-28         5.0       0.0
# ...         ...       ...          ...         ...         ...       ...
# 151080      ZWE    Africa     Zimbabwe  2021-12-26    204351.0     605.0
# 151081      ZWE    Africa     Zimbabwe  2021-12-27    205449.0    1098.0
# 151082      ZWE    Africa     Zimbabwe  2021-12-28    207548.0    2099.0
# 151083      ZWE    Africa     Zimbabwe  2021-12-29    207548.0       0.0
# 151084      ZWE    Africa     Zimbabwe  2021-12-30    211728.0    4180.0
#
#        new_cases_smoothed total_deaths new_deaths new_deaths_smoothed  ...  \
# 0                    NULL         NULL       NULL                NULL  ...
# 1                    NULL         NULL       NULL                NULL  ...
# 2                    NULL         NULL       NULL                NULL  ...
# 3                    NULL         NULL       NULL                NULL  ...
# 4                    NULL         NULL       NULL                NULL  ...
# ...                   ...          ...        ...                 ...  ...
# 151080           1811.143       4891.0        6.0              15.571  ...
# 151081           1481.429       4908.0       17.0              14.714  ...
# 151082           1397.143       4940.0       32.0              17.286  ...
# 151083           1163.429       4940.0        0.0                16.0  ...
# 151084           1483.429       4997.0       57.0              20.286  ...
#
#        female_smokers male_smokers handwashing_facilities  \
# 0                NULL         NULL                 37.746
# 1                NULL         NULL                 37.746
# 2                NULL         NULL                 37.746
# 3                NULL         NULL                 37.746
# 4                NULL         NULL                 37.746
# ...               ...          ...                    ...
# 151080            1.6         30.7                 36.791
# 151081            1.6         30.7                 36.791
# 151082            1.6         30.7                 36.791
# 151083            1.6         30.7                 36.791
# 151084            1.6         30.7                 36.791
#
#        hospital_beds_per_thousand life_expectancy human_development_index  \
# 0                             0.5           64.83                   0.511
# 1                             0.5           64.83                   0.511
# 2                             0.5           64.83                   0.511
# 3                             0.5           64.83                   0.511
# 4                             0.5           64.83                   0.511
# ...                           ...             ...                     ...
# 151080                        1.7           61.49                   0.571
# 151081                        1.7           61.49                   0.571
# 151082                        1.7           61.49                   0.571
# 151083                        1.7           61.49                   0.571
# 151084                        1.7           61.49                   0.571
#
#        excess_mortality_cumulative_absolute excess_mortality_cumulative  \
# 0                                      NULL                        NULL
# 1                                      NULL                        NULL
# 2                                      NULL                        NULL
# 3                                      NULL                        NULL
# 4                                      NULL                        NULL
# ...                                     ...                         ...
# 151080                                 NULL                        NULL
# 151081                                 NULL                        NULL
# 151082                                 NULL                        NULL
# 151083                                 NULL                        NULL
# 151084                                 NULL                        NULL
#
#        excess_mortality excess_mortality_cumulative_per_million
# 0                  NULL                                    NULL
# 1                  NULL                                    NULL
# 2                  NULL                                    NULL
# 3                  NULL                                    NULL
# 4                  NULL                                    NULL
# ...                 ...                                     ...
# 151080             NULL                                    NULL
# 151081             NULL                                    NULL
# 151082             NULL                                    NULL
# 151083             NULL                                    NULL
# 151084             NULL                                    NULL
#
# [151085 rows x 67 columns]

# %%
df.isnull().values.any()
# Out:
# False

# %% [markdown]
# ## Save prepared Data for MySQL

# %%
df.to_csv('clean_owid_covid.csv', encoding='utf-8')

# %% [markdown]
# ## Data Preparation

# %% [markdown]
# ### Reload & update data from source

# %%
df = pd.read_csv("https://covid.ourworldindata.org/data/owid-covid-data.csv")

# %% [markdown]
# ### Check columns names

# %%
df.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
#        'new_vaccinations', 'new_vaccinations_smoothed',
#        'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred',
#        'people_fully_vaccinated_per_hundred', 'total_boosters_per_hundred',
#        'new_vaccinations_smoothed_per_million',
#        'new_people_vaccinated_smoothed',
#        'new_people_vaccinated_smoothed_per_hundred', 'stringency_index',
#        'population', 'population_density', 'median_age', 'aged_65_older',
#        'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
#        'cardiovasc_death_rate', 'diabetes_prevalence', 'female_smokers',
#        'male_smokers', 'handwashing_facilities', 'hospital_beds_per_thousand',
#        'life_expectancy', 'human_development_index',
#        'excess_mortality_cumulative_absolute', 'excess_mortality_cumulative',
#        'excess_mortality', 'excess_mortality_cumulative_per_million'],
#       dtype='object')

# %%
df.shape
# Out:
# (167554, 67)

# %%
df.drop(['iso_code','new_cases_smoothed', 'new_deaths',
       'new_deaths_smoothed', 'total_cases_per_million',
       'new_cases_per_million', 'new_cases_smoothed_per_million',
       'total_deaths_per_million', 'new_deaths_per_million',
       'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
       'icu_patients_per_million', 'hosp_patients',
       'hosp_patients_per_million', 'weekly_icu_admissions',
       'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
       'weekly_hosp_admissions_per_million', 'new_tests', 'total_tests',
       'total_tests_per_thousand', 'new_tests_per_thousand',
       'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
       'positive_rate', 'tests_per_case', 'tests_units',
       'people_vaccinated', 'total_boosters',
       'new_vaccinations', 'new_vaccinations_smoothed',
       'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred',
       'people_fully_vaccinated_per_hundred', 'total_boosters_per_hundred',
       'new_vaccinations_smoothed_per_million',
       'new_people_vaccinated_smoothed',
       'new_people_vaccinated_smoothed_per_hundred', 'stringency_index', 
       'population_density', 'median_age', 'aged_65_older',
       'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
       'cardiovasc_death_rate', 'diabetes_prevalence', 'female_smokers',
       'male_smokers', 'handwashing_facilities', 'hospital_beds_per_thousand',
       'life_expectancy', 'human_development_index',
       'excess_mortality_cumulative_absolute', 'excess_mortality_cumulative',
       'excess_mortality', 'excess_mortality_cumulative_per_million'], axis=1, inplace=True)

# %%
df.head()
# Out:
#   continent     location        date  total_cases  new_cases  total_deaths  \
# 0      Asia  Afghanistan  2020-02-24          5.0        5.0           NaN
# 1      Asia  Afghanistan  2020-02-25          5.0        0.0           NaN
# 2      Asia  Afghanistan  2020-02-26          5.0        0.0           NaN
# 3      Asia  Afghanistan  2020-02-27          5.0        0.0           NaN
# 4      Asia  Afghanistan  2020-02-28          5.0        0.0           NaN
#
#    total_vaccinations  people_fully_vaccinated  population
# 0                 NaN                      NaN  39835428.0
# 1                 NaN                      NaN  39835428.0
# 2                 NaN                      NaN  39835428.0
# 3                 NaN                      NaN  39835428.0
# 4                 NaN                      NaN  39835428.0

# %%
df.shape
# Out:
# (167554, 9)

# %% [markdown]
# ## Check for nulls

# %%
df.isnull().any()
# Out:
# continent                   True
# location                   False
# date                       False
# total_cases                 True
# new_cases                   True
# total_deaths                True
# total_vaccinations          True
# people_fully_vaccinated     True
# population                  True
# dtype: bool

# %% [markdown]
# ### Replace Blank for zeros

# %%
df = df.fillna(0)

# %%
df.isnull().any()
# Out:
# continent                  False
# location                   False
# date                       False
# total_cases                False
# new_cases                  False
# total_deaths               False
# total_vaccinations         False
# people_fully_vaccinated    False
# population                 False
# dtype: bool

# %% [markdown]
# ### Check data types

# %%
df.dtypes
# Out:
# continent                   object
# location                    object
# date                        object
# total_cases                float64
# new_cases                  float64
# total_deaths               float64
# total_vaccinations         float64
# people_fully_vaccinated    float64
# population                 float64
# dtype: object

# %% [markdown]
# ### Change data types

# %%
df['date'] = pd.to_datetime(df['date'])

# %% [markdown]
# ## Data Exploration

# %% [markdown]
# ### Total cases

# %%
total_cases = df['total_cases'].max()
total_cases
# Out:
# 453426276.0

# %% [markdown]
# ### Total deaths

# %%
total_deaths = df['total_deaths'].max()
total_deaths
# Out:
# 6029789.0

# %%
data_per = total_deaths/total_cases*100
data_per
# Out:
# 1.3298278726131876

# %%
plt.figure(figsize=(10,8))
plt.pie([total_cases-total_deaths, total_deaths], labels = ['alive', 'deaths'])
plt.title('total_deaths from total_cases')
circle = plt.Circle( (0,0), 0.7, color='white')
p=plt.gcf()
p.gca().add_artist(circle)

plt.show()

# %%
result = {'alive': [total_cases-total_deaths], 'deaths': [total_deaths]}
result = pd.DataFrame(result, index=None)
result
# Out:
#          alive     deaths
# 0  447396487.0  6029789.0

# %%
result.to_csv('total_deaths_cases_owid_covid.csv', encoding='utf-8',index=None)

# %% [markdown]
# ### Cases per day

# %%
cases_per_day = df.groupby('date').max()
cases_per_day = cases_per_day[['new_cases']].sort_values(by=['date'], ascending=True)
cases_per_day['7dayAvg'] = cases_per_day['new_cases'].rolling(7).mean()
cases_per_day
# Out:
# C:\Users\Daniel\AppData\Local\Temp/ipykernel_1632/727484434.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   cases_per_day = df.groupby('date').max()
#             new_cases       7dayAvg
# date
# 2020-01-01        0.0           NaN
# 2020-01-02        0.0           NaN
# 2020-01-03        0.0           NaN
# 2020-01-04        0.0           NaN
# 2020-01-05        0.0           NaN
# ...               ...           ...
# 2022-03-07  1498717.0  1.541542e+06
# 2022-03-08  1844922.0  1.585029e+06
# 2022-03-09  1881823.0  1.617683e+06
# 2022-03-10  1817503.0  1.608428e+06
# 2022-03-11        0.0  1.365647e+06
#
# [801 rows x 2 columns]

# %%
plt.figure(figsize=(10,8))
plt.plot(cases_per_day.index, cases_per_day['new_cases'], cases_per_day['7dayAvg'])
plt.title('New cases per day')
plt.xlabel('Month')
plt.ylabel('New Cases')
plt.legend(['New Cases', '7dayAvg'])
plt.show()

# %%
cases_per_day.to_csv('new_cases_per_day_owid_covid.csv', encoding='utf-8')

# %% [markdown]
# ### Total Vaccinations

# %%
total_vacc = df['total_vaccinations'].max()
total_vacc
# Out:
# 10953605441.0

# %% [markdown]
# ### Fully Vaccinated

# %%
fully_vacc = df['people_fully_vaccinated'].max()
fully_vacc
# Out:
# 4456512074.0

# %%
max_pop = df['population'].max()
full_per = (fully_vacc/max_pop)*100
full_per
# Out:
# 56.59087578023022

# %%
plt.figure(figsize=(10,8))
plt.pie([fully_vacc, max_pop-fully_vacc], labels = ['people_fully_vaccinated', 'not_or_not_fully_vaccinated'])
plt.title('% of people_fully_vaccinated')
circle = plt.Circle( (0,0), 0.7, color='white')
p=plt.gcf()
p.gca().add_artist(circle)

plt.show()

# %%
result = {'not_or_not_fully_vaccinated': [max_pop-fully_vacc], 'fully_vacc': [fully_vacc]}
result = pd.DataFrame(result, index=None)
result
# Out:
#    not_or_not_fully_vaccinated    fully_vacc
# 0                 3.418454e+09  4.456512e+09

# %%
result.to_csv('total_fully_vacc_owid_covid.csv', encoding='utf-8',index=None)

# %% [markdown]
# ### Top 5 Countries with most deaths

# %%
top_deaths = df.groupby('location').max()
top_deaths = top_deaths[['total_deaths']].sort_values(by=['total_deaths'], ascending=False)
top_deaths.head(15)
# Out:
#                      total_deaths
# location
# World                   6029789.0
# Upper middle income     2459831.0
# High income             2241611.0
# Europe                  1736367.0
# North America           1395529.0
# Asia                    1372854.0
# Lower middle income     1285457.0
# South America           1266078.0
# European Union          1026201.0
# United States            965464.0
# Brazil                   654380.0
# India                    515714.0
# Russia                   351776.0
# Mexico                   320607.0
# Africa                   250750.0

# %%
top_deaths = top_deaths.iloc[9:]
top_deaths = top_deaths.head(5)
top_deaths
# Out:
#                total_deaths
# location
# United States      965464.0
# Brazil             654380.0
# India              515714.0
# Russia             351776.0
# Mexico             320607.0

# %%
plt.figure(figsize=(10,8))
plt.bar(top_deaths.index, top_deaths['total_deaths'])
plt.title('Top 5 countries')

plt.show()

# %%
result = top_deaths

# %%
result.to_csv('top_countries_owid_covid.csv', encoding='utf-8')

# %% [markdown]
# ## Deaths per day by country

# %%
deaths_per_day = df[['date','location','total_deaths']]
deaths_per_day = deaths_per_day.pivot(index='location', columns='date', values='total_deaths')
deaths_per_day.tail(20)
# Out:
# date                      2020-01-01  2020-01-02  2020-01-03  2020-01-04  \
# location
# Turkmenistan                     NaN         NaN         NaN         NaN
# Turks and Caicos Islands         NaN         NaN         NaN         NaN
# Tuvalu                           NaN         NaN         NaN         NaN
# Uganda                           NaN         NaN         NaN         NaN
# Ukraine                          NaN         NaN         NaN         NaN
# United Arab Emirates             NaN         NaN         NaN         NaN
# United Kingdom                   NaN         NaN         NaN         NaN
# United States                    NaN         NaN         NaN         NaN
# Upper middle income              NaN         NaN         NaN         NaN
# Uruguay                          NaN         NaN         NaN         NaN
# Uzbekistan                       NaN         NaN         NaN         NaN
# Vanuatu                          NaN         NaN         NaN         NaN
# Vatican                          NaN         NaN         NaN         NaN
# Venezuela                        NaN         NaN         NaN         NaN
# Vietnam                          NaN         NaN         NaN         NaN
# Wallis and Futuna                NaN         NaN         NaN         NaN
# World                            NaN         NaN         NaN         NaN
# Yemen                            NaN         NaN         NaN         NaN
# Zambia                           NaN         NaN         NaN         NaN
# Zimbabwe                         NaN         NaN         NaN         NaN
#
# date                      2020-01-05  2020-01-06  2020-01-07  2020-01-08  \
# location
# Turkmenistan                     NaN         NaN         NaN         NaN
# Turks and Caicos Islands         NaN         NaN         NaN         NaN
# Tuvalu                           NaN         NaN         NaN         NaN
# Uganda                           NaN         NaN         NaN         NaN
# Ukraine                          NaN         NaN         NaN         NaN
# United Arab Emirates             NaN         NaN         NaN         NaN
# United Kingdom                   NaN         NaN         NaN         NaN
# United States                    NaN         NaN         NaN         NaN
# Upper middle income              NaN         NaN         NaN         NaN
# Uruguay                          NaN         NaN         NaN         NaN
# Uzbekistan                       NaN         NaN         NaN         NaN
# Vanuatu                          NaN         NaN         NaN         NaN
# Vatican                          NaN         NaN         NaN         NaN
# Venezuela                        NaN         NaN         NaN         NaN
# Vietnam                          NaN         NaN         NaN         NaN
# Wallis and Futuna                NaN         NaN         NaN         NaN
# World                            NaN         NaN         NaN         NaN
# Yemen                            NaN         NaN         NaN         NaN
# Zambia                           NaN         NaN         NaN         NaN
# Zimbabwe                         NaN         NaN         NaN         NaN
#
# date                      2020-01-09  2020-01-10  ...  2022-03-02  2022-03-03  \
# location                                          ...
# Turkmenistan                     NaN         NaN  ...         NaN         NaN
# Turks and Caicos Islands         NaN         NaN  ...        36.0        36.0
# Tuvalu                           NaN         NaN  ...         NaN         NaN
# Uganda                           NaN         NaN  ...      3588.0      3588.0
# Ukraine                          NaN         NaN  ...    112459.0    112459.0
# United Arab Emirates             NaN         NaN  ...      2301.0      2301.0
# United Kingdom                   NaN         NaN  ...    161848.0    162042.0
# United States                    NaN         NaN  ...    954906.0    956651.0
# Upper middle income              NaN         NaN  ...   2441263.0   2443928.0
# Uruguay                          NaN         NaN  ...      7005.0      7014.0
# Uzbekistan                       NaN         NaN  ...      1637.0      1637.0
# Vanuatu                          NaN         NaN  ...         1.0         1.0
# Vatican                          NaN         NaN  ...         0.0         0.0
# Venezuela                        NaN         NaN  ...      5639.0      5643.0
# Vietnam                          NaN         NaN  ...     40452.0     40547.0
# Wallis and Futuna                NaN         NaN  ...         7.0         7.0
# World                            NaN         NaN  ...   5973264.0   5981705.0
# Yemen                            NaN         NaN  ...      2135.0      2135.0
# Zambia                           NaN         NaN  ...      3955.0      3957.0
# Zimbabwe                         NaN         NaN  ...      5396.0      5396.0
#
# date                      2022-03-04  2022-03-05  2022-03-06  2022-03-07  \
# location
# Turkmenistan                     NaN         NaN         NaN         NaN
# Turks and Caicos Islands        36.0        36.0        36.0        36.0
# Tuvalu                           NaN         NaN         NaN         NaN
# Uganda                        3590.0      3590.0      3590.0      3592.0
# Ukraine                     112459.0    112459.0    112459.0    112459.0
# United Arab Emirates          2301.0      2301.0      2301.0      2302.0
# United Kingdom              162152.0    162152.0    162152.0    162292.0
# United States               958342.0    958635.0    958819.0    960505.0
# Upper middle income        2446779.0   2449308.0   2451215.0   2453099.0
# Uruguay                       7031.0      7040.0      7046.0      7051.0
# Uzbekistan                    1637.0      1637.0      1637.0      1637.0
# Vanuatu                          1.0         1.0         1.0         1.0
# Vatican                          0.0         0.0         0.0         0.0
# Venezuela                     5645.0      5647.0      5649.0      5649.0
# Vietnam                      40644.0     40726.0     40813.0     40891.0
# Wallis and Futuna                7.0         7.0         7.0         7.0
# World                      5990206.0   5995686.0   5999710.0   6007511.0
# Yemen                         2135.0      2135.0      2138.0      2138.0
# Zambia                        3958.0      3958.0      3959.0      3959.0
# Zimbabwe                      5397.0      5397.0      5399.0      5399.0
#
# date                      2022-03-08  2022-03-09  2022-03-10  2022-03-11
# location
# Turkmenistan                     NaN         NaN         NaN         NaN
# Turks and Caicos Islands        36.0        36.0        36.0         NaN
# Tuvalu                           NaN         NaN         NaN         NaN
# Uganda                        3592.0      3593.0      3593.0         NaN
# Ukraine                     112459.0    112459.0    112459.0         NaN
# United Arab Emirates          2302.0      2302.0      2302.0         0.0
# United Kingdom              162505.0    162628.0    162770.0         NaN
# United States               961843.0    963819.0    965464.0         NaN
# Upper middle income        2455321.0   2457556.0   2459831.0         0.0
# Uruguay                       7059.0      7069.0      7075.0         0.0
# Uzbekistan                    1637.0      1637.0      1637.0         NaN
# Vanuatu                          1.0         1.0         1.0         NaN
# Vatican                          0.0         0.0         0.0         NaN
# Venezuela                     5650.0      5652.0      5655.0         NaN
# Vietnam                      40977.0     41086.0     41157.0         0.0
# Wallis and Futuna                7.0         7.0         7.0         NaN
# World                      6014690.0   6022403.0   6029789.0         0.0
# Yemen                         2138.0      2138.0      2139.0         NaN
# Zambia                        3959.0      3960.0      3960.0         0.0
# Zimbabwe                      5400.0      5400.0      5408.0         0.0
#
# [20 rows x 801 columns]

# %%
deaths_per_day.to_csv('deaths_perday_countries_owid_covid.csv', encoding='utf-8')
